# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import aphrodite.results
import vislab.results
import vislab.datasets
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
label_df = vislab.datasets.wikipaintings.get_artist_df(1000)

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'wikipaintings_artist_oct25', '/Users/sergeyk/work/aphrodite/data/results3/',
    multiclass=True, force=False)
pred_prefix = 'pred'
print preds_panel.minor_axis
# Out:
# Results in collection wikipaintings_artist_oct25: 1
# Index([u'noise False vw'], dtype='object')

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=['noise False vw', '_random'],
    balanced=True, with_plot=True, with_print=True)
# Out:
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [ True]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:264: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [0 1 3 5 6]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [0 1 3 5 6].
#   y_true, y_pred)
# Looks like the preds frame already has gt info.
# ********************noise False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                                    precision    recall  f1-score  support
# ...
