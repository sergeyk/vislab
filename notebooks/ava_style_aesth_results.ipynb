# %%
# %load_ext autoreload
# %autoreload 2
import re
import os
import aphrodite.results
import pandas as pd

import vislab
import vislab.datasets
import vislab.results
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
c = vislab.util.get_mongodb_client()['predict']['ava_style_aesth_oct29']
if c.find({'features': 'noise'}).count() > 0:
    c.remove({'features': 'noise'})
pd.DataFrame([x for x in c.find()])
# Out:
#                          _id                          data  \
# 0   526f86549622958641aaee6f      ava_style_rating_std_bin
# 1   526f86689622958641aaee70   ava_style_rating_std_cn_bin
# 2   526f868b9622958641aaee71     ava_style_rating_mean_bin
# 3   526f873a9622958641aaee72  ava_style_rating_mean_cn_bin
# 4   526f87f19622958641aaee73      ava_style_rating_std_bin
# 5   526f8d349622958641aaee75   ava_style_rating_std_cn_bin
# 6   526f8d499622958641aaee76      ava_style_rating_std_bin
# 7   526f8df79622958641aaee77  ava_style_rating_mean_cn_bin
# 8   526f92cb9622958641aaee78   ava_style_rating_std_cn_bin
# 9   526f93819622958641aaee79     ava_style_rating_mean_bin
# 10  527014449622958641aaee7a     ava_style_rating_mean_bin
# 11  5270145a9622958641aaee7b   ava_style_rating_std_cn_bin
# 12  527014989622958641aaee7c  ava_style_rating_mean_cn_bin
# 13  52701bdb9622958641aaee7d     ava_style_rating_mean_bin
# 14  527020209622958641aaee7e      ava_style_rating_std_bin
# 15  527022309622958641aaee7f  ava_style_rating_mean_cn_bin
# 16  52702b579622958641aaee80      ava_style_rating_std_bin
# 17  52702b5e9622958641aaee81     ava_style_rating_mean_bin
# 18  52702baa9622958641aaee82  ava_style_rating_mean_cn_bin
# 19  52702bb19622958641aaee83   ava_style_rating_std_cn_bin
# 20  52702cab9622958641aaee84      ava_style_rating_std_bin
# 21  52702d2c9622958641aaee85   ava_style_rating_std_cn_bin
# 22  52702e439622958641aaee86     ava_style_rating_mean_bin
# 23  52702e479622958641aaee87  ava_style_rating_mean_cn_bin
# 24  5272510b8dc9cfbe92ca2345     ava_style_rating_mean_bin
# 25  527251378dc9cfbe92ca2346      ava_style_rating_std_bin
# 26  527250e49622958641af684d      ava_style_rating_std_bin
#
#                     features  num_test  num_train  num_val quadratic  \
# 0                 [lab_hist]      2809       8984     2286     False
# 1                 [lab_hist]      2809       9170     2100     False
# 2                 [lab_hist]      2809       9060     2210     False
# 3                 [lab_hist]      2809       8998     2272     False
# 4            [gbvs_saliency]      2809       8984     2286     False
# 5                [decaf_fc6]      2809       9170     2100     False
# 6                [decaf_fc6]      2809       8984     2286     False
# 7                [decaf_fc6]      2809       8998     2272     False
# 8        [decaf_fc6_flatten]      2809       9170     2100     False
# 9        [decaf_fc6_flatten]      2809       9060     2210     False
# 10           [gbvs_saliency]      2809       9060     2210     False
# 11           [gbvs_saliency]      2809       9170     2100     False
# 12           [gbvs_saliency]      2809       8998     2272     False
# 13               [decaf_fc6]      2809       9060     2210     False
# 14       [decaf_fc6_flatten]      2809       8984     2286     False
# 15       [decaf_fc6_flatten]      2809       8998     2272     False
# 16                [gist_256]      2809       8984     2286     False
# 17                [gist_256]      2809       9060     2210     False
# 18                [gist_256]      2809       8998     2272     False
# 19                [gist_256]      2809       9170     2100     False
# 20                  [mc_bit]      2809       8984     2286     False
# 21                  [mc_bit]      2809       9170     2100     False
# 22                  [mc_bit]      2809       9060     2210     False
# 23                  [mc_bit]      2809       8998     2272     False
# 24  [fusion_ava_style_oct22]      2809       9060     2210      None
# 25  [fusion_ava_style_oct22]      2809       8984     2286      None
# 26  [fusion_ava_style_oct22]      2809       8984     2286      None
#
#                                          results_name  score_test  score_val  \
# 0   data_ava_style_rating_std_bin_features_['lab_h...    0.535583   0.551982
# 1   data_ava_style_rating_std_cn_bin_features_['la...    0.543307   0.569578
# 2   data_ava_style_rating_mean_bin_features_['lab_...    0.543319   0.583865
# 3   data_ava_style_rating_mean_cn_bin_features_['l...    0.549347   0.548444
# 4   data_ava_style_rating_std_bin_features_['gbvs_...    0.511687   0.542105
# 5   data_ava_style_rating_std_cn_bin_features_['de...    0.563672   0.601905
# 6   data_ava_style_rating_std_bin_features_['decaf...    0.554665   0.566054
# 7   data_ava_style_rating_mean_cn_bin_features_['d...    0.621670   0.626320
# 8   data_ava_style_rating_std_cn_bin_features_['de...    0.542578   0.671279
# 9   data_ava_style_rating_mean_bin_features_['deca...    0.586433   0.673303
# 10  data_ava_style_rating_mean_bin_features_['gbvs...    0.508035   0.551410
# 11  data_ava_style_rating_std_cn_bin_features_['gb...    0.526254   0.546367
# 12  data_ava_style_rating_mean_cn_bin_features_['g...    0.507942   0.522546
# 13  data_ava_style_rating_mean_bin_features_['deca...    0.630831   0.612217
# 14  data_ava_style_rating_std_bin_features_['decaf...    0.535350   0.587204
# 15  data_ava_style_rating_mean_cn_bin_features_['d...    0.585735   0.593034
# 16  data_ava_style_rating_std_bin_features_['gist_...    0.526603   0.566054
# 17  data_ava_style_rating_mean_bin_features_['gist...    0.523324   0.535294
# 18  data_ava_style_rating_mean_cn_bin_features_['g...    0.534917   0.573504
# 19  data_ava_style_rating_std_cn_bin_features_['gi...    0.533203   0.536667
# 20  data_ava_style_rating_std_bin_features_['mc_bi...    0.530448   0.580318
# 21  data_ava_style_rating_std_cn_bin_features_['mc...    0.565200   0.570881
# 22  data_ava_style_rating_mean_bin_features_['mc_b...    0.627473   0.725733
# 23  data_ava_style_rating_mean_cn_bin_features_['m...    0.620927   0.653404
# 24  data_ava_style_rating_mean_bin_features_['fusi...    0.559131   0.574208
# 25  data_ava_style_rating_std_bin_features_['fusio...    0.545741   0.571741
# 26  data_ava_style_rating_std_bin_features_['fusio...    0.562303   0.582677
#
#    task
# 0   clf
# 1   clf
# 2   clf
# 3   clf
# 4   clf
# 5   clf
# 6   clf
# 7   clf
# 8   clf
# 9   clf
# 10  clf
# 11  clf
# 12  clf
# 13  clf
# 14  clf
# 15  clf
# 16  clf
# 17  clf
# 18  clf
# 19  clf
# 20  clf
# 21  clf
# 22  clf
# 23  clf
# 24  clf
# 25  clf
# 26  clf

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_aesth_oct29', os.path.expanduser('~/work/aphrodite/data/results2'),
    multiclass=False, force=True)
pred_prefix = 'ava_style'
print preds_panel.minor_axis
preds_panel
# Out:
# Results in collection ava_style_aesth_oct29: 27
# Index([u'decaf_fc6 False vw', u'decaf_fc6_flatten False vw', u'fusion_ava_style_oct22 None vw', u'gbvs_saliency False vw', u'gist_256 False vw', u'lab_hist False vw', u'label', u'mc_bit False vw', u'split'], dtype='object')
# <class 'pandas.core.panel.Panel'>
# Dimensions: 4 (items) x 14079 (major_axis) x 9 (minor_axis)
# Items axis: clf ava_style_rating_mean_bin to clf ava_style_rating_std_cn_bin
# Major_axis axis: 1187 to 97009
# Minor_axis axis: decaf_fc6 False vw to split

# %%
label_df = vislab.datasets.ava.get_ratings_df()
label_df.iloc[:5]
# Out:
#           rating_mean  rating_std rating_mean_bin rating_std_bin  \
# image_id
# 953619         5.6371      1.4218            True          False
# 953958         4.6984      1.9851           False           True
# 954184         5.6746      1.1043            True          False
# 954113         5.7734      1.2822            True          False
# 953980         5.2093      1.1592           False          False
#
#          rating_mean_cn_bin rating_std_cn_bin
# image_id
# 953619                False              True
# 953958                False              True
# 954184                False             False
# 954113                 True             False
# 953980                False             False

# %%
task_name = 'clf ava_style_rating_mean_bin'

task_names = preds_panel.items
task_metrics = {}
for task_name in task_names:
    pred_df = preds_panel[task_name]
    feature_names = [x for x in pred_df.columns if x not in ['label', 'split']]
    feat_metrics = {}
    for feature_name in feature_names:
        pdf = pred_df[[feature_name, 'label']]
        pdf.columns = ['pred', 'label']
        feat_metrics[feature_name] = vislab.results.binary_metrics(
            pdf, task_name + ' ' + feature_name, balanced=True,
            with_plot=False, with_print=True)
    task_metrics[task_name] = feat_metrics
    
acc_df = pd.DataFrame([
    pd.Series(
        [
             task_metrics[task_name][key]['accuracy']
             for key in sorted(task_metrics[task_name].keys())
        ],
        sorted(task_metrics[task_name].keys()),
        name=task_name
    )
    for task_name in task_names
])
# Out:
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_bin decaf_fc6 False vw balanced
# ap_sklearn: 0.750563022822
# mcc: 0.375171192946
# ap: 0.751333470656
#        precision    recall  f1-score  support
# False   0.682620  0.700928  0.691653     6898
# True    0.692686  0.674108  0.683271     6898
# accuracy: 0.687518121195
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_bin decaf_fc6_flatten False vw balanced
# ap_sklearn: 0.867989939821
# mcc: 0.559598388257
# ap: 0.868084795781
#        precision    recall  f1-score  support
# False   0.777698  0.783560  0.780618     6898
# True    0.781916  0.776022  0.778958     6898
# accuracy: 0.779791243839
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_bin fusion_ava_style_oct22 None vw balanced
# ap_sklearn: 0.567382288621
# mcc: 0.168443172286
# ap: 0.603277990998
#        precision    recall  f1-score  support
# False   0.599479  0.500580  0.545584     6898
# True    0.571304  0.665555  0.614839     6898
# accuracy: 0.583067555813
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_bin gbvs_saliency False vw balanced
# ap_sklearn: 0.624670574351
# mcc: 0.0773390632414
# ap: 0.665226258963
#        precision    recall  f1-score  support
# False   0.542596  0.490287  0.515117     6898
# True    0.535105  0.586692  0.559712     6898
# accuracy: 0.538489417222
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_bin gist_256 False vw balanced
# ap_sklearn: 0.577092567682
# mcc: 0.115442377921
# ap: 0.578352526583
#        precision    recall  f1-score  support
# False   0.556104  0.571905  0.563894     6898
# True    0.559385  0.543491  0.551324     6898
# accuracy: 0.557697883444
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_bin lab_hist False vw balanced
# ap_sklearn: 0.756128107669
# mcc: 0.146514694021
# ap: 0.779373460574
#        precision    recall  f1-score  support
# False   0.577580  0.544506  0.560555     6898
# True    0.569176  0.601769  0.585019     6898
# accuracy: 0.5731371412
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_bin mc_bit False vw balanced
# ap_sklearn: 0.920535336372
# mcc: 0.685334279968
# ap: 0.92101432716
#        precision    recall  f1-score  support
# False   0.834324  0.854885  0.844479     6898
# True    0.851219  0.830241  0.840599     6898
# accuracy: 0.842563061757
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_cn_bin decaf_fc6 False vw balanced
# ap_sklearn: 0.738333840218
# mcc: 0.372589142843
# ap: 0.739030049376
#        precision    recall  f1-score  support
# False   0.682766  0.695820  0.689231     7009
# True    0.689891  0.676701  0.683232     7009
# accuracy: 0.686260522186
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_cn_bin decaf_fc6_flatten False vw balanced
# ap_sklearn: 0.637590933033
# mcc: 0.576420830539
# ap: 0.725283256966
#        precision    recall  f1-score  support
# False   0.785876  0.792267  0.789059     7009
# True    0.790564  0.784135  0.787336     7009
# accuracy: 0.788200884577
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_cn_bin fusion_ava_style_oct22 None vw balanced
# ap_sklearn: 0.497189032435
# mcc: 0.0
# ap: 0.50313783395
#        precision  recall  f1-score  support
# False        0.5       1  0.666667     7009
# True         0.0       0  0.000000     7009
# accuracy: 0.5
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_cn_bin gbvs_saliency False vw balanced
# ap_sklearn: 0.430075635624
# mcc: 0.0916858473655
# ap: 0.512869818385
#        precision    recall  f1-score  support
# False   0.550188  0.500499  0.524169     7009
# True    0.541874  0.590812  0.565286     7009
# accuracy: 0.545655585676
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_cn_bin gist_256 False vw balanced
# ap_sklearn: 0.559631661198
# mcc: 0.115229663983
# ap: 0.562204586577
#        precision    recall  f1-score  support
# False   0.555357  0.577543  0.566233     7009
# True    0.559964  0.537595  0.548551     7009
# accuracy: 0.557568840063
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_cn_bin lab_hist False vw balanced
# ap_sklearn: 0.400965561322
# mcc: 0.148983721214
# ap: 0.508747068922
#        precision    recall  f1-score  support
# False   0.559393  0.683978  0.615444     7009
# True    0.593429  0.461264  0.519066     7009
# accuracy: 0.572620915965
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_mean_cn_bin mc_bit False vw balanced
# ap_sklearn: 0.766033002712
# mcc: 0.682511732151
# ap: 0.851446443819
#        precision    recall  f1-score  support
# False   0.835367  0.849907  0.842574     7009
# True    0.847248  0.832501  0.839810     7009
# accuracy: 0.841204166072
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_bin decaf_fc6 False vw balanced
# ap_sklearn: 0.68658822588
# mcc: 0.300322652266
# ap: 0.687492711443
#        precision    recall  f1-score  support
# False   0.651031  0.647271  0.649146     6926
# True    0.649297  0.653046  0.651166     6926
# accuracy: 0.650158821831
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_bin decaf_fc6_flatten False vw balanced
# ap_sklearn: 0.778126312094
# mcc: 0.544932708953
# ap: 0.787757525258
#        precision    recall  f1-score  support
# False   0.775314  0.767254  0.771263     6926
# True    0.769648  0.777649  0.773628     6926
# accuracy: 0.772451631533
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_bin fusion_ava_style_oct22 None vw balanced
# ap_sklearn: 0.602512668599
# mcc: 0.168047807807
# ap: 0.668678344541
#        precision    recall  f1-score  support
# False   0.560359  0.739243  0.637490     6926
# True    0.616967  0.420012  0.499785     6926
# accuracy: 0.579627490615
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_bin gbvs_saliency False vw balanced
# ap_sklearn: 0.508592479767
# mcc: 0.0846991723324
# ap: 0.532242861243
#        precision    recall  f1-score  support
# False   0.540436  0.565406  0.552639     6926
# True    0.544354  0.519203  0.531481     6926
# accuracy: 0.542304360381
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_bin gist_256 False vw balanced
# ap_sklearn: 0.566483402408
# mcc: 0.107863658301
# ap: 0.568113778592
#        precision    recall  f1-score  support
# False   0.545725  0.634999  0.586987     6926
# True    0.563611  0.471412  0.513405     6926
# accuracy: 0.553205313312
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_bin lab_hist False vw balanced
# ap_sklearn: 0.512866194588
# mcc: 0.143825662218
# ap: 0.593612424373
#        precision    recall  f1-score  support
# False   0.558128  0.675137  0.611082     6926
# True    0.588966  0.465492  0.520000     6926
# accuracy: 0.570314755992
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_bin mc_bit False vw balanced
# ap_sklearn: 0.602580761558
# mcc: 0.565865367314
# ap: 0.700867249753
#        precision    recall  f1-score  support
# False   0.737893  0.864568  0.796224     6926
# True    0.836500  0.692896  0.757956     6926
# accuracy: 0.778732313023
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_cn_bin decaf_fc6 False vw balanced
# ap_sklearn: 0.706563396386
# mcc: 0.33297986749
# ap: 0.707680780791
#        precision    recall  f1-score  support
# False   0.665702  0.668861  0.667278     6532
# True    0.667282  0.664115  0.665695     6532
# accuracy: 0.666488058788
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_cn_bin decaf_fc6_flatten False vw balanced
# ap_sklearn: 0.860450658028
# mcc: 0.548123789144
# ap: 0.861754147051
#        precision    recall  f1-score  support
# False   0.781678  0.760257  0.770819     6532
# True    0.766652  0.787661  0.777014     6532
# accuracy: 0.773958971219
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_cn_bin fusion_ava_style_oct22 None vw balanced
# ap_sklearn: 0.501694651605
# mcc: 0.0
# ap: 0.506072836568
#        precision  recall  f1-score  support
# False        0.5       1  0.666667     6532
# True         0.0       0  0.000000     6532
# accuracy: 0.5
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_cn_bin gbvs_saliency False vw balanced
# ap_sklearn: 0.613809473716
# mcc: 0.0915511883131
# ap: 0.61976988133
#        precision   recall  f1-score  support
# False   0.546071  0.54256   0.54431     6532
# True    0.545482  0.54899   0.54723     6532
# accuracy: 0.545774647887
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_cn_bin gist_256 False vw balanced
# ap_sklearn: 0.578865837136
# mcc: 0.110979607957
# ap: 0.580379525149
#        precision    recall  f1-score  support
# False   0.548812  0.618800  0.581708     6532
# True    0.563081  0.491274  0.524732     6532
# accuracy: 0.555036742192
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_cn_bin lab_hist False vw balanced
# ap_sklearn: 0.793920343844
# mcc: 0.16206132531
# ap: 0.847043329857
#        precision    recall  f1-score  support
# False   0.570792  0.647428  0.606700     6532
# True    0.592750  0.513166  0.550094     6532
# accuracy: 0.580296999388
#
# ------------------------------------------------------------
# Classification metrics on clf ava_style_rating_std_cn_bin mc_bit False vw balanced
# ap_sklearn: 0.870645580966
# mcc: 0.638004251001
# ap: 0.875354181116
#        precision    recall  f1-score  support
# False   0.787488  0.869106  0.826286     6532
# True    0.853971  0.765462  0.807298     6532
# accuracy: 0.81728413962
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [ True]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])

# %%
acc_df
# Out:
#                                   decaf_fc6 False vw  \
# clf ava_style_rating_mean_bin               0.687518
# clf ava_style_rating_mean_cn_bin            0.686261
# clf ava_style_rating_std_bin                0.650159
# clf ava_style_rating_std_cn_bin             0.666488
#
#                                   decaf_fc6_flatten False vw  \
# clf ava_style_rating_mean_bin                       0.779791
# clf ava_style_rating_mean_cn_bin                    0.788201
# clf ava_style_rating_std_bin                        0.772452
# clf ava_style_rating_std_cn_bin                     0.773959
#
#                                   fusion_ava_style_oct22 None vw  \
# clf ava_style_rating_mean_bin                           0.583068
# clf ava_style_rating_mean_cn_bin                        0.500000
# clf ava_style_rating_std_bin                            0.579627
# clf ava_style_rating_std_cn_bin                         0.500000
#
#                                   gbvs_saliency False vw  gist_256 False vw  \
# clf ava_style_rating_mean_bin                   0.538489           0.557698
# clf ava_style_rating_mean_cn_bin                0.545656           0.557569
# clf ava_style_rating_std_bin                    0.542304           0.553205
# clf ava_style_rating_std_cn_bin                 0.545775           0.555037
#
#                                   lab_hist False vw  mc_bit False vw
# clf ava_style_rating_mean_bin              0.573137         0.842563
# clf ava_style_rating_mean_cn_bin           0.572621         0.841204
# clf ava_style_rating_std_bin               0.570315         0.778732
# clf ava_style_rating_std_cn_bin            0.580297         0.817284

# %%
fig = vislab.results_viz.plot_df_bar(acc_df)
# TODO: why are these all so similar?
