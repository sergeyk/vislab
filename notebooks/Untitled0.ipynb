# %%
# %load_ext autoreload
# %autoreload 2

import vislab.datasets
from vislab.predict import *
import pandas as pd

# %%
source_df = vislab.datasets.ava.get_style_df()
source_df = source_df[source_df['_split'] != 'test']
dataset_name = 'ava_style'
random_seed = 42
column_names = [x for x in source_df.columns if not x.startswith('_')]
column_set_name = 'styles'
balanced = False
test_frac = 0.2

# %%
plt.figure()
plt.bar(arange(num_labels), 1. * np.bincount(dataset['train_df'].label), label='train')
plt.figure()
plt.bar(arange(num_labels), 1. * np.bincount(dataset['val_df'].label), label='val')
plt.figure()
plt.bar(arange(num_labels), 1. * np.bincount(dataset['test_df'].label), label='test')
# Out:
# <Container object of 14 artists>
