# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import pandas as pd

import vislab
import vislab.datasets
import vislab.results

# %%
c = vislab.util.get_mongodb_client()['predict']['ava_style_oct22']
if c.find({'features': 'noise'}).count() > 0:
    c.remove({'features': 'noise'})
pd.DataFrame([x for x in c.find()])
# Out:
#                         _id                 data                   features  \
# 0  52677171efd80f8750020095  ava_style_style_ALL                 [lab_hist]
# 1  52687f4043d2db703b9f97e6  ava_style_style_ALL                 [gist_256]
# 2  5268e26a43d2db703b9f97e7  ava_style_style_ALL                   [mc_bit]
# 3  5269dc0c43d2db703b9f9825  ava_style_style_ALL                [decaf_fc6]
# 4  5269f802265138430c54b4d6  ava_style_style_ALL        [decaf_fc6_flatten]
# 5  526edf859622958641aaee55  ava_style_style_ALL            [gbvs_saliency]
# 6  52719c9e9622958641af6842  ava_style_style_ALL          [decaf_tuned_fc6]
# 7  5271e1399622958641af6845  ava_style_style_ALL  [decaf_tuned_fc6_flatten]
#
#    num_test  num_train  num_val  \
# 0      2573       8501     2769
# 1      2573       8501     2769
# 2      2573       8501     2769
# 3      2573       8501     2769
# 4      2573       8501     2769
# 5      2573       8501     2769
# 6      2573       8501     2769
# 7      2573       8501     2769
#
#                                              pred_df quadratic  \
# 0  �cpandas.core.frame\nDataFrame\nq)�qcpandas...
# 1  �cpandas.core.frame\nDataFrame\nq)�qcpandas...     False
# 2  �cpandas.core.frame\nDataFrame\nq)�qcpandas...     False
# 3  �cpandas.core.frame\nDataFrame\nq)�qcpandas...     False
# 4  �cpandas.core.frame\nDataFrame\nq)�qcpandas...     False
# 5                                                NaN     False
# 6                                                NaN     False
# 7                                                NaN     False
#
#                                         results_name  score_test  score_val  \
# 0                                                NaN    0.284286   0.247508
# 1                                                NaN    0.187143   0.184385
# 2                                                NaN    0.434286   0.417647
# 3                                                NaN    0.488571   0.529900
# 4                                                NaN    0.435714   0.823920
# 5  data_ava_style_style_ALL_features_['gbvs_salie...    0.084666   0.181594
# 6  data_ava_style_style_ALL_features_['decaf_tune...    0.417053   0.696795
# 7  data_ava_style_style_ALL_features_['decaf_tune...    0.363299   0.820871
#
#   task
# 0  clf
# 1  clf
# 2  clf
# 3  clf
# 4  clf
# 5  clf
# 6  clf
# 7  clf

# %%
label_df = vislab.datasets.ava.get_style_df()

# %%
df = label_df[[x for x in label_df.columns if not x.startswith('_')]]
M = df.shape[1]
data = []

df_m = pd.DataFrame([
        df.apply(lambda x: [x[i] & x[j] for j in range(M)], raw=True, axis=1).sum(0).astype(float) / df[column].sum()
        for i, column in enumerate(df.columns)
    ],
    index=df.columns
)
df_m
# Out:
#                             style_Complementary_Colors  style_Duotones  \
# style_Complementary_Colors                    1.000000        0.000000
# style_Duotones                                0.000000        1.000000
# style_HDR                                     0.017500        0.012500
# style_Image_Grain                             0.004678        0.116959
# style_Light_On_White                          0.000894        0.023256
# style_Long_Exposure                           0.007919        0.015837
# style_Macro                                   0.019802        0.024202
# style_Motion_Blur                             0.004710        0.045526
# style_Negative_Image                          0.014568        0.031217
# style_Rule_of_Thirds                          0.017881        0.047020
# style_Shallow_DOF                             0.039226        0.053735
# style_Silhouettes                             0.011407        0.024715
# style_Soft_Focus                              0.008141        0.047490
# style_Vanishing_Point                         0.006231        0.048287
#
#                             style_HDR  style_Image_Grain  \
# style_Complementary_Colors   0.007021           0.004012
# style_Duotones               0.003067           0.061350
# style_HDR                    1.000000           0.000000
# style_Image_Grain            0.000000           1.000000
# style_Light_On_White         0.000000           0.004472
# style_Long_Exposure          0.005656           0.004525
# style_Macro                  0.000000           0.002750
# style_Motion_Blur            0.000000           0.014129
# style_Negative_Image         0.000000           0.001041
# style_Rule_of_Thirds         0.003311           0.013245
# style_Shallow_DOF            0.000537           0.013971
# style_Silhouettes            0.000000           0.007605
# style_Soft_Focus             0.000000           0.008141
# style_Vanishing_Point        0.001558           0.009346
#
#                             style_Light_On_White  style_Long_Exposure  \
# style_Complementary_Colors              0.001003             0.007021
# style_Duotones                          0.015951             0.008589
# style_HDR                               0.000000             0.012500
# style_Image_Grain                       0.005848             0.004678
# style_Light_On_White                    1.000000             0.000000
# style_Long_Exposure                     0.000000             1.000000
# style_Macro                             0.008251             0.002200
# style_Motion_Blur                       0.001570             0.045526
# style_Negative_Image                    0.003122             0.000000
# style_Rule_of_Thirds                    0.012583             0.006623
# style_Shallow_DOF                       0.010210             0.001075
# style_Silhouettes                       0.000000             0.006654
# style_Soft_Focus                        0.010855             0.000000
# style_Vanishing_Point                   0.000000             0.003115
#
#                             style_Macro  style_Motion_Blur  \
# style_Complementary_Colors     0.036108           0.003009
# style_Duotones                 0.026994           0.017791
# style_HDR                      0.000000           0.000000
# style_Image_Grain              0.005848           0.010526
# style_Light_On_White           0.013417           0.000894
# style_Long_Exposure            0.004525           0.032805
# style_Macro                    1.000000           0.001650
# style_Motion_Blur              0.004710           1.000000
# style_Negative_Image           0.016649           0.000000
# style_Rule_of_Thirds           0.013245           0.004636
# style_Shallow_DOF              0.087050           0.004299
# style_Silhouettes              0.003802           0.000951
# style_Soft_Focus               0.024423           0.001357
# style_Vanishing_Point          0.000000           0.001558
#
#                             style_Negative_Image  style_Rule_of_Thirds  \
# style_Complementary_Colors              0.014042              0.027081
# style_Duotones                          0.018405              0.043558
# style_HDR                               0.000000              0.012500
# style_Image_Grain                       0.001170              0.023392
# style_Light_On_White                    0.002683              0.016995
# style_Long_Exposure                     0.000000              0.011312
# style_Macro                             0.008801              0.011001
# style_Motion_Blur                       0.000000              0.010989
# style_Negative_Image                    1.000000              0.003122
# style_Rule_of_Thirds                    0.001987              1.000000
# style_Shallow_DOF                       0.013434              0.069855
# style_Silhouettes                       0.000000              0.029468
# style_Soft_Focus                        0.000000              0.029851
# style_Vanishing_Point                   0.003115              0.010903
#
#                             style_Shallow_DOF  style_Silhouettes  \
# style_Complementary_Colors           0.073220           0.012036
# style_Duotones                       0.061350           0.015951
# style_HDR                            0.002500           0.000000
# style_Image_Grain                    0.030409           0.009357
# style_Light_On_White                 0.016995           0.000000
# style_Long_Exposure                  0.002262           0.007919
# style_Macro                          0.089109           0.002200
# style_Motion_Blur                    0.012559           0.001570
# style_Negative_Image                 0.026015           0.000000
# style_Rule_of_Thirds                 0.086093           0.020530
# style_Shallow_DOF                    1.000000           0.001075
# style_Silhouettes                    0.001901           1.000000
# style_Soft_Focus                     0.044776           0.010855
# style_Vanishing_Point                0.010903           0.001558
#
#                             style_Soft_Focus  style_Vanishing_Point
# style_Complementary_Colors          0.006018               0.004012
# style_Duotones                      0.021472               0.019018
# style_HDR                           0.000000               0.002500
# style_Image_Grain                   0.007018               0.007018
# style_Light_On_White                0.007156               0.000000
# style_Long_Exposure                 0.000000               0.002262
# style_Macro                         0.009901               0.000000
# style_Motion_Blur                   0.001570               0.001570
# style_Negative_Image                0.000000               0.002081
# style_Rule_of_Thirds                0.014570               0.004636
# style_Shallow_DOF                   0.017732               0.003761
# style_Silhouettes                   0.007605               0.000951
# style_Soft_Focus                    1.000000               0.002714
# style_Vanishing_Point               0.003115               1.000000

# %%
fig = vislab.dataset_viz.plot_occurrence(df_m)

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_oct22', os.path.expanduser('~/work/aphrodite/data/results2'),
    multiclass=True, force=True)
pred_prefix = 'pred'
print preds_panel.minor_axis
preds_panel
# Out:
# Results in collection ava_style_oct22: 8
# Index([u'decaf_fc6 False vw', u'decaf_fc6_flatten False vw', u'decaf_tuned_fc6 False vw', u'decaf_tuned_fc6_flatten False vw', u'gbvs_saliency False vw', u'gist_256 False vw', u'lab_hist  vw', u'mc_bit False vw'], dtype='object')
# <class 'pandas.core.panel.Panel'>
# Dimensions: 31 (items) x 13843 (major_axis) x 8 (minor_axis)
# Items axis: importance to style_Vanishing_Point
# Major_axis axis: 1187 to 97008
# Minor_axis axis: decaf_fc6 False vw to mc_bit False vw

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=preds_panel.minor_axis.tolist() + ['random'],
    balanced=True, with_plot=False, with_print=True)
# Out:
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_fc6 False vw********************
# Balancing dataset!
# style_Complementary_Colors    237
# style_Duotones                589
# style_HDR                      83
# style_Image_Grain             183
# style_Light_On_White          158
# style_Long_Exposure           208
# style_Macro                   459
# style_Motion_Blur             149
# style_Negative_Image          193
# style_Rule_of_Thirds          398
# style_Shallow_DOF             677
# style_Silhouettes             227
# style_Soft_Focus              169
# style_Vanishing_Point         102
# dtype: int64
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.618421  0.394958  0.482051      119
# style_Duotones               0.797619  0.290043  0.425397      231
# style_HDR                    0.521127  0.521127  0.521127       71
# style_Image_Grain            0.222222  0.444444  0.296296       45
# style_Light_On_White         0.559633  0.871429  0.681564       70
# style_Long_Exposure          0.464789  0.383721  0.420382       86
# style_Macro                  0.433962  0.242105  0.310811       95
# style_Motion_Blur            0.311475  0.404255  0.351852       47
# style_Negative_Image         0.489130  0.714286  0.580645       63
# style_Rule_of_Thirds         0.263158  0.133333  0.176991       75
# style_Shallow_DOF            0.204819  0.447368  0.280992       38
# style_Silhouettes            0.505618  0.750000  0.604027       60
# style_Soft_Focus             0.191781  0.451613  0.269231       31
# style_Vanishing_Point        0.376471  0.727273  0.496124       44
# accuracy: 0.437209302326
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_fc6_flatten False vw********************
# Balancing dataset!
# style_Complementary_Colors    237
# style_Duotones                588
# style_HDR                      83
# style_Image_Grain             183
# style_Light_On_White          158
# style_Long_Exposure           208
# style_Macro                   459
# style_Motion_Blur             149
# style_Negative_Image          193
# style_Rule_of_Thirds          398
# style_Shallow_DOF             677
# style_Silhouettes             227
# style_Soft_Focus              169
# style_Vanishing_Point         101
# dtype: int64
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.438095  0.389831  0.412556      118
# style_Duotones               0.702381  0.268182  0.388158      220
# style_HDR                    0.681818  0.211268  0.322581       71
# style_Image_Grain            0.272727  0.195652  0.227848       46
# style_Light_On_White         0.485294  0.891892  0.628571       74
# style_Long_Exposure          0.328358  0.275000  0.299320       80
# style_Macro                  0.611111  0.231579  0.335878       95
# style_Motion_Blur            0.290909  0.347826  0.316832       46
# style_Negative_Image         0.412371  0.666667  0.509554       60
# style_Rule_of_Thirds         0.300000  0.233766  0.262774       77
# style_Shallow_DOF            0.177215  0.333333  0.231405       42
# style_Silhouettes            0.435897  0.809524  0.566667       63
# style_Soft_Focus             0.224490  0.379310  0.282051       29
# style_Vanishing_Point        0.252033  0.738095  0.375758       42
# accuracy: 0.395108184384
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_tuned_fc6 False vw********************
# Balancing dataset!
# style_Complementary_Colors    237
# style_Duotones                588
# style_HDR                      83
# style_Image_Grain             183
# style_Light_On_White          158
# style_Long_Exposure           208
# style_Macro                   459
# style_Motion_Blur             149
# style_Negative_Image          193
# style_Rule_of_Thirds          398
# style_Shallow_DOF             677
# style_Silhouettes             227
# style_Soft_Focus              169
# style_Vanishing_Point         101
# dtype: int64
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.577465  0.344538  0.431579      119
# style_Duotones               0.760563  0.235808  0.360000      229
# style_HDR                    0.500000  0.478873  0.489209       71
# style_Image_Grain            0.238095  0.434783  0.307692       46
# style_Light_On_White         0.603774  0.864865  0.711111       74
# style_Long_Exposure          0.310345  0.211765  0.251748       85
# style_Macro                  0.422535  0.306122  0.355030       98
# style_Motion_Blur            0.263889  0.387755  0.314050       49
# style_Negative_Image         0.366667  0.600000  0.455172       55
# style_Rule_of_Thirds         0.256410  0.142857  0.183486       70
# style_Shallow_DOF            0.172840  0.318182  0.224000       44
# style_Silhouettes            0.458333  0.771930  0.575163       57
# style_Soft_Focus             0.140351  0.333333  0.197531       24
# style_Vanishing_Point        0.326531  0.780488  0.460432       41
# accuracy: 0.396421845574
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_tuned_fc6_flatten False vw********************
# Balancing dataset!
# style_Complementary_Colors    237
# style_Duotones                588
# style_HDR                      83
# style_Image_Grain             183
# style_Light_On_White          158
# style_Long_Exposure           208
# style_Macro                   459
# style_Motion_Blur             149
# style_Negative_Image          193
# style_Rule_of_Thirds          398
# style_Shallow_DOF             677
# style_Silhouettes             227
# style_Soft_Focus              169
# style_Vanishing_Point         101
# dtype: int64
# ------------------------------------------------------------
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [ True]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:284: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [0].
#   index=label_cols)
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.568627  0.263636  0.360248      110
# style_Duotones               0.809524  0.210744  0.334426      242
# style_HDR                    0.625000  0.211268  0.315789       71
# style_Image_Grain            0.351351  0.361111  0.356164       36
# style_Light_On_White         0.471831  0.893333  0.617512       75
# style_Long_Exposure          0.367647  0.312500  0.337838       80
# style_Macro                  0.457627  0.278351  0.346154       97
# style_Motion_Blur            0.268657  0.367347  0.310345       49
# style_Negative_Image         0.388889  0.583333  0.466667       60
# style_Rule_of_Thirds         0.322581  0.281690  0.300752       71
# style_Shallow_DOF            0.148148  0.255319  0.187500       47
# style_Silhouettes            0.380952  0.800000  0.516129       60
# style_Soft_Focus             0.157143  0.379310  0.222222       29
# style_Vanishing_Point        0.263566  0.809524  0.397661       42
# accuracy: 0.378858746492
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************gbvs_saliency False vw********************
# Balancing dataset!
# style_Complementary_Colors    236
# style_Duotones                587
# style_HDR                      83
# style_Image_Grain             182
# style_Light_On_White          157
# style_Long_Exposure           208
# style_Macro                   457
# style_Motion_Blur             149
# style_Negative_Image          193
# style_Rule_of_Thirds          398
# style_Shallow_DOF             675
# style_Silhouettes             227
# style_Soft_Focus              168
# style_Vanishing_Point         101
# dtype: int64
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.000000  0.000000  0.000000      111
# style_Duotones               0.203390  0.051064  0.081633      235
# style_HDR                    0.050000  0.070423  0.058480       71
# style_Image_Grain            0.016667  0.022222  0.019048       45
# style_Light_On_White         0.143939  0.243590  0.180952       78
# style_Long_Exposure          0.078431  0.048780  0.060150       82
# style_Macro                  0.096774  0.029703  0.045455      101
# style_Motion_Blur            0.036585  0.063830  0.046512       47
# style_Negative_Image         0.072917  0.132075  0.093960       53
# style_Rule_of_Thirds         0.096774  0.157895  0.120000       76
# style_Shallow_DOF            0.087719  0.113636  0.099010       44
# style_Silhouettes            0.075269  0.125000  0.093960       56
# style_Soft_Focus             0.028571  0.058824  0.038462       34
# style_Vanishing_Point        0.102564  0.195122  0.134454       41
# accuracy: 0.0819366852886
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************gist_256 False vw********************
# Balancing dataset!
# style_Complementary_Colors    237
# style_Duotones                589
# style_HDR                      83
# style_Image_Grain             183
# style_Light_On_White          158
# style_Long_Exposure           208
# style_Macro                   459
# style_Motion_Blur             149
# style_Negative_Image          193
# style_Rule_of_Thirds          398
# style_Shallow_DOF             677
# style_Silhouettes             227
# style_Soft_Focus              169
# style_Vanishing_Point         102
# dtype: int64
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.294118  0.219298  0.251256      114
# style_Duotones               0.368421  0.059829  0.102941      234
# style_HDR                    0.238095  0.281690  0.258065       71
# style_Image_Grain            0.012195  0.025000  0.016393       40
# style_Light_On_White         0.412587  0.786667  0.541284       75
# style_Long_Exposure          0.203390  0.137931  0.164384       87
# style_Macro                  0.200000  0.212766  0.206186       94
# style_Motion_Blur            0.130952  0.244444  0.170543       45
# style_Negative_Image         0.133333  0.245614  0.172840       57
# style_Rule_of_Thirds         0.117647  0.026316  0.043011       76
# style_Shallow_DOF            0.031250  0.022727  0.026316       44
# style_Silhouettes            0.171171  0.327586  0.224852       58
# style_Soft_Focus             0.047619  0.071429  0.057143       28
# style_Vanishing_Point        0.097561  0.195122  0.130081       41
# accuracy: 0.195488721805
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************lab_hist  vw********************
# Balancing dataset!
# style_Complementary_Colors    235
# style_Duotones                586
# style_HDR                      83
# style_Image_Grain             182
# style_Light_On_White          157
# style_Long_Exposure           207
# style_Macro                   456
# style_Motion_Blur             149
# style_Negative_Image          192
# style_Rule_of_Thirds          397
# style_Shallow_DOF             673
# style_Silhouettes             223
# style_Soft_Focus              168
# style_Vanishing_Point         101
# dtype: int64
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.447059  0.333333  0.381910      114
# style_Duotones               0.603093  0.493671  0.542923      237
# style_HDR                    0.231579  0.309859  0.265060       71
# style_Image_Grain            0.093750  0.150000  0.115385       40
# style_Light_On_White         0.465839  0.974026  0.630252       77
# style_Long_Exposure          0.281553  0.318681  0.298969       91
# style_Macro                  0.187500  0.104651  0.134328       86
# style_Motion_Blur            0.181818  0.076923  0.108108       52
# style_Negative_Image         0.311475  0.327586  0.319328       58
# style_Rule_of_Thirds         0.138889  0.060976  0.084746       82
# style_Shallow_DOF            0.233333  0.142857  0.177215       49
# style_Silhouettes            0.202128  0.339286  0.253333       56
# style_Soft_Focus             0.121951  0.161290  0.138889       31
# style_Vanishing_Point        0.163265  0.205128  0.181818       39
# accuracy: 0.335180055402
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************mc_bit False vw********************
# Balancing dataset!
# style_Complementary_Colors    237
# style_Duotones                585
# style_HDR                      82
# style_Image_Grain             181
# style_Light_On_White          157
# style_Long_Exposure           208
# style_Macro                   455
# style_Motion_Blur             148
# style_Negative_Image          191
# style_Rule_of_Thirds          395
# style_Shallow_DOF             674
# style_Silhouettes             226
# style_Soft_Focus              169
# style_Vanishing_Point         102
# dtype: int64
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.423077  0.096491  0.157143      114
# style_Duotones               0.795918  0.166667  0.275618      234
# style_HDR                    0.641509  0.485714  0.552846       70
# style_Image_Grain            0.318841  0.500000  0.389381       44
# style_Light_On_White         0.604396  0.753425  0.670732       73
# style_Long_Exposure          0.545455  0.307692  0.393443       78
# style_Macro                  0.371212  0.500000  0.426087       98
# style_Motion_Blur            0.227273  0.510204  0.314465       49
# style_Negative_Image         0.360465  0.500000  0.418919       62
# style_Rule_of_Thirds         0.205128  0.111111  0.144144       72
# style_Shallow_DOF            0.108108  0.210526  0.142857       38
# style_Silhouettes            0.593750  0.644068  0.617886       59
# style_Soft_Focus             0.236842  0.300000  0.264706       30
# style_Vanishing_Point        0.201058  0.883721  0.327586       43
# accuracy: 0.367481203008
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************random********************
# Balancing dataset!
# style_Complementary_Colors    237
# style_Duotones                589
# style_HDR                      83
# style_Image_Grain             183
# style_Light_On_White          158
# style_Long_Exposure           208
# style_Macro                   459
# style_Motion_Blur             149
# style_Negative_Image          193
# style_Rule_of_Thirds          398
# style_Shallow_DOF             677
# style_Silhouettes             227
# style_Soft_Focus              169
# style_Vanishing_Point         102
# dtype: int64
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.070588  0.047619  0.056872      126
# style_Duotones               0.234568  0.084444  0.124183      225
# style_HDR                    0.051282  0.056338  0.053691       71
# style_Image_Grain            0.044776  0.071429  0.055046       42
# style_Light_On_White         0.058824  0.048780  0.053333       82
# style_Long_Exposure          0.054795  0.049383  0.051948       81
# style_Macro                  0.039474  0.031579  0.035088       95
# style_Motion_Blur            0.034483  0.060000  0.043796       50
# style_Negative_Image         0.047619  0.051724  0.049587       58
# style_Rule_of_Thirds         0.109756  0.128571  0.118421       70
# style_Shallow_DOF            0.035294  0.075000  0.048000       40
# style_Silhouettes            0.032787  0.036364  0.034483       55
# style_Soft_Focus             0.025000  0.076923  0.037736       26
# style_Vanishing_Point        0.025641  0.046512  0.033058       43
# accuracy: 0.062969924812
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])

# %%
fig = vislab.dataset_viz.plot_conditional_occurrence(
    mc_metrics['feat_metrics']['decaf_fc6 False vw']['conf_df_n'],
    sort_by_prior=False
)

# %%
ap_df = mc_metrics['ap_df'].copy()
ap_df = ap_df[sorted(ap_df.columns)]

ap_df['Murray-CVPR-2012'] = 0
ap_df['Murray-CVPR-2012'].iloc[:-1] = [
    .44, .51, .64, .74, .73, .43, .50, .40, .69, .30, .48, .72, .39, .57]
ap_df['Murray-CVPR-2012'].iloc[-1] = ap_df['Murray-CVPR-2012'].iloc[:-1].mean()

# %%
ap_df
# Out:
#                            decaf_fc6 False vw decaf_fc6_flatten False vw  \
# style_Complementary_Colors           0.564939                  0.3617455
# style_Duotones                      0.7293772                  0.4021643
# style_HDR                           0.5711236                  0.5258823
# style_Image_Grain                   0.5494825                  0.5288635
# style_Light_On_White                0.9263643                  0.7860433
# style_Long_Exposure                 0.4249405                  0.2275141
# style_Macro                         0.4785662                  0.3285489
# style_Motion_Blur                   0.4363031                  0.3144424
# style_Negative_Image                0.6729635                  0.4339564
# style_Rule_of_Thirds                 0.299815                  0.2450106
# style_Shallow_DOF                   0.6378587                  0.5156987
# style_Silhouettes                   0.7866216                  0.5747714
# style_Soft_Focus                    0.3417942                  0.1857079
# style_Vanishing_Point               0.6699527                  0.5033235
# _mean                               0.5778645                  0.4238338
#
#                            decaf_tuned_fc6 False vw  \
# style_Complementary_Colors                0.5030691
# style_Duotones                            0.6999282
# style_HDR                                  0.522515
# style_Image_Grain                         0.5887111
# style_Light_On_White                      0.8603792
# style_Long_Exposure                       0.3561818
# style_Macro                               0.5259368
# style_Motion_Blur                         0.5045284
# style_Negative_Image                      0.6120895
# style_Rule_of_Thirds                      0.3039119
# style_Shallow_DOF                         0.6553198
# style_Silhouettes                         0.7965229
# style_Soft_Focus                          0.3361018
# style_Vanishing_Point                     0.6119626
# _mean                                     0.5626541
#
#                            decaf_tuned_fc6_flatten False vw  \
# style_Complementary_Colors                        0.3786172
# style_Duotones                                    0.3902803
# style_HDR                                         0.5424831
# style_Image_Grain                                 0.5451742
# style_Light_On_White                              0.8142573
# style_Long_Exposure                               0.2010326
# style_Macro                                       0.3692743
# style_Motion_Blur                                 0.3080508
# style_Negative_Image                              0.4090215
# style_Rule_of_Thirds                              0.2260468
# style_Shallow_DOF                                 0.4752892
# style_Silhouettes                                 0.5658779
# style_Soft_Focus                                  0.2027378
# style_Vanishing_Point                             0.4095743
# _mean                                             0.4169798
#
#                            gbvs_saliency False vw gist_256 False vw  \
# style_Complementary_Colors              0.1156515         0.2681854
# style_Duotones                          0.2280559         0.2680033
# style_HDR                                0.102748         0.1249076
# style_Image_Grain                       0.1077747         0.1104732
# style_Light_On_White                    0.2133543         0.6963491
# style_Long_Exposure                     0.1436824         0.1317226
# style_Macro                              0.148444         0.2948252
# style_Motion_Blur                        0.107628         0.0955145
# style_Negative_Image                    0.1223819         0.2090929
# style_Rule_of_Thirds                    0.2210552         0.1660022
# style_Shallow_DOF                       0.2368395         0.2508895
# style_Silhouettes                       0.1578774         0.2065784
# style_Soft_Focus                        0.1001462         0.1063841
# style_Vanishing_Point                   0.1455149         0.1141389
# _mean                                   0.1536539         0.2173619
#
#                            lab_hist  vw mc_bit False vw      random  \
# style_Complementary_Colors    0.2882853       0.2859412   0.1339856
# style_Duotones                0.5652728       0.5693072   0.2205204
# style_HDR                     0.2006592       0.6530367  0.08502571
# style_Image_Grain             0.2107738       0.7241903   0.1178171
# style_Light_On_White          0.8893095       0.8238458   0.1031095
# style_Long_Exposure           0.2722267        0.491789    0.104739
# style_Macro                   0.2321003       0.4436068   0.1408828
# style_Motion_Blur             0.1279356       0.5129939  0.09258187
# style_Negative_Image          0.3016068       0.5031125  0.09816009
# style_Rule_of_Thirds          0.1824609       0.2515069   0.1535799
# style_Shallow_DOF             0.3755199       0.5984651   0.2318041
# style_Silhouettes             0.2761445       0.8021835  0.09296613
# style_Soft_Focus              0.1324649       0.2963617   0.1034838
# style_Vanishing_Point         0.1150055       0.6789977  0.08431847
# _mean                         0.2978404       0.5453813   0.1259267
#
#                             Murray-CVPR-2012
# style_Complementary_Colors          0.440000
# style_Duotones                      0.510000
# style_HDR                           0.640000
# style_Image_Grain                   0.740000
# style_Light_On_White                0.730000
# style_Long_Exposure                 0.430000
# style_Macro                         0.500000
# style_Motion_Blur                   0.400000
# style_Negative_Image                0.690000
# style_Rule_of_Thirds                0.300000
# style_Shallow_DOF                   0.480000
# style_Silhouettes                   0.720000
# style_Soft_Focus                    0.390000
# style_Vanishing_Point               0.570000
# _mean                               0.538571

# %%
fig = vislab.results_viz.plot_df_bar(ap_df)
