# %%
# %load_ext autoreload
# %autoreload 2
import os
import aphrodite.results
import pandas as pd

import vislab
import vislab.datasets
import vislab.results
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
c = vislab.util.get_mongodb_client()['predict']['ava_style_oct22']
if c.find({'features': 'noise'}).count() > 0:
    c.remove({'features': 'noise'})
pd.DataFrame([x for x in c.find()])
# Out:
#                         _id                 data                   features  \
# 0  52677171efd80f8750020095  ava_style_style_ALL                 [lab_hist]
# 1  52687f4043d2db703b9f97e6  ava_style_style_ALL                 [gist_256]
# 2  5268e26a43d2db703b9f97e7  ava_style_style_ALL                   [mc_bit]
# 3  5269dc0c43d2db703b9f9825  ava_style_style_ALL                [decaf_fc6]
# 4  5269f802265138430c54b4d6  ava_style_style_ALL        [decaf_fc6_flatten]
# 5  526edf859622958641aaee55  ava_style_style_ALL            [gbvs_saliency]
# 6  52719c9e9622958641af6842  ava_style_style_ALL          [decaf_tuned_fc6]
# 7  5271e1399622958641af6845  ava_style_style_ALL  [decaf_tuned_fc6_flatten]
# 8  52724df68dc9cfbe92ca2344  ava_style_style_ALL   [fusion_ava_style_oct22]
#
#    num_test  num_train  num_val  \
# 0      2573       8501     2769
# 1      2573       8501     2769
# 2      2573       8501     2769
# 3      2573       8501     2769
# 4      2573       8501     2769
# 5      2573       8501     2769
# 6      2573       8501     2769
# 7      2573       8501     2769
# 8      2573       8501     2769
#
#                                              pred_df quadratic  \
# 0  �cpandas.core.frame\nDataFrame\nq)�qcpandas...
# 1  �cpandas.core.frame\nDataFrame\nq)�qcpandas...     False
# 2  �cpandas.core.frame\nDataFrame\nq)�qcpandas...     False
# 3  �cpandas.core.frame\nDataFrame\nq)�qcpandas...     False
# 4  �cpandas.core.frame\nDataFrame\nq)�qcpandas...     False
# 5                                                NaN     False
# 6                                                NaN     False
# 7                                                NaN     False
# 8                                                NaN      None
#
#                                         results_name  score_test  score_val  \
# 0                                                NaN    0.284286   0.247508
# 1                                                NaN    0.187143   0.184385
# 2                                                NaN    0.434286   0.417647
# 3                                                NaN    0.488571   0.529900
# 4                                                NaN    0.435714   0.823920
# 5  data_ava_style_style_ALL_features_['gbvs_salie...    0.084666   0.181594
# 6  data_ava_style_style_ALL_features_['decaf_tune...    0.417053   0.696795
# 7  data_ava_style_style_ALL_features_['decaf_tune...    0.363299   0.820871
# 8  data_ava_style_style_ALL_features_['fusion_ava...    0.449765   0.756779
#
#   task
# 0  clf
# 1  clf
# 2  clf
# 3  clf
# 4  clf
# 5  clf
# 6  clf
# 7  clf
# 8  clf

# %%
label_df = vislab.datasets.ava.get_style_df()

# %%
df = label_df[[x for x in label_df.columns if not x.startswith('_')]]
M = df.shape[1]
data = []

df_m = pd.DataFrame([
        df.apply(lambda x: [x[i] & x[j] for j in range(M)], raw=True, axis=1).sum(0).astype(float) / df[column].sum()
        for i, column in enumerate(df.columns)
    ],
    index=df.columns
)
df_m
# Out:
#                             style_Complementary_Colors  style_Duotones  \
# style_Complementary_Colors                    1.000000        0.000000
# style_Duotones                                0.000000        1.000000
# style_HDR                                     0.017500        0.012500
# style_Image_Grain                             0.004678        0.116959
# style_Light_On_White                          0.000894        0.023256
# style_Long_Exposure                           0.007919        0.015837
# style_Macro                                   0.019802        0.024202
# style_Motion_Blur                             0.004710        0.045526
# style_Negative_Image                          0.014568        0.031217
# style_Rule_of_Thirds                          0.017881        0.047020
# style_Shallow_DOF                             0.039226        0.053735
# style_Silhouettes                             0.011407        0.024715
# style_Soft_Focus                              0.008141        0.047490
# style_Vanishing_Point                         0.006231        0.048287
#
#                             style_HDR  style_Image_Grain  \
# style_Complementary_Colors   0.007021           0.004012
# style_Duotones               0.003067           0.061350
# style_HDR                    1.000000           0.000000
# style_Image_Grain            0.000000           1.000000
# style_Light_On_White         0.000000           0.004472
# style_Long_Exposure          0.005656           0.004525
# style_Macro                  0.000000           0.002750
# style_Motion_Blur            0.000000           0.014129
# style_Negative_Image         0.000000           0.001041
# style_Rule_of_Thirds         0.003311           0.013245
# style_Shallow_DOF            0.000537           0.013971
# style_Silhouettes            0.000000           0.007605
# style_Soft_Focus             0.000000           0.008141
# style_Vanishing_Point        0.001558           0.009346
#
#                             style_Light_On_White  style_Long_Exposure  \
# style_Complementary_Colors              0.001003             0.007021
# style_Duotones                          0.015951             0.008589
# style_HDR                               0.000000             0.012500
# style_Image_Grain                       0.005848             0.004678
# style_Light_On_White                    1.000000             0.000000
# style_Long_Exposure                     0.000000             1.000000
# style_Macro                             0.008251             0.002200
# style_Motion_Blur                       0.001570             0.045526
# style_Negative_Image                    0.003122             0.000000
# style_Rule_of_Thirds                    0.012583             0.006623
# style_Shallow_DOF                       0.010210             0.001075
# style_Silhouettes                       0.000000             0.006654
# style_Soft_Focus                        0.010855             0.000000
# style_Vanishing_Point                   0.000000             0.003115
#
#                             style_Macro  style_Motion_Blur  \
# style_Complementary_Colors     0.036108           0.003009
# style_Duotones                 0.026994           0.017791
# style_HDR                      0.000000           0.000000
# style_Image_Grain              0.005848           0.010526
# style_Light_On_White           0.013417           0.000894
# style_Long_Exposure            0.004525           0.032805
# style_Macro                    1.000000           0.001650
# style_Motion_Blur              0.004710           1.000000
# style_Negative_Image           0.016649           0.000000
# style_Rule_of_Thirds           0.013245           0.004636
# style_Shallow_DOF              0.087050           0.004299
# style_Silhouettes              0.003802           0.000951
# style_Soft_Focus               0.024423           0.001357
# style_Vanishing_Point          0.000000           0.001558
#
#                             style_Negative_Image  style_Rule_of_Thirds  \
# style_Complementary_Colors              0.014042              0.027081
# style_Duotones                          0.018405              0.043558
# style_HDR                               0.000000              0.012500
# style_Image_Grain                       0.001170              0.023392
# style_Light_On_White                    0.002683              0.016995
# style_Long_Exposure                     0.000000              0.011312
# style_Macro                             0.008801              0.011001
# style_Motion_Blur                       0.000000              0.010989
# style_Negative_Image                    1.000000              0.003122
# style_Rule_of_Thirds                    0.001987              1.000000
# style_Shallow_DOF                       0.013434              0.069855
# style_Silhouettes                       0.000000              0.029468
# style_Soft_Focus                        0.000000              0.029851
# style_Vanishing_Point                   0.003115              0.010903
#
#                             style_Shallow_DOF  style_Silhouettes  \
# style_Complementary_Colors           0.073220           0.012036
# style_Duotones                       0.061350           0.015951
# style_HDR                            0.002500           0.000000
# style_Image_Grain                    0.030409           0.009357
# style_Light_On_White                 0.016995           0.000000
# style_Long_Exposure                  0.002262           0.007919
# style_Macro                          0.089109           0.002200
# style_Motion_Blur                    0.012559           0.001570
# style_Negative_Image                 0.026015           0.000000
# style_Rule_of_Thirds                 0.086093           0.020530
# style_Shallow_DOF                    1.000000           0.001075
# style_Silhouettes                    0.001901           1.000000
# style_Soft_Focus                     0.044776           0.010855
# style_Vanishing_Point                0.010903           0.001558
#
#                             style_Soft_Focus  style_Vanishing_Point
# style_Complementary_Colors          0.006018               0.004012
# style_Duotones                      0.021472               0.019018
# style_HDR                           0.000000               0.002500
# style_Image_Grain                   0.007018               0.007018
# style_Light_On_White                0.007156               0.000000
# style_Long_Exposure                 0.000000               0.002262
# style_Macro                         0.009901               0.000000
# style_Motion_Blur                   0.001570               0.001570
# style_Negative_Image                0.000000               0.002081
# style_Rule_of_Thirds                0.014570               0.004636
# style_Shallow_DOF                   0.017732               0.003761
# style_Silhouettes                   0.007605               0.000951
# style_Soft_Focus                    1.000000               0.002714
# style_Vanishing_Point               0.003115               1.000000

# %%
fig = vislab.dataset_viz.plot_occurrence(df_m)

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_oct22', os.path.expanduser('~/work/aphrodite/data/results2'),
    multiclass=True, force=True)
pred_prefix = 'pred'
print preds_panel.minor_axis
preds_panel
# Out:
# Results in collection ava_style_oct22: 9
# Index([u'decaf_fc6 False vw', u'decaf_fc6_flatten False vw', u'decaf_tuned_fc6 False vw', u'decaf_tuned_fc6_flatten False vw', u'fusion_ava_style_oct22 None vw', u'gbvs_saliency False vw', u'gist_256 False vw', u'lab_hist  vw', u'mc_bit False vw'], dtype='object')
# <class 'pandas.core.panel.Panel'>
# Dimensions: 31 (items) x 13843 (major_axis) x 9 (minor_axis)
# Items axis: importance to style_Vanishing_Point
# Major_axis axis: 1187 to 97008
# Minor_axis axis: decaf_fc6 False vw to mc_bit False vw

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=preds_panel.minor_axis.tolist() + ['random'],
    balanced=True, with_plot=False, with_print=True)
# Out:
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_fc6 False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.676471  0.393162  0.497297      117
# style_Duotones               0.772152  0.258475  0.387302      236
# style_HDR                    0.536232  0.521127  0.528571       71
# style_Image_Grain            0.193182  0.435897  0.267717       39
# style_Light_On_White         0.559322  0.891892  0.687500       74
# style_Long_Exposure          0.448276  0.320988  0.374101       81
# style_Macro                  0.404762  0.207317  0.274194       82
# style_Motion_Blur            0.391892  0.580000  0.467742       50
# style_Negative_Image         0.466667  0.573770  0.514706       61
# style_Rule_of_Thirds         0.222222  0.108108  0.145455       74
# style_Shallow_DOF            0.206522  0.463415  0.285714       41
# style_Silhouettes            0.443299  0.741379  0.554839       58
# style_Soft_Focus             0.205882  0.466667  0.285714       30
# style_Vanishing_Point        0.340659  0.756098  0.469697       41
# accuracy: 0.425592417062
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_fc6_flatten False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.446429  0.416667  0.431034      120
# style_Duotones               0.719101  0.268908  0.391437      238
# style_HDR                    0.789474  0.211268  0.333333       71
# style_Image_Grain            0.294118  0.232558  0.259740       43
# style_Light_On_White         0.528926  0.901408  0.666667       71
# style_Long_Exposure          0.357143  0.297619  0.324675       84
# style_Macro                  0.511628  0.236559  0.323529       93
# style_Motion_Blur            0.285714  0.307692  0.296296       52
# style_Negative_Image         0.392157  0.677966  0.496894       59
# style_Rule_of_Thirds         0.235294  0.169014  0.196721       71
# style_Shallow_DOF            0.128571  0.236842  0.166667       38
# style_Silhouettes            0.405660  0.826923  0.544304       52
# style_Soft_Focus             0.222222  0.368421  0.277228       38
# style_Vanishing_Point        0.220588  0.714286  0.337079       42
# accuracy: 0.386194029851
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_tuned_fc6 False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.567164  0.358491  0.439306      106
# style_Duotones               0.775000  0.275556  0.406557      225
# style_HDR                    0.441558  0.478873  0.459459       71
# style_Image_Grain            0.207792  0.355556  0.262295       45
# style_Light_On_White         0.584071  0.857143  0.694737       77
# style_Long_Exposure          0.393939  0.309524  0.346667       84
# style_Macro                  0.452830  0.237624  0.311688      101
# style_Motion_Blur            0.265823  0.403846  0.320611       52
# style_Negative_Image         0.431818  0.622951  0.510067       61
# style_Rule_of_Thirds         0.395833  0.253333  0.308943       75
# style_Shallow_DOF            0.222222  0.347826  0.271186       46
# style_Silhouettes            0.426966  0.703704  0.531469       54
# style_Soft_Focus             0.180328  0.423077  0.252874       26
# style_Vanishing_Point        0.360825  0.795455  0.496454       44
# accuracy: 0.416119962512
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_tuned_fc6_flatten False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.531250  0.293103  0.377778      116
# style_Duotones               0.761194  0.212500  0.332248      240
# style_HDR                    0.681818  0.211268  0.322581       71
# style_Image_Grain            0.307692  0.285714  0.296296       42
# style_Light_On_White         0.511811  0.878378  0.646766       74
# style_Long_Exposure          0.416667  0.294118  0.344828       85
# style_Macro                  0.370370  0.215054  0.272109       93
# style_Motion_Blur            0.223684  0.354167  0.274194       48
# style_Negative_Image         0.340426  0.542373  0.418301       59
# style_Rule_of_Thirds         0.340000  0.226667  0.272000       75
# style_Shallow_DOF            0.137500  0.244444  0.176000       45
# style_Silhouettes            0.297710  0.764706  0.428571       51
# style_Soft_Focus             0.186667  0.482759  0.269231       29
# style_Vanishing_Point        0.272727  0.837209  0.411429       43
# accuracy: 0.362278244631
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************fusion_ava_style_oct22 None vw********************
# ------------------------------------------------------------
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [ True]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:280: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [0].
#   y_true, y_pred)
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.534247  0.336207  0.412698      116
# style_Duotones               0.878788  0.255507  0.395904      227
# style_HDR                    0.637931  0.521127  0.573643       71
# style_Image_Grain            0.273973  0.454545  0.341880       44
# style_Light_On_White         0.647059  0.857143  0.737430       77
# style_Long_Exposure          0.481481  0.305882  0.374101       85
# style_Macro                  0.383721  0.340206  0.360656       97
# style_Motion_Blur            0.287671  0.437500  0.347107       48
# style_Negative_Image         0.473118  0.800000  0.594595       55
# style_Rule_of_Thirds         0.318841  0.297297  0.307692       74
# style_Shallow_DOF            0.148936  0.350000  0.208955       40
# style_Silhouettes            0.584416  0.750000  0.656934       60
# style_Soft_Focus             0.298246  0.472222  0.365591       36
# style_Vanishing_Point        0.387755  0.883721  0.539007       43
# accuracy: 0.44734389562
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************gbvs_saliency False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.000000  0.000000  0.000000      118
# style_Duotones               0.203704  0.048246  0.078014      228
# style_HDR                    0.052632  0.070423  0.060241       71
# style_Image_Grain            0.054054  0.095238  0.068966       42
# style_Light_On_White         0.167939  0.293333  0.213592       75
# style_Long_Exposure          0.096154  0.057471  0.071942       87
# style_Macro                  0.088235  0.029412  0.044118      102
# style_Motion_Blur            0.038462  0.062500  0.047619       48
# style_Negative_Image         0.063830  0.100000  0.077922       60
# style_Rule_of_Thirds         0.101695  0.176471  0.129032       68
# style_Shallow_DOF            0.048387  0.065217  0.055556       46
# style_Silhouettes            0.062500  0.105263  0.078431       57
# style_Soft_Focus             0.043478  0.096774  0.060000       31
# style_Vanishing_Point        0.094118  0.195122  0.126984       41
# accuracy: 0.084729981378
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************gist_256 False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.253731  0.150442  0.188889      113
# style_Duotones               0.386364  0.071730  0.120996      237
# style_HDR                    0.217391  0.281690  0.245399       71
# style_Image_Grain            0.023810  0.040000  0.029851       50
# style_Light_On_White         0.416667  0.779221  0.542986       77
# style_Long_Exposure          0.121951  0.112360  0.116959       89
# style_Macro                  0.148936  0.140000  0.144330      100
# style_Motion_Blur            0.144737  0.244444  0.181818       45
# style_Negative_Image         0.128440  0.222222  0.162791       63
# style_Rule_of_Thirds         0.080000  0.025974  0.039216       77
# style_Shallow_DOF            0.027027  0.028571  0.027778       35
# style_Silhouettes            0.190476  0.333333  0.242424       60
# style_Soft_Focus             0.025641  0.040000  0.031250       25
# style_Vanishing_Point        0.073171  0.157895  0.100000       38
# accuracy: 0.180555555556
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************lab_hist  vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.443038  0.307018  0.362694      114
# style_Duotones               0.651934  0.504274  0.568675      234
# style_HDR                    0.250000  0.309859  0.276730       71
# style_Image_Grain            0.107692  0.148936  0.125000       47
# style_Light_On_White         0.453947  0.985714  0.621622       70
# style_Long_Exposure          0.294737  0.314607  0.304348       89
# style_Macro                  0.162791  0.081395  0.108527       86
# style_Motion_Blur            0.142857  0.081633  0.103896       49
# style_Negative_Image         0.333333  0.415385  0.369863       65
# style_Rule_of_Thirds         0.161290  0.064935  0.092593       77
# style_Shallow_DOF            0.125000  0.086957  0.102564       46
# style_Silhouettes            0.250000  0.375000  0.300000       56
# style_Soft_Focus             0.088235  0.193548  0.121212       31
# style_Vanishing_Point        0.125000  0.150000  0.136364       40
# accuracy: 0.333953488372
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************mc_bit False vw********************
# ------------------------------------------------------------
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:280: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [10].
#   y_true, y_pred)
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.366667  0.091667  0.146667      120
# style_Duotones               0.738095  0.134199  0.227106      231
# style_HDR                    0.641509  0.485714  0.552846       70
# style_Image_Grain            0.373333  0.636364  0.470588       44
# style_Light_On_White         0.603960  0.762500  0.674033       80
# style_Long_Exposure          0.536585  0.239130  0.330827       92
# style_Macro                  0.272727  0.351064  0.306977       94
# style_Motion_Blur            0.203704  0.458333  0.282051       48
# style_Negative_Image         0.392857  0.559322  0.461538       59
# style_Rule_of_Thirds         0.250000  0.154930  0.191304       71
# style_Shallow_DOF            0.166667  0.368421  0.229508       38
# style_Silhouettes            0.620690  0.666667  0.642857       54
# style_Soft_Focus             0.187500  0.250000  0.214286       24
# style_Vanishing_Point        0.192708  0.925000  0.318966       40
# accuracy: 0.355868544601
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************random********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.112360  0.086957  0.098039      115
# style_Duotones               0.223684  0.072650  0.109677      234
# style_HDR                    0.086957  0.084507  0.085714       71
# style_Image_Grain            0.074627  0.119048  0.091743       42
# style_Light_On_White         0.053333  0.054054  0.053691       74
# style_Long_Exposure          0.050000  0.036585  0.042254       82
# style_Macro                  0.068966  0.065934  0.067416       91
# style_Motion_Blur            0.013699  0.022222  0.016949       45
# style_Negative_Image         0.096386  0.133333  0.111888       60
# style_Rule_of_Thirds         0.027778  0.029412  0.028571       68
# style_Shallow_DOF            0.000000  0.000000  0.000000       41
# style_Silhouettes            0.044944  0.065574  0.053333       61
# style_Soft_Focus             0.038462  0.093750  0.054545       32
# style_Vanishing_Point        0.014085  0.024390  0.017857       41
# accuracy: 0.0662251655629

# %%
fig = vislab.dataset_viz.plot_conditional_occurrence(
    mc_metrics['feat_metrics']['decaf_fc6 False vw']['conf_df_n'],
    sort_by_prior=False
)

# %%
ap_df = mc_metrics['ap_df'].copy()
ap_df = ap_df[sorted(ap_df.columns)]

ap_df['Murray-CVPR-2012'] = 0
ap_df['Murray-CVPR-2012'].iloc[:-1] = [
    .44, .51, .64, .74, .73, .43, .50, .40, .69, .30, .48, .72, .39, .57]
ap_df['Murray-CVPR-2012'].iloc[-1] = ap_df['Murray-CVPR-2012'].iloc[:-1].mean()

# %%
ap_df
# Out:
#                            decaf_fc6 False vw decaf_fc6_flatten False vw  \
# style_Complementary_Colors          0.6211382                  0.4050502
# style_Duotones                      0.7437157                  0.3887592
# style_HDR                           0.5982294                  0.5036383
# style_Image_Grain                   0.5748732                  0.5112717
# style_Light_On_White                0.8921758                  0.7682353
# style_Long_Exposure                 0.4008606                  0.2000928
# style_Macro                          0.475182                   0.352307
# style_Motion_Blur                   0.5165882                  0.2914459
# style_Negative_Image                0.5554986                  0.4782896
# style_Rule_of_Thirds                0.3167302                  0.2655599
# style_Shallow_DOF                   0.6843224                  0.4874635
# style_Silhouettes                   0.8566712                  0.6027647
# style_Soft_Focus                    0.3494747                  0.2426235
# style_Vanishing_Point                0.699022                  0.4824038
# _mean                               0.5917487                  0.4271361
#
#                            decaf_tuned_fc6 False vw  \
# style_Complementary_Colors                0.5154938
# style_Duotones                            0.6898746
# style_HDR                                 0.5049583
# style_Image_Grain                         0.5568195
# style_Light_On_White                      0.8892144
# style_Long_Exposure                       0.3958949
# style_Macro                               0.5235831
# style_Motion_Blur                           0.40739
# style_Negative_Image                      0.5075607
# style_Rule_of_Thirds                      0.3238382
# style_Shallow_DOF                         0.6314746
# style_Silhouettes                         0.7868109
# style_Soft_Focus                          0.2932381
# style_Vanishing_Point                     0.6502109
# _mean                                     0.5483116
#
#                            decaf_tuned_fc6_flatten False vw  \
# style_Complementary_Colors                        0.4070169
# style_Duotones                                    0.3845286
# style_HDR                                         0.5373122
# style_Image_Grain                                 0.5511326
# style_Light_On_White                              0.7757477
# style_Long_Exposure                               0.2369791
# style_Macro                                       0.3213329
# style_Motion_Blur                                 0.3192446
# style_Negative_Image                              0.3348116
# style_Rule_of_Thirds                              0.2473028
# style_Shallow_DOF                                 0.4926406
# style_Silhouettes                                 0.5211472
# style_Soft_Focus                                  0.2219749
# style_Vanishing_Point                             0.3996313
# _mean                                             0.4107716
#
#                            fusion_ava_style_oct22 None vw  \
# style_Complementary_Colors                       0.496849
# style_Duotones                                    0.67665
# style_HDR                                       0.6868687
# style_Image_Grain                               0.6478373
# style_Light_On_White                            0.8560058
# style_Long_Exposure                             0.4673444
# style_Macro                                     0.4815137
# style_Motion_Blur                               0.4578592
# style_Negative_Image                            0.6246604
# style_Rule_of_Thirds                            0.3708029
# style_Shallow_DOF                               0.6237929
# style_Silhouettes                                0.842203
# style_Soft_Focus                                0.3589144
# style_Vanishing_Point                           0.7467429
# _mean                                           0.5955746
#
#                            gbvs_saliency False vw gist_256 False vw  \
# style_Complementary_Colors              0.1125282         0.2390141
# style_Duotones                          0.2348814         0.2584748
# style_HDR                              0.09987049         0.1261098
# style_Image_Grain                        0.112201         0.1116457
# style_Light_On_White                    0.1831719         0.7012673
# style_Long_Exposure                     0.1270515         0.1389667
# style_Macro                             0.1545326          0.238954
# style_Motion_Blur                       0.1145572         0.1215065
# style_Negative_Image                    0.1261571         0.1760233
# style_Rule_of_Thirds                    0.2290782         0.1667675
# style_Shallow_DOF                       0.2299649         0.2775961
# style_Silhouettes                       0.1246769         0.2332399
# style_Soft_Focus                        0.1007078         0.1078582
# style_Vanishing_Point                   0.1637242         0.1168859
# _mean                                    0.150936         0.2153078
#
#                            lab_hist  vw mc_bit False vw      random  \
# style_Complementary_Colors    0.3168973       0.3179067   0.1145152
# style_Duotones                0.5780096       0.6240607   0.2382315
# style_HDR                       0.20023       0.6340626  0.09669249
# style_Image_Grain             0.2118243       0.7454211   0.1169746
# style_Light_On_White          0.9244232       0.7816035  0.09827191
# style_Long_Exposure           0.2814205       0.4695828   0.1033127
# style_Macro                    0.244478       0.3713565   0.1471085
# style_Motion_Blur             0.1329838       0.4366714  0.09936345
# style_Negative_Image          0.2555414       0.5323945  0.09602108
# style_Rule_of_Thirds          0.2086969       0.2562186    0.155704
# style_Shallow_DOF             0.3237923       0.5986007   0.2054494
# style_Silhouettes             0.2838109       0.8640415   0.1151476
# style_Soft_Focus               0.141035       0.3287371   0.0967055
# style_Vanishing_Point         0.1329768       0.6669271   0.1052145
# _mean                           0.30258       0.5448275   0.1277652
#
#                             Murray-CVPR-2012
# style_Complementary_Colors          0.440000
# style_Duotones                      0.510000
# style_HDR                           0.640000
# style_Image_Grain                   0.740000
# style_Light_On_White                0.730000
# style_Long_Exposure                 0.430000
# style_Macro                         0.500000
# style_Motion_Blur                   0.400000
# style_Negative_Image                0.690000
# style_Rule_of_Thirds                0.300000
# style_Shallow_DOF                   0.480000
# style_Silhouettes                   0.720000
# style_Soft_Focus                    0.390000
# style_Vanishing_Point               0.570000
# _mean                               0.538571

# %%
fig = vislab.results_viz.plot_df_bar(ap_df)
