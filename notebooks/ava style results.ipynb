# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import pandas as pd

import vislab
import vislab.datasets
import vislab.results

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_oct21', '/Users/sergeyk/work/aphrodite/data/results2', force=False)
preds_panel
# Out:
# Results in collection ava_style_oct21: 14
# <class 'pandas.core.panel.Panel'>
# Dimensions: 14 (items) x 13994 (major_axis) x 3 (minor_axis)
# Items axis: clf ava_style_style_Complementary_Colors to clf ava_style_style_Vanishing_Point
# Major_axis axis: 1187 to 97009
# Minor_axis axis: lab_hist  vw to split

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_split_oct17', '/Users/sergeyk/work/aphrodite/data/results2', force=False)
preds_panel
# Out:
# Loaded from cache: 42 records
# <class 'pandas.core.panel.Panel'>
# Dimensions: 14 (items) x 14079 (major_axis) x 5 (minor_axis)
# Items axis: clf ava_style_style_Complementary_Colors to clf ava_style_style_Vanishing_Point
# Major_axis axis: 1187 to 97009
# Minor_axis axis: decaf_fc6  vw to split

# %%
pred_prefix = 'clf ava_style'

# %% [markdown]
# ### Decaf FC6 results

# %%
label_df = vislab.datasets.ava.get_style_df()
test_df = label_df[label_df['_split'] == 'test']
del test_df['_split']
test_df.astype(int).sum()
# Out:
# style_Complementary_Colors    237
# style_Duotones                589
# style_HDR                      83
# style_Image_Grain             183
# style_Light_On_White          158
# style_Long_Exposure           208
# style_Macro                   459
# style_Motion_Blur             149
# style_Negative_Image          193
# style_Rule_of_Thirds          398
# style_Shallow_DOF             677
# style_Silhouettes             227
# style_Soft_Focus              169
# style_Vanishing_Point         102
# dtype: int64

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=['lab_hist  vw', 'decaf_fc6  vw', '_random'],
    balanced=True,
    with_plot=True, with_print=True)
# Out:
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.283
# 2     0.410
# 3     0.527
# 4     0.596
# 5     0.653
# 6     0.706
# 7     0.777
# 8     0.821
# 9     0.869
# 10    0.910
# 11    0.937
# 12    0.981
# 13    0.993
# 14    1.000
# dtype: float64
#                             precision  recall  f1-score  support
# style_Complementary_Colors   0.313725    0.32  0.316832       50
# style_Duotones               0.317073    0.26  0.285714       50
# style_HDR                    0.275862    0.16  0.202532       50
# style_Image_Grain            0.187500    0.12  0.146341       50
# style_Light_On_White         0.526316    1.00  0.689655       50
# style_Long_Exposure          0.270833    0.26  0.265306       50
# style_Macro                  0.137931    0.08  0.101266       50
# style_Motion_Blur            0.095238    0.04  0.056338       50
# style_Negative_Image         0.389831    0.46  0.422018       50
# style_Rule_of_Thirds         0.125000    0.04  0.060606       50
# style_Shallow_DOF            0.000000    0.00  0.000000       50
# style_Silhouettes            0.280899    0.50  0.359712       50
# style_Soft_Focus             0.174603    0.44  0.250000       50
# style_Vanishing_Point        0.225806    0.28  0.250000       50
# accuracy: 0.282857142857
#
# ------------------------------------------------------------
# /Users/sergeyk/work/vislab/vislab/results.py:258: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [10].
#   y_true, y_pred)
# /Users/sergeyk/work/vislab/vislab/results.py:71: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.439
# 2     0.601
# 3     0.719
# 4     0.786
# 5     0.839
# 6     0.891
# 7     0.931
# 8     0.943
# 9     0.964
# 10    0.974
# 11    0.983
# 12    0.993
# 13    0.999
# 14    1.000
# dtype: float64
#                             precision  recall  f1-score  support
# style_Complementary_Colors   0.588235    0.20  0.298507       50
# style_Duotones               0.650000    0.26  0.371429       50
# style_HDR                    0.457627    0.54  0.495413       50
# style_Image_Grain            0.435897    0.34  0.382022       50
# style_Light_On_White         0.780000    0.78  0.780000       50
# style_Long_Exposure          0.300000    0.36  0.327273       50
# style_Macro                  0.327586    0.38  0.351852       50
# style_Motion_Blur            0.311475    0.38  0.342342       50
# style_Negative_Image         0.515625    0.66  0.578947       50
# style_Rule_of_Thirds         0.214286    0.12  0.153846       50
# style_Shallow_DOF            0.250000    0.18  0.209302       50
# style_Silhouettes            0.614035    0.70  0.654206       50
# style_Soft_Focus             0.388889    0.42  0.403846       50
# style_Vanishing_Point        0.422680    0.82  0.557823       50
# accuracy: 0.438571428571
#
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.077
# 2     0.149
# 3     0.237
# 4     0.283
# 5     0.350
# 6     0.416
# 7     0.479
# 8     0.544
# 9     0.613
# 10    0.693
# 11    0.773
# 12    0.841
# 13    0.917
# 14    1.000
# dtype: float64
#                             precision  recall  f1-score  support
# style_Complementary_Colors   0.035088    0.04  0.037383       50
# style_Duotones               0.037736    0.04  0.038835       50
# style_HDR                    0.078125    0.10  0.087719       50
# style_Image_Grain            0.022222    0.02  0.021053       50
# style_Light_On_White         0.142857    0.14  0.141414       50
# style_Long_Exposure          0.090909    0.08  0.085106       50
# style_Macro                  0.047619    0.04  0.043478       50
# style_Motion_Blur            0.116279    0.10  0.107527       50
# style_Negative_Image         0.074074    0.08  0.076923       50
# style_Rule_of_Thirds         0.068966    0.08  0.074074       50
# style_Shallow_DOF            0.090909    0.08  0.085106       50
# style_Silhouettes            0.097561    0.08  0.087912       50
# style_Soft_Focus             0.137255    0.14  0.138614       50
# style_Vanishing_Point        0.054545    0.06  0.057143       50
# accuracy: 0.0771428571429

# %%
mc_metrics['ap_df']
# Out:
#                                _random decaf_fc6  vw lab_hist  vw
# style_Complementary_Colors  0.09198403      0.478988    0.2071847
# style_Duotones               0.0729927      0.555009    0.4102992
# style_HDR                   0.08707243       0.53743    0.1776701
# style_Image_Grain            0.1086379     0.4335749    0.1856471
# style_Light_On_White         0.1200147     0.9158559    0.8905281
# style_Long_Exposure          0.1081089     0.2774761    0.2279304
# style_Macro                   0.119901     0.3893883    0.1584447
# style_Motion_Blur            0.1235053     0.3982253    0.1569327
# style_Negative_Image        0.09353759     0.4661569    0.2650764
# style_Rule_of_Thirds         0.1426789     0.2753588      0.16822
# style_Shallow_DOF            0.2027396     0.5318029    0.2368485
# style_Silhouettes           0.09254355     0.8244434    0.3940484
# style_Soft_Focus             0.1285899     0.3724169    0.1967996
# style_Vanishing_Point       0.09744463     0.6657302    0.2150535
# _mean                        0.1135536      0.508704     0.277906

# %%
mc_metrics['ap_df']['Murray-CVPR-2012'] = 0
mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[:-1] = [
    .44, .51, .64, .74, .73, .43, .50, .40, .69, .30, .48, .72, .39, .57]
mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[-1] = mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[:-1].mean()
mc_metrics['ap_df']
# Out:
#                                _random decaf_fc6  vw lab_hist  vw  \
# style_Complementary_Colors  0.09198403      0.478988    0.2071847
# style_Duotones               0.0729927      0.555009    0.4102992
# style_HDR                   0.08707243       0.53743    0.1776701
# style_Image_Grain            0.1086379     0.4335749    0.1856471
# style_Light_On_White         0.1200147     0.9158559    0.8905281
# style_Long_Exposure          0.1081089     0.2774761    0.2279304
# style_Macro                   0.119901     0.3893883    0.1584447
# style_Motion_Blur            0.1235053     0.3982253    0.1569327
# style_Negative_Image        0.09353759     0.4661569    0.2650764
# style_Rule_of_Thirds         0.1426789     0.2753588      0.16822
# style_Shallow_DOF            0.2027396     0.5318029    0.2368485
# style_Silhouettes           0.09254355     0.8244434    0.3940484
# style_Soft_Focus             0.1285899     0.3724169    0.1967996
# style_Vanishing_Point       0.09744463     0.6657302    0.2150535
# _mean                        0.1135536      0.508704     0.277906
#
#                             Murray-CVPR-2012
# style_Complementary_Colors          0.440000
# style_Duotones                      0.510000
# style_HDR                           0.640000
# style_Image_Grain                   0.740000
# style_Light_On_White                0.730000
# style_Long_Exposure                 0.430000
# style_Macro                         0.500000
# style_Motion_Blur                   0.400000
# style_Negative_Image                0.690000
# style_Rule_of_Thirds                0.300000
# style_Shallow_DOF                   0.480000
# style_Silhouettes                   0.720000
# style_Soft_Focus                    0.390000
# style_Vanishing_Point               0.570000
# _mean                               0.538571

# %%
fig = vislab.results_viz.plot_df_bar(mc_metrics['ap_df'])
