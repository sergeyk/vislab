# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import pandas as pd

import vislab
import vislab.datasets
import vislab.results

# %%
c = vislab.util.get_mongodb_client()['predict']['ava_style_oct22']
#df = pd.DataFrame([x for x in c.find()])
if c.find({'features': 'noise'}).count() > 0:
    c.remove({'features': 'noise'})

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_oct22', '/Users/sergeyk/work/aphrodite/data/results2', multiclass=True, force=True)
pred_prefix = 'pred'
print preds_panel.minor_axis
preds_panel
# Out:
# Results in collection ava_style_oct22: 6
# Index([u'decaf_fc6 False vw', u'decaf_fc6_flatten False vw', u'gbvs_saliency False vw', u'gist_256 False vw', u'lab_hist  vw', u'mc_bit False vw'], dtype='object')
# <class 'pandas.core.panel.Panel'>
# Dimensions: 31 (items) x 13843 (major_axis) x 6 (minor_axis)
# Items axis: importance to style_Vanishing_Point
# Major_axis axis: 1187 to 97008
# Minor_axis axis: decaf_fc6 False vw to mc_bit False vw

# %%
label_df = vislab.datasets.ava.get_style_df()

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=preds_panel.minor_axis.tolist() + ['_random'],
    balanced=True, with_plot=True, with_print=True)
# Out:
# Looks like the preds frame already has gt info.
# ********************decaf_fc6 False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.629156  0.573427  0.600000      429
# style_Duotones               0.603175  0.429379  0.501650      531
# style_HDR                    0.689252  0.760309  0.723039      388
# style_Image_Grain            0.584951  0.669444  0.624352      360
# style_Light_On_White         0.705882  0.881013  0.783784      395
# style_Long_Exposure          0.534392  0.500000  0.516624      404
# style_Macro                  0.591603  0.371703  0.456554      417
# style_Motion_Blur            0.609827  0.576503  0.592697      366
# style_Negative_Image         0.617169  0.690909  0.651961      385
# style_Rule_of_Thirds         0.490741  0.273902  0.351575      387
# style_Shallow_DOF            0.426887  0.560372  0.484605      323
# style_Silhouettes            0.657563  0.843666  0.739079      371
# style_Soft_Focus             0.516539  0.595308  0.553134      341
# style_Vanishing_Point        0.635747  0.753351  0.689571      373
# accuracy: 0.598903107861
#
# Looks like the preds frame already has gt info.
# ********************decaf_fc6_flatten False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.683190  0.723744  0.702882      438
# style_Duotones               0.761773  0.518868  0.617284      530
# style_HDR                    0.973064  0.744845  0.843796      388
# style_Image_Grain            0.879433  0.666667  0.758410      372
# style_Light_On_White         0.713748  0.938119  0.810695      404
# style_Long_Exposure          0.699208  0.664160  0.681234      399
# style_Macro                  0.842795  0.466184  0.600311      414
# style_Motion_Blur            0.722798  0.768595  0.744993      363
# style_Negative_Image         0.740476  0.831551  0.783375      374
# style_Rule_of_Thirds         0.649682  0.536842  0.587896      380
# style_Shallow_DOF            0.575419  0.651899  0.611276      316
# style_Silhouettes            0.636719  0.871658  0.735892      374
# style_Soft_Focus             0.670241  0.755287  0.710227      331
# style_Vanishing_Point        0.604736  0.892473  0.720955      372
# accuracy: 0.710174152154
#
# Looks like the preds frame already has gt info.
# ********************gbvs_saliency False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.180791  0.074074  0.105090      432
# style_Duotones               0.125436  0.067542  0.087805      533
# style_HDR                    0.158763  0.198454  0.176403      388
# style_Image_Grain            0.116095  0.120879  0.118439      364
# style_Light_On_White         0.172800  0.272727  0.211557      396
# style_Long_Exposure          0.127389  0.099010  0.111421      404
# style_Macro                  0.097403  0.035800  0.052356      419
# style_Motion_Blur            0.123007  0.147945  0.134328      365
# style_Negative_Image         0.130435  0.169811  0.147541      371
# style_Rule_of_Thirds         0.177193  0.254408  0.208893      397
# style_Shallow_DOF            0.085185  0.070336  0.077052      327
# style_Silhouettes            0.143411  0.196286  0.165733      377
# style_Soft_Focus             0.090652  0.095238  0.092888      336
# style_Vanishing_Point        0.185882  0.214674  0.199243      368
# accuracy: 0.142048566734
#
# Looks like the preds frame already has gt info.
# ********************gist_256 False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.309192  0.252847  0.278195      439
# style_Duotones               0.217949  0.062157  0.096728      547
# style_HDR                    0.263158  0.347938  0.299667      388
# style_Image_Grain            0.152381  0.177778  0.164103      360
# style_Light_On_White         0.425439  0.729323  0.537396      399
# style_Long_Exposure          0.188889  0.167076  0.177314      407
# style_Macro                  0.194561  0.218824  0.205980      425
# style_Motion_Blur            0.202410  0.229508  0.215109      366
# style_Negative_Image         0.220755  0.307087  0.256861      381
# style_Rule_of_Thirds         0.100000  0.031915  0.048387      376
# style_Shallow_DOF            0.101604  0.059937  0.075397      317
# style_Silhouettes            0.232852  0.347709  0.278919      371
# style_Soft_Focus             0.178571  0.132353  0.152027      340
# style_Vanishing_Point        0.166667  0.207182  0.184729      362
# accuracy: 0.233114275283
#
# Looks like the preds frame already has gt info.
# ********************lab_hist  vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.390000  0.451389  0.418455      432
# style_Duotones               0.343434  0.522073  0.414318      521
# style_HDR                    0.328125  0.432990  0.373333      388
# style_Image_Grain            0.191693  0.165746  0.177778      362
# style_Light_On_White         0.514727  0.912935  0.658296      402
# style_Long_Exposure          0.282772  0.375622  0.322650      402
# style_Macro                  0.257426  0.120930  0.164557      430
# style_Motion_Blur            0.405594  0.157182  0.226562      369
# style_Negative_Image         0.419355  0.383378  0.400560      373
# style_Rule_of_Thirds         0.279412  0.097938  0.145038      388
# style_Shallow_DOF            0.232704  0.115625  0.154489      320
# style_Silhouettes            0.327485  0.445623  0.377528      377
# style_Soft_Focus             0.267123  0.234234  0.249600      333
# style_Vanishing_Point        0.264984  0.227027  0.244541      370
# accuracy: 0.342235229559
#
# Looks like the preds frame already has gt info.
# ********************mc_bit False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.860465  0.503401  0.635193      441
# style_Duotones               0.833333  0.393053  0.534161      547
# style_HDR                    0.866477  0.790155  0.826558      386
# style_Image_Grain            0.807065  0.841360  0.823856      353
# style_Light_On_White         0.856459  0.899497  0.877451      398
# style_Long_Exposure          0.843373  0.689655  0.758808      406
# style_Macro                  0.556405  0.738579  0.634678      394
# style_Motion_Blur            0.647679  0.852778  0.736211      360
# style_Negative_Image         0.722353  0.810026  0.763682      379
# style_Rule_of_Thirds         0.756972  0.500000  0.602219      380
# style_Shallow_DOF            0.614958  0.687307  0.649123      323
# style_Silhouettes            0.832898  0.859838  0.846154      371
# style_Soft_Focus             0.837838  0.725146  0.777429      342
# style_Vanishing_Point        0.459279  0.934783  0.615936      368
# accuracy: 0.716776798825
#
# Looks like the preds frame already has gt info.
# ********************_random********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.084788  0.078161  0.081340      435
# style_Duotones               0.115196  0.084991  0.097815      553
# style_HDR                    0.061538  0.061856  0.061697      388
# style_Image_Grain            0.065990  0.073239  0.069426      355
# style_Light_On_White         0.084184  0.082915  0.083544      398
# style_Long_Exposure          0.058081  0.056650  0.057357      406
# style_Macro                  0.074935  0.071078  0.072956      408
# style_Motion_Blur            0.054545  0.057221  0.055851      367
# style_Negative_Image         0.044199  0.042895  0.043537      373
# style_Rule_of_Thirds         0.086207  0.091384  0.088720      383
# style_Shallow_DOF            0.058411  0.078125  0.066845      320
# style_Silhouettes            0.049046  0.048000  0.048518      375
# style_Soft_Focus             0.068966  0.076696  0.072626      339
# style_Vanishing_Point        0.077957  0.079452  0.078697      365
# accuracy: 0.0706312900274
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])

# %%
mc_metrics['ap_df']['Murray-CVPR-2012'] = 0
mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[:-1] = [
    .44, .51, .64, .74, .73, .43, .50, .40, .69, .30, .48, .72, .39, .57]
mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[-1] = mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[:-1].mean()
mc_metrics['ap_df']
# Out:
#                            decaf_fc6 False vw decaf_fc6_flatten False vw  \
# style_Complementary_Colors          0.6529222                  0.5497499
# style_Duotones                      0.5173235                  0.4737373
# style_HDR                           0.7363976                  0.8875039
# style_Image_Grain                   0.6553655                  0.8220983
# style_Light_On_White                 0.863676                   0.830158
# style_Long_Exposure                 0.4914707                  0.4590614
# style_Macro                         0.4812273                  0.5011594
# style_Motion_Blur                   0.6040404                  0.5338009
# style_Negative_Image                0.7462567                  0.6270309
# style_Rule_of_Thirds                0.3440286                  0.3590153
# style_Shallow_DOF                   0.4594503                  0.5648782
# style_Silhouettes                   0.8483893                   0.789615
# style_Soft_Focus                     0.503225                  0.4976579
# style_Vanishing_Point               0.7505899                  0.6750529
# _mean                               0.6181688                  0.6121799
#
#                            gbvs_saliency False vw gist_256 False vw  \
# style_Complementary_Colors              0.1114829          0.286296
# style_Duotones                          0.1226766         0.1299861
# style_HDR                               0.1413063         0.1626095
# style_Image_Grain                       0.1080517         0.1141517
# style_Light_On_White                    0.1587846         0.6351919
# style_Long_Exposure                      0.138723         0.1439795
# style_Macro                             0.1129641         0.1909872
# style_Motion_Blur                       0.1180323         0.1580708
# style_Negative_Image                    0.1202113         0.2136189
# style_Rule_of_Thirds                    0.1349869         0.1209747
# style_Shallow_DOF                       0.1233621         0.1484964
# style_Silhouettes                       0.1291063          0.236023
# style_Soft_Focus                        0.1043148         0.1672772
# style_Vanishing_Point                   0.1732286         0.1392348
# _mean                                   0.1283737         0.2033498
#
#                            lab_hist  vw mc_bit False vw  Murray-CVPR-2012
# style_Complementary_Colors    0.3351943        0.698068          0.440000
# style_Duotones                0.3607458       0.6527609          0.510000
# style_HDR                     0.2583269       0.8636212          0.640000
# style_Image_Grain             0.2166171       0.9086773          0.740000
# style_Light_On_White          0.7974474       0.9284059          0.730000
# style_Long_Exposure           0.2990173       0.8018483          0.430000
# style_Macro                   0.1947404       0.6515734          0.500000
# style_Motion_Blur             0.1927683       0.7997921          0.400000
# style_Negative_Image          0.3355112       0.7805032          0.690000
# style_Rule_of_Thirds          0.1650095       0.6011863          0.300000
# style_Shallow_DOF             0.2011229       0.6854663          0.480000
# style_Silhouettes              0.288034       0.9166468          0.720000
# style_Soft_Focus              0.2296008       0.7372475          0.390000
# style_Vanishing_Point         0.1812717       0.8973872          0.570000
# _mean                          0.289672       0.7802275          0.538571

# %%
fig = vislab.results_viz.plot_df_bar(mc_metrics['ap_df'])

# %%
# Force-directed graph of confusion matrix
conf_df = mc_metrics['feat_metrics']['mc_bit False vw']['conf_df']
conf_df_n = conf_df.astype(float) / conf_df.sum(1)
conf_df_n
# Out:
#                             style_Complementary_Colors  style_Duotones  \
# style_Complementary_Colors                    0.549223        0.002591
# style_Duotones                                0.010363        0.515544
# style_HDR                                     0.002591        0.005181
# style_Image_Grain                             0.000000        0.012953
# style_Light_On_White                          0.005181        0.005181
# style_Long_Exposure                           0.005181        0.010363
# style_Macro                                   0.010363        0.002591
# style_Motion_Blur                             0.002591        0.002591
# style_Negative_Image                          0.007772        0.010363
# style_Rule_of_Thirds                          0.012953        0.005181
# style_Shallow_DOF                             0.010363        0.015544
# style_Silhouettes                             0.010363        0.015544
# style_Soft_Focus                              0.002591        0.005181
# style_Vanishing_Point                         0.000000        0.005181
#
#                             style_HDR  style_Image_Grain  \
# style_Complementary_Colors   0.018135           0.010363
# style_Duotones               0.015544           0.059585
# style_HDR                    0.790155           0.002591
# style_Image_Grain            0.002591           0.873057
# style_Light_On_White         0.000000           0.005181
# style_Long_Exposure          0.015544           0.002591
# style_Macro                  0.002591           0.000000
# style_Motion_Blur            0.005181           0.000000
# style_Negative_Image         0.005181           0.005181
# style_Rule_of_Thirds         0.018135           0.015544
# style_Shallow_DOF            0.005181           0.002591
# style_Silhouettes            0.000000           0.000000
# style_Soft_Focus             0.005181           0.005181
# style_Vanishing_Point        0.000000           0.005181
#
#                             style_Light_On_White  style_Long_Exposure  \
# style_Complementary_Colors              0.012953             0.023316
# style_Duotones                          0.028497             0.018135
# style_HDR                               0.000000             0.015544
# style_Image_Grain                       0.002591             0.000000
# style_Light_On_White                    0.888601             0.000000
# style_Long_Exposure                     0.010363             0.702073
# style_Macro                             0.012953             0.007772
# style_Motion_Blur                       0.010363             0.012953
# style_Negative_Image                    0.015544             0.002591
# style_Rule_of_Thirds                    0.020725             0.015544
# style_Shallow_DOF                       0.015544             0.000000
# style_Silhouettes                       0.005181             0.010363
# style_Soft_Focus                        0.020725             0.018135
# style_Vanishing_Point                   0.002591             0.012953
#
#                             style_Macro  style_Motion_Blur  \
# style_Complementary_Colors     0.142487           0.049223
# style_Duotones                 0.051813           0.033679
# style_HDR                      0.018135           0.023316
# style_Image_Grain              0.023316           0.015544
# style_Light_On_White           0.020725           0.012953
# style_Long_Exposure            0.023316           0.056995
# style_Macro                    0.777202           0.036269
# style_Motion_Blur              0.020725           0.836788
# style_Negative_Image           0.038860           0.020725
# style_Rule_of_Thirds           0.051813           0.023316
# style_Shallow_DOF              0.101036           0.028497
# style_Silhouettes              0.007772           0.015544
# style_Soft_Focus               0.046632           0.054404
# style_Vanishing_Point          0.005181           0.005181
#
#                             style_Negative_Image  style_Rule_of_Thirds  \
# style_Complementary_Colors              0.025907              0.023316
# style_Duotones                          0.051813              0.018135
# style_HDR                               0.015544              0.012953
# style_Image_Grain                       0.005181              0.007772
# style_Light_On_White                    0.028497              0.002591
# style_Long_Exposure                     0.005181              0.020725
# style_Macro                             0.020725              0.018135
# style_Motion_Blur                       0.010363              0.015544
# style_Negative_Image                    0.795337              0.018135
# style_Rule_of_Thirds                    0.025907              0.572539
# style_Shallow_DOF                       0.023316              0.023316
# style_Silhouettes                       0.007772              0.010363
# style_Soft_Focus                        0.015544              0.002591
# style_Vanishing_Point                   0.007772              0.002591
#
#                             style_Shallow_DOF  style_Silhouettes  \
# style_Complementary_Colors           0.041451           0.010363
# style_Duotones                       0.015544           0.015544
# style_HDR                            0.007772           0.005181
# style_Image_Grain                    0.002591           0.005181
# style_Light_On_White                 0.010363           0.005181
# style_Long_Exposure                  0.015544           0.007772
# style_Macro                          0.064767           0.000000
# style_Motion_Blur                    0.018135           0.002591
# style_Negative_Image                 0.015544           0.005181
# style_Rule_of_Thirds                 0.051813           0.018135
# style_Shallow_DOF                    0.699482           0.012953
# style_Silhouettes                    0.002591           0.862694
# style_Soft_Focus                     0.046632           0.005181
# style_Vanishing_Point                0.002591           0.005181
#
#                             style_Soft_Focus  style_Vanishing_Point
# style_Complementary_Colors          0.005181               0.085492
# style_Duotones                      0.010363               0.155440
# style_HDR                           0.002591               0.098446
# style_Image_Grain                   0.002591               0.046632
# style_Light_On_White                0.002591               0.012953
# style_Long_Exposure                 0.010363               0.113990
# style_Macro                         0.018135               0.028497
# style_Motion_Blur                   0.018135               0.044041
# style_Negative_Image                0.007772               0.051813
# style_Rule_of_Thirds                0.010363               0.158031
# style_Shallow_DOF                   0.023316               0.038860
# style_Silhouettes                   0.002591               0.049223
# style_Soft_Focus                    0.740933               0.031088
# style_Vanishing_Point               0.000000               0.945596

# %%
import networkx as nx
g = nx.DiGraph()
for row_ix, row in conf_df_n.iterrows():
    g.add_weighted_edges_from([(row_ix, col_ix, vals) for col_ix, vals in row.iteritems()])

# %%
nx.draw_spring(g)
