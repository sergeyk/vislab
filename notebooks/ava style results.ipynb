# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import pandas as pd

import vislab
import vislab.datasets
import vislab.results

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_oct22', '/Users/sergeyk/work/aphrodite/data/results2', multiclass=True, force=True)
pred_prefix = 'pred'
print preds_panel.minor_axis
preds_panel
# Out:
# Results in collection ava_style_oct22: 4
# Index([u'gist_256 False vw', u'lab_hist  vw', u'mc_bit False vw', u'noise  vw'], dtype='object')
# <class 'pandas.core.panel.Panel'>
# Dimensions: 31 (items) x 13843 (major_axis) x 4 (minor_axis)
# Items axis: importance to style_Vanishing_Point
# Major_axis axis: 1187 to 97008
# Minor_axis axis: gist_256 False vw to noise  vw

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_oct21', '/Users/sergeyk/work/aphrodite/data/results2', multiclass=False, force=False)
pred_prefix = 'clf ava_style'
print preds_panel.minor_axis
preds_panel
# Out:
# Loaded from cache: 14 records
# Index([u'lab_hist  vw', u'label', u'split'], dtype='object')
# <class 'pandas.core.panel.Panel'>
# Dimensions: 14 (items) x 13994 (major_axis) x 3 (minor_axis)
# Items axis: clf ava_style_style_Complementary_Colors to clf ava_style_style_Vanishing_Point
# Major_axis axis: 1187 to 97009
# Minor_axis axis: lab_hist  vw to split

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_split_oct17', '/Users/sergeyk/work/aphrodite/data/results2', multiclass=False, force=False)
pred_prefix = 'clf ava_style'
print preds_panel.minor_axis
preds_panel
# Out:
# Loaded from cache: 42 records
# Index([u'decaf_fc6  vw', u'decaf_fc6,lab_hist  vw', u'lab_hist  vw', u'label', u'split'], dtype='object')
# <class 'pandas.core.panel.Panel'>
# Dimensions: 14 (items) x 14079 (major_axis) x 5 (minor_axis)
# Items axis: clf ava_style_style_Complementary_Colors to clf ava_style_style_Vanishing_Point
# Major_axis axis: 1187 to 97009
# Minor_axis axis: decaf_fc6  vw to split

# %% [markdown]
# ### Decaf FC6 results

# %%
label_df = vislab.datasets.ava.get_style_df()

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=['lab_hist  vw', 'mc_bit False vw', 'gist_256 False vw', '_random'],
    balanced=True, with_plot=True, with_print=True)
# Out:
# Looks like the preds frame already has gt info.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.332
# 2     0.483
# 3     0.590
# 4     0.678
# 5     0.740
# 6     0.793
# 7     0.842
# 8     0.887
# 9     0.922
# 10    0.950
# 11    0.970
# 12    0.985
# 13    0.996
# 14    1.000
# dtype: float64
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.383302  0.520619  0.441530      388
# style_Duotones               0.257979  0.500000  0.340351      388
# style_HDR                    0.329412  0.432990  0.374165      388
# style_Image_Grain            0.230994  0.203608  0.216438      388
# style_Light_On_White         0.506550  0.896907  0.647442      388
# style_Long_Exposure          0.294559  0.404639  0.340934      388
# style_Macro                  0.237838  0.113402  0.153578      388
# style_Motion_Blur            0.342857  0.154639  0.213144      388
# style_Negative_Image         0.430723  0.368557  0.397222      388
# style_Rule_of_Thirds         0.259259  0.090206  0.133843      388
# style_Shallow_DOF            0.218935  0.095361  0.132855      388
# style_Silhouettes            0.329167  0.407216  0.364055      388
# style_Soft_Focus             0.295820  0.237113  0.263233      388
# style_Vanishing_Point        0.295918  0.224227  0.255132      388
# accuracy: 0.332106038292
#
# Looks like the preds frame already has gt info.
# ------------------------------------------------------------
# /Users/sergeyk/work/vislab/vislab/results.py:71: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:71: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [ True]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.741
# 2     0.831
# 3     0.885
# 4     0.916
# 5     0.936
# 6     0.958
# 7     0.971
# 8     0.978
# 9     0.984
# 10    0.990
# 11    0.994
# 12    0.997
# 13    0.999
# 14    1.000
# dtype: float64
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.854251  0.546632  0.666667      386
# style_Duotones               0.784753  0.453368  0.574713      386
# style_HDR                    0.876437  0.790155  0.831063      386
# style_Image_Grain            0.886544  0.870466  0.878431      386
# style_Light_On_White         0.838308  0.873057  0.855330      386
# style_Long_Exposure          0.837061  0.678756  0.749642      386
# style_Macro                  0.571956  0.803109  0.668103      386
# style_Motion_Blur            0.662474  0.818653  0.732329      386
# style_Negative_Image         0.767089  0.784974  0.775928      386
# style_Rule_of_Thirds         0.779851  0.541451  0.639144      386
# style_Shallow_DOF            0.686486  0.658031  0.671958      386
# style_Silhouettes            0.871391  0.860104  0.865711      386
# style_Soft_Focus             0.887538  0.756477  0.816783      386
# style_Vanishing_Point        0.498630  0.943005  0.652330      386
# accuracy: 0.741302738712
#
# Looks like the preds frame already has gt info.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.227
# 2     0.355
# 3     0.451
# 4     0.531
# 5     0.604
# 6     0.672
# 7     0.735
# 8     0.792
# 9     0.840
# 10    0.884
# 11    0.928
# 12    0.963
# 13    0.986
# 14    1.000
# dtype: float64
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.307246  0.273196  0.289222      388
# style_Duotones               0.163636  0.069588  0.097649      388
# style_HDR                    0.250464  0.347938  0.291262      388
# style_Image_Grain            0.125908  0.134021  0.129838      388
# style_Light_On_White         0.411950  0.675258  0.511719      388
# style_Long_Exposure          0.192201  0.177835  0.184739      388
# style_Macro                  0.192225  0.229381  0.209166      388
# style_Motion_Blur            0.194064  0.219072  0.205811      388
# style_Negative_Image         0.214421  0.291237  0.246995      388
# style_Rule_of_Thirds         0.101010  0.025773  0.041068      388
# style_Shallow_DOF            0.150000  0.077320  0.102041      388
# style_Silhouettes            0.226316  0.332474  0.269311      388
# style_Soft_Focus             0.203320  0.126289  0.155803      388
# style_Vanishing_Point        0.180778  0.203608  0.191515      388
# accuracy: 0.22735640648
#
# Looks like the preds frame already has gt info.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.073
# 2     0.142
# 3     0.216
# 4     0.289
# 5     0.361
# 6     0.431
# 7     0.510
# 8     0.575
# 9     0.649
# 10    0.716
# 11    0.781
# 12    0.855
# 13    0.929
# 14    1.000
# dtype: float64
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.094595  0.090206  0.092348      388
# style_Duotones               0.066138  0.064433  0.065274      388
# style_HDR                    0.065823  0.067010  0.066411      388
# style_Image_Grain            0.054455  0.056701  0.055556      388
# style_Light_On_White         0.070130  0.069588  0.069858      388
# style_Long_Exposure          0.074257  0.077320  0.075758      388
# style_Macro                  0.080645  0.077320  0.078947      388
# style_Motion_Blur            0.087071  0.085052  0.086050      388
# style_Negative_Image         0.076010  0.082474  0.079110      388
# style_Rule_of_Thirds         0.056150  0.054124  0.055118      388
# style_Shallow_DOF            0.084270  0.077320  0.080645      388
# style_Silhouettes            0.078086  0.079897  0.078981      388
# style_Soft_Focus             0.073048  0.074742  0.073885      388
# style_Vanishing_Point        0.070000  0.072165  0.071066      388
# accuracy: 0.0734536082474
# /Users/sergeyk/work/vislab/vislab/results.py:71: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=['lab_hist  vw', 'decaf_fc6  vw', '_random'],
    balanced=True, with_plot=True, with_print=True)
# Out:
# /Users/sergeyk/work/vislab/vislab/results.py:71: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:263: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ 7 10].
#   y_true, y_pred)
# Only taking 'test' split predictions.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.264
# 2     0.384
# 3     0.496
# 4     0.557
# 5     0.619
# 6     0.670
# 7     0.751
# 8     0.813
# 9     0.860
# 10    0.904
# 11    0.949
# 12    0.980
# 13    0.991
# 14    1.000
# dtype: float64
#                             precision  recall  f1-score  support
# style_Complementary_Colors   0.333333    0.32  0.326531       50
# style_Duotones               0.205128    0.16  0.179775       50
# style_HDR                    0.259259    0.14  0.181818       50
# style_Image_Grain            0.137931    0.08  0.101266       50
# style_Light_On_White         0.475728    0.98  0.640523       50
# style_Long_Exposure          0.340426    0.32  0.329897       50
# style_Macro                  0.200000    0.10  0.133333       50
# style_Motion_Blur            0.000000    0.00  0.000000       50
# style_Negative_Image         0.344262    0.42  0.378378       50
# style_Rule_of_Thirds         0.055556    0.02  0.029412       50
# style_Shallow_DOF            0.000000    0.00  0.000000       50
# style_Silhouettes            0.250000    0.40  0.307692       50
# style_Soft_Focus             0.174242    0.46  0.252747       50
# style_Vanishing_Point        0.215385    0.28  0.243478       50
# accuracy: 0.262857142857
#
# Only taking 'test' split predictions.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.451
# 2     0.634
# 3     0.734
# 4     0.793
# 5     0.856
# 6     0.901
# 7     0.936
# 8     0.951
# 9     0.967
# 10    0.980
# 11    0.991
# 12    0.996
# 13    0.999
# 14    1.000
# dtype: float64
#                             precision  recall  f1-score  support
# style_Complementary_Colors   0.600000    0.24  0.342857       50
# style_Duotones               0.444444    0.16  0.235294       50
# style_HDR                    0.500000    0.54  0.519231       50
# style_Image_Grain            0.421053    0.32  0.363636       50
# style_Light_On_White         0.736842    0.84  0.785047       50
# style_Long_Exposure          0.266667    0.32  0.290909       50
# style_Macro                  0.397059    0.54  0.457627       50
# style_Motion_Blur            0.327869    0.40  0.360360       50
# style_Negative_Image         0.666667    0.64  0.653061       50
# style_Rule_of_Thirds         0.296296    0.16  0.207792       50
# style_Shallow_DOF            0.295455    0.26  0.276596       50
# style_Silhouettes            0.641509    0.68  0.660194       50
# style_Soft_Focus             0.338983    0.40  0.366972       50
# style_Vanishing_Point        0.440860    0.82  0.573427       50
# accuracy: 0.451428571429
#
# Only taking 'test' split predictions.
# /Users/sergeyk/work/vislab/vislab/results.py:71: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:263: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [13].
#   y_true, y_pred)
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.056
# 2     0.124
# 3     0.201
# 4     0.246
# 5     0.333
# 6     0.386
# 7     0.461
# 8     0.536
# 9     0.646
# 10    0.713
# 11    0.781
# 12    0.844
# 13    0.924
# 14    1.000
# dtype: float64
#                             precision  recall  f1-score  support
# style_Complementary_Colors   0.052632    0.06  0.056075       50
# style_Duotones               0.108696    0.10  0.104167       50
# style_HDR                    0.022222    0.02  0.021053       50
# style_Image_Grain            0.071429    0.08  0.075472       50
# style_Light_On_White         0.066667    0.06  0.063158       50
# style_Long_Exposure          0.090909    0.10  0.095238       50
# style_Macro                  0.061224    0.06  0.060606       50
# style_Motion_Blur            0.025000    0.02  0.022222       50
# style_Negative_Image         0.018182    0.02  0.019048       50
# style_Rule_of_Thirds         0.096154    0.10  0.098039       50
# style_Shallow_DOF            0.083333    0.08  0.081633       50
# style_Silhouettes            0.040000    0.04  0.040000       50
# style_Soft_Focus             0.036364    0.04  0.038095       50
# style_Vanishing_Point        0.000000    0.00  0.000000       50
# accuracy: 0.0557142857143

# %%
mc_metrics['ap_df']
# Out:
#                                _random decaf_fc6  vw lab_hist  vw
# style_Complementary_Colors  0.08060519     0.4933497    0.2106849
# style_Duotones              0.08152482     0.5267968    0.3758171
# style_HDR                   0.08361347     0.5993104    0.1613276
# style_Image_Grain           0.09229018     0.4740618    0.1577514
# style_Light_On_White        0.09682099     0.8937988    0.7503228
# style_Long_Exposure          0.1030225      0.258962    0.2819763
# style_Macro                   0.121708     0.4448732    0.1386544
# style_Motion_Blur           0.09332166     0.3997095    0.1190837
# style_Negative_Image        0.09327412     0.6057644    0.2987933
# style_Rule_of_Thirds          0.146758     0.2376113    0.1543358
# style_Shallow_DOF            0.2214503     0.5759486    0.2234908
# style_Silhouettes            0.1009726     0.7860277    0.3460605
# style_Soft_Focus             0.1300505     0.4120709    0.2047908
# style_Vanishing_Point       0.08614584     0.6600815    0.2082094
# _mean                         0.109397     0.5263119    0.2593785

# %%
mc_metrics['ap_df']['Murray-CVPR-2012'] = 0
mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[:-1] = [
    .44, .51, .64, .74, .73, .43, .50, .40, .69, .30, .48, .72, .39, .57]
mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[-1] = mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[:-1].mean()
mc_metrics['ap_df']
# Out:
#                                _random decaf_fc6  vw lab_hist  vw  \
# style_Complementary_Colors  0.08060519     0.4933497    0.2106849
# style_Duotones              0.08152482     0.5267968    0.3758171
# style_HDR                   0.08361347     0.5993104    0.1613276
# style_Image_Grain           0.09229018     0.4740618    0.1577514
# style_Light_On_White        0.09682099     0.8937988    0.7503228
# style_Long_Exposure          0.1030225      0.258962    0.2819763
# style_Macro                   0.121708     0.4448732    0.1386544
# style_Motion_Blur           0.09332166     0.3997095    0.1190837
# style_Negative_Image        0.09327412     0.6057644    0.2987933
# style_Rule_of_Thirds          0.146758     0.2376113    0.1543358
# style_Shallow_DOF            0.2214503     0.5759486    0.2234908
# style_Silhouettes            0.1009726     0.7860277    0.3460605
# style_Soft_Focus             0.1300505     0.4120709    0.2047908
# style_Vanishing_Point       0.08614584     0.6600815    0.2082094
# _mean                         0.109397     0.5263119    0.2593785
#
#                             Murray-CVPR-2012
# style_Complementary_Colors          0.440000
# style_Duotones                      0.510000
# style_HDR                           0.640000
# style_Image_Grain                   0.740000
# style_Light_On_White                0.730000
# style_Long_Exposure                 0.430000
# style_Macro                         0.500000
# style_Motion_Blur                   0.400000
# style_Negative_Image                0.690000
# style_Rule_of_Thirds                0.300000
# style_Shallow_DOF                   0.480000
# style_Silhouettes                   0.720000
# style_Soft_Focus                    0.390000
# style_Vanishing_Point               0.570000
# _mean                               0.538571

# %%
fig = vislab.results_viz.plot_df_bar(mc_metrics['ap_df'])
