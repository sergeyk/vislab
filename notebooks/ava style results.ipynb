# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import pandas as pd

import vislab
import vislab.datasets
import vislab.results

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_oct22', '/Users/sergeyk/work/aphrodite/data/results3', multiclass=True, force=True)
pred_prefix = 'pred'
print preds_panel.minor_axis
preds_panel
# Out:
# Results in collection ava_style_oct22: 6
# Index([u'decaf_fc6 False vw', u'decaf_fc6_flatten False vw', u'gist_256 False vw', u'lab_hist  vw', u'mc_bit False vw', u'noise  vw'], dtype='object')
# <class 'pandas.core.panel.Panel'>
# Dimensions: 31 (items) x 13843 (major_axis) x 6 (minor_axis)
# Items axis: importance to style_Vanishing_Point
# Major_axis axis: 1187 to 97008
# Minor_axis axis: decaf_fc6 False vw to noise  vw

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_oct21', '/Users/sergeyk/work/aphrodite/data/results2', multiclass=False, force=False)
pred_prefix = 'clf ava_style'
print preds_panel.minor_axis
preds_panel
# Out:
# Loaded from cache: 14 records
# Index([u'lab_hist  vw', u'label', u'split'], dtype='object')
# <class 'pandas.core.panel.Panel'>
# Dimensions: 14 (items) x 13994 (major_axis) x 3 (minor_axis)
# Items axis: clf ava_style_style_Complementary_Colors to clf ava_style_style_Vanishing_Point
# Major_axis axis: 1187 to 97009
# Minor_axis axis: lab_hist  vw to split

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_split_oct17', '/Users/sergeyk/work/aphrodite/data/results2', multiclass=False, force=False)
pred_prefix = 'clf ava_style'
print preds_panel.minor_axis
preds_panel
# Out:
# Loaded from cache: 42 records
# Index([u'decaf_fc6  vw', u'decaf_fc6,lab_hist  vw', u'lab_hist  vw', u'label', u'split'], dtype='object')
# <class 'pandas.core.panel.Panel'>
# Dimensions: 14 (items) x 14079 (major_axis) x 5 (minor_axis)
# Items axis: clf ava_style_style_Complementary_Colors to clf ava_style_style_Vanishing_Point
# Major_axis axis: 1187 to 97009
# Minor_axis axis: decaf_fc6  vw to split

# %% [markdown]
# ### Decaf FC6 results

# %%
label_df = vislab.datasets.ava.get_style_df()

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=preds_panel.minor_axis,
    balanced=True, with_plot=True, with_print=True)
# Out:
# Looks like the preds frame already has gt info.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.601
# 2     0.759
# 3     0.847
# 4     0.896
# 5     0.931
# 6     0.955
# 7     0.969
# 8     0.979
# 9     0.986
# 10    0.992
# 11    0.996
# 12    0.997
# 13    0.999
# 14    1.000
# dtype: float64
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.583333  0.577320  0.580311      388
# style_Duotones               0.509749  0.471649  0.489960      388
# style_HDR                    0.659955  0.760309  0.706587      388
# style_Image_Grain            0.652174  0.657216  0.654685      388
# style_Light_On_White         0.677932  0.878866  0.765432      388
# style_Long_Exposure          0.524079  0.476804  0.499325      388
# style_Macro                  0.555985  0.371134  0.445131      388
# style_Motion_Blur            0.607895  0.595361  0.601562      388
# style_Negative_Image         0.657702  0.693299  0.675031      388
# style_Rule_of_Thirds         0.504950  0.262887  0.345763      388
# style_Shallow_DOF            0.463183  0.502577  0.482077      388
# style_Silhouettes            0.671548  0.827320  0.741339      388
# style_Soft_Focus             0.556086  0.600515  0.577447      388
# style_Vanishing_Point        0.672131  0.739691  0.704294      388
# accuracy: 0.601067746686
#
# Looks like the preds frame already has gt info.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.717
# 2     0.829
# 3     0.880
# 4     0.908
# 5     0.930
# 6     0.945
# 7     0.957
# 8     0.965
# 9     0.972
# 10    0.978
# 11    0.982
# 12    0.987
# 13    0.996
# 14    1.000
# dtype: float64
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.635611  0.791237  0.704937      388
# style_Duotones               0.665680  0.579897  0.619835      388
# style_HDR                    0.966555  0.744845  0.841339      388
# style_Image_Grain            0.913669  0.654639  0.762763      388
# style_Light_On_White         0.695985  0.938144  0.799122      388
# style_Long_Exposure          0.698667  0.675258  0.686763      388
# style_Macro                  0.855814  0.474227  0.610282      388
# style_Motion_Blur            0.791557  0.773196  0.782269      388
# style_Negative_Image         0.721963  0.796392  0.757353      388
# style_Rule_of_Thirds         0.661922  0.479381  0.556054      388
# style_Shallow_DOF            0.658854  0.652062  0.655440      388
# style_Silhouettes            0.689796  0.871134  0.769932      388
# style_Soft_Focus             0.683047  0.716495  0.699371      388
# style_Vanishing_Point        0.623188  0.886598  0.731915      388
# accuracy: 0.716678939617
#
# Looks like the preds frame already has gt info.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.233
# 2     0.360
# 3     0.460
# 4     0.552
# 5     0.625
# 6     0.695
# 7     0.752
# 8     0.805
# 9     0.848
# 10    0.889
# 11    0.931
# 12    0.966
# 13    0.987
# 14    1.000
# dtype: float64
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.311178  0.265464  0.286509      388
# style_Duotones               0.142012  0.061856  0.086176      388
# style_HDR                    0.250000  0.347938  0.290948      388
# style_Image_Grain            0.130435  0.139175  0.134663      388
# style_Light_On_White         0.422601  0.703608  0.528046      388
# style_Long_Exposure          0.210084  0.193299  0.201342      388
# style_Macro                  0.194748  0.229381  0.210651      388
# style_Motion_Blur            0.202643  0.237113  0.218527      388
# style_Negative_Image         0.202020  0.257732  0.226501      388
# style_Rule_of_Thirds         0.112245  0.028351  0.045267      388
# style_Shallow_DOF            0.202765  0.113402  0.145455      388
# style_Silhouettes            0.249541  0.350515  0.291533      388
# style_Soft_Focus             0.183908  0.123711  0.147920      388
# style_Vanishing_Point        0.180804  0.208763  0.193780      388
# accuracy: 0.232879234168
#
# Looks like the preds frame already has gt info.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.330
# 2     0.483
# 3     0.589
# 4     0.669
# 5     0.733
# 6     0.788
# 7     0.843
# 8     0.885
# 9     0.919
# 10    0.946
# 11    0.967
# 12    0.985
# 13    0.995
# 14    1.000
# dtype: float64
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.373796  0.500000  0.427784      388
# style_Duotones               0.249037  0.500000  0.332476      388
# style_HDR                    0.334661  0.432990  0.377528      388
# style_Image_Grain            0.236686  0.206186  0.220386      388
# style_Light_On_White         0.519708  0.917526  0.663560      388
# style_Long_Exposure          0.302103  0.407216  0.346872      388
# style_Macro                  0.224390  0.118557  0.155143      388
# style_Motion_Blur            0.321429  0.139175  0.194245      388
# style_Negative_Image         0.451149  0.404639  0.426630      388
# style_Rule_of_Thirds         0.280576  0.100515  0.148008      388
# style_Shallow_DOF            0.271429  0.097938  0.143939      388
# style_Silhouettes            0.294118  0.373711  0.329171      388
# style_Soft_Focus             0.292359  0.226804  0.255443      388
# style_Vanishing_Point        0.260274  0.195876  0.223529      388
# accuracy: 0.330081001473
#
# Looks like the preds frame already has gt info.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.754
# 2     0.840
# 3     0.891
# 4     0.921
# 5     0.941
# 6     0.959
# 7     0.972
# 8     0.980
# 9     0.986
# 10    0.991
# 11    0.995
# 12    0.997
# 13    0.999
# 14    1.000
# dtype: float64
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.872428  0.549223  0.674086      386
# style_Duotones               0.839662  0.515544  0.638844      386
# style_HDR                    0.894428  0.790155  0.839065      386
# style_Image_Grain            0.884514  0.873057  0.878748      386
# style_Light_On_White         0.849010  0.888601  0.868354      386
# style_Long_Exposure          0.836420  0.702073  0.763380      386
# style_Macro                  0.584795  0.777202  0.667408      386
# style_Motion_Blur            0.690171  0.836788  0.756440      386
# style_Negative_Image         0.765586  0.795337  0.780178      386
# style_Rule_of_Thirds         0.764706  0.572539  0.654815      386
# style_Shallow_DOF            0.703125  0.699482  0.701299      386
# style_Silhouettes            0.897574  0.862694  0.879789      386
# style_Soft_Focus             0.866667  0.740933  0.798883      386
# style_Vanishing_Point        0.508357  0.945596  0.661232      386
# accuracy: 0.753515914138
#
# Looks like the preds frame already has gt info.
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.076
# 2     0.154
# 3     0.230
# 4     0.303
# 5     0.372
# 6     0.440
# 7     0.503
# 8     0.578
# 9     0.651
# 10    0.725
# 11    0.794
# 12    0.864
# 13    0.933
# 14    1.000
# dtype: float64
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.000000  0.000000  0.000000      388
# style_Duotones               0.081862  0.131443  0.100890      388
# style_HDR                    0.000000  0.000000  0.000000      388
# style_Image_Grain            0.000000  0.000000  0.000000      388
# style_Light_On_White         0.000000  0.000000  0.000000      388
# style_Long_Exposure          0.059737  0.128866  0.081633      388
# style_Macro                  0.000000  0.000000  0.000000      388
# style_Motion_Blur            0.000000  0.000000  0.000000      388
# style_Negative_Image         0.000000  0.000000  0.000000      388
# style_Rule_of_Thirds         0.000000  0.000000  0.000000      388
# style_Shallow_DOF            0.078754  0.358247  0.129122      388
# style_Silhouettes            0.000000  0.000000  0.000000      388
# style_Soft_Focus             0.142857  0.005155  0.009950      388
# style_Vanishing_Point        0.078118  0.440722  0.132712      388
# accuracy: 0.0760309278351
# /Users/sergeyk/work/vislab/vislab/results.py:263: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [0 2 3 4 6 7 8 9]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ 0  2  3  4  6  7  8  9 11].
#   y_true, y_pred)

# %%
mc_metrics['ap_df']
# Out:
#                            decaf_fc6 False vw decaf_fc6_flatten False vw  \
# style_Complementary_Colors          0.6044296                   0.572985
# style_Duotones                      0.4859987                  0.3848768
# style_HDR                           0.7167106                  0.8928516
# style_Image_Grain                   0.6863488                   0.856307
# style_Light_On_White                0.8867727                  0.8192314
# style_Long_Exposure                  0.495598                  0.4422379
# style_Macro                         0.4679847                   0.498734
# style_Motion_Blur                   0.6145312                   0.602417
# style_Negative_Image                0.7212775                  0.6346668
# style_Rule_of_Thirds                0.3725731                  0.3571809
# style_Shallow_DOF                   0.5198262                  0.6213134
# style_Silhouettes                   0.8385604                  0.7764932
# style_Soft_Focus                    0.5508356                   0.504954
# style_Vanishing_Point               0.7464519                  0.6894564
# _mean                               0.6219928                  0.6181218
#
#                            gist_256 False vw lab_hist  vw mc_bit False vw  \
# style_Complementary_Colors         0.2852322    0.3450408       0.7121357
# style_Duotones                     0.1047053    0.3001362       0.6794547
# style_HDR                          0.1718876    0.2433617       0.8667603
# style_Image_Grain                  0.1208174    0.2425394         0.92879
# style_Light_On_White               0.6158781    0.7852607        0.923851
# style_Long_Exposure                0.1497411    0.2932762       0.7992134
# style_Macro                        0.1718779    0.1723932       0.6967584
# style_Motion_Blur                  0.1571878    0.1928658       0.8476103
# style_Negative_Image               0.2123086    0.3767021       0.8277585
# style_Rule_of_Thirds               0.1157574    0.1692627       0.6549987
# style_Shallow_DOF                   0.169156    0.2101263       0.7373371
# style_Silhouettes                  0.2232176    0.2783566       0.9239977
# style_Soft_Focus                   0.1542022    0.2168467       0.8138199
# style_Vanishing_Point              0.1421402    0.1895302       0.9038165
# _mean                              0.1995792    0.2868356       0.8083073
#
#                              noise  vw
# style_Complementary_Colors  0.07423963
# style_Duotones              0.07703176
# style_HDR                   0.07573065
# style_Image_Grain           0.08503261
# style_Light_On_White        0.07440397
# style_Long_Exposure         0.08230322
# style_Macro                  0.0856503
# style_Motion_Blur           0.08455654
# style_Negative_Image        0.08064567
# style_Rule_of_Thirds         0.0904317
# style_Shallow_DOF            0.1084411
# style_Silhouettes           0.08712438
# style_Soft_Focus            0.08067429
# style_Vanishing_Point       0.08232192
# _mean                       0.08347055

# %%
mc_metrics['ap_df']['Murray-CVPR-2012'] = 0
mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[:-1] = [
    .44, .51, .64, .74, .73, .43, .50, .40, .69, .30, .48, .72, .39, .57]
mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[-1] = mc_metrics['ap_df']['Murray-CVPR-2012'].iloc[:-1].mean()
mc_metrics['ap_df']
# Out:
#                            decaf_fc6 False vw decaf_fc6_flatten False vw  \
# style_Complementary_Colors          0.6044296                   0.572985
# style_Duotones                      0.4859987                  0.3848768
# style_HDR                           0.7167106                  0.8928516
# style_Image_Grain                   0.6863488                   0.856307
# style_Light_On_White                0.8867727                  0.8192314
# style_Long_Exposure                  0.495598                  0.4422379
# style_Macro                         0.4679847                   0.498734
# style_Motion_Blur                   0.6145312                   0.602417
# style_Negative_Image                0.7212775                  0.6346668
# style_Rule_of_Thirds                0.3725731                  0.3571809
# style_Shallow_DOF                   0.5198262                  0.6213134
# style_Silhouettes                   0.8385604                  0.7764932
# style_Soft_Focus                    0.5508356                   0.504954
# style_Vanishing_Point               0.7464519                  0.6894564
# _mean                               0.6219928                  0.6181218
#
#                            gist_256 False vw lab_hist  vw mc_bit False vw  \
# style_Complementary_Colors         0.2852322    0.3450408       0.7121357
# style_Duotones                     0.1047053    0.3001362       0.6794547
# style_HDR                          0.1718876    0.2433617       0.8667603
# style_Image_Grain                  0.1208174    0.2425394         0.92879
# style_Light_On_White               0.6158781    0.7852607        0.923851
# style_Long_Exposure                0.1497411    0.2932762       0.7992134
# style_Macro                        0.1718779    0.1723932       0.6967584
# style_Motion_Blur                  0.1571878    0.1928658       0.8476103
# style_Negative_Image               0.2123086    0.3767021       0.8277585
# style_Rule_of_Thirds               0.1157574    0.1692627       0.6549987
# style_Shallow_DOF                   0.169156    0.2101263       0.7373371
# style_Silhouettes                  0.2232176    0.2783566       0.9239977
# style_Soft_Focus                   0.1542022    0.2168467       0.8138199
# style_Vanishing_Point              0.1421402    0.1895302       0.9038165
# _mean                              0.1995792    0.2868356       0.8083073
#
#                              noise  vw  Murray-CVPR-2012
# style_Complementary_Colors  0.07423963          0.440000
# style_Duotones              0.07703176          0.510000
# style_HDR                   0.07573065          0.640000
# style_Image_Grain           0.08503261          0.740000
# style_Light_On_White        0.07440397          0.730000
# style_Long_Exposure         0.08230322          0.430000
# style_Macro                  0.0856503          0.500000
# style_Motion_Blur           0.08455654          0.400000
# style_Negative_Image        0.08064567          0.690000
# style_Rule_of_Thirds         0.0904317          0.300000
# style_Shallow_DOF            0.1084411          0.480000
# style_Silhouettes           0.08712438          0.720000
# style_Soft_Focus            0.08067429          0.390000
# style_Vanishing_Point       0.08232192          0.570000
# _mean                       0.08347055          0.538571

# %%
fig = vislab.results_viz.plot_df_bar(mc_metrics['ap_df'])

# %%
# Force-directed graph of confusion matrix
conf_df = mc_metrics['feat_metrics']['mc_bit False vw']['conf_df']
conf_df_n = conf_df.astype(float) / conf_df.sum(1)
conf_df_n
# Out:
#                             style_Complementary_Colors  style_Duotones  \
# style_Complementary_Colors                    0.549223        0.002591
# style_Duotones                                0.010363        0.515544
# style_HDR                                     0.002591        0.005181
# style_Image_Grain                             0.000000        0.012953
# style_Light_On_White                          0.005181        0.005181
# style_Long_Exposure                           0.005181        0.010363
# style_Macro                                   0.010363        0.002591
# style_Motion_Blur                             0.002591        0.002591
# style_Negative_Image                          0.007772        0.010363
# style_Rule_of_Thirds                          0.012953        0.005181
# style_Shallow_DOF                             0.010363        0.015544
# style_Silhouettes                             0.010363        0.015544
# style_Soft_Focus                              0.002591        0.005181
# style_Vanishing_Point                         0.000000        0.005181
#
#                             style_HDR  style_Image_Grain  \
# style_Complementary_Colors   0.018135           0.010363
# style_Duotones               0.015544           0.059585
# style_HDR                    0.790155           0.002591
# style_Image_Grain            0.002591           0.873057
# style_Light_On_White         0.000000           0.005181
# style_Long_Exposure          0.015544           0.002591
# style_Macro                  0.002591           0.000000
# style_Motion_Blur            0.005181           0.000000
# style_Negative_Image         0.005181           0.005181
# style_Rule_of_Thirds         0.018135           0.015544
# style_Shallow_DOF            0.005181           0.002591
# style_Silhouettes            0.000000           0.000000
# style_Soft_Focus             0.005181           0.005181
# style_Vanishing_Point        0.000000           0.005181
#
#                             style_Light_On_White  style_Long_Exposure  \
# style_Complementary_Colors              0.012953             0.023316
# style_Duotones                          0.028497             0.018135
# style_HDR                               0.000000             0.015544
# style_Image_Grain                       0.002591             0.000000
# style_Light_On_White                    0.888601             0.000000
# style_Long_Exposure                     0.010363             0.702073
# style_Macro                             0.012953             0.007772
# style_Motion_Blur                       0.010363             0.012953
# style_Negative_Image                    0.015544             0.002591
# style_Rule_of_Thirds                    0.020725             0.015544
# style_Shallow_DOF                       0.015544             0.000000
# style_Silhouettes                       0.005181             0.010363
# style_Soft_Focus                        0.020725             0.018135
# style_Vanishing_Point                   0.002591             0.012953
#
#                             style_Macro  style_Motion_Blur  \
# style_Complementary_Colors     0.142487           0.049223
# style_Duotones                 0.051813           0.033679
# style_HDR                      0.018135           0.023316
# style_Image_Grain              0.023316           0.015544
# style_Light_On_White           0.020725           0.012953
# style_Long_Exposure            0.023316           0.056995
# style_Macro                    0.777202           0.036269
# style_Motion_Blur              0.020725           0.836788
# style_Negative_Image           0.038860           0.020725
# style_Rule_of_Thirds           0.051813           0.023316
# style_Shallow_DOF              0.101036           0.028497
# style_Silhouettes              0.007772           0.015544
# style_Soft_Focus               0.046632           0.054404
# style_Vanishing_Point          0.005181           0.005181
#
#                             style_Negative_Image  style_Rule_of_Thirds  \
# style_Complementary_Colors              0.025907              0.023316
# style_Duotones                          0.051813              0.018135
# style_HDR                               0.015544              0.012953
# style_Image_Grain                       0.005181              0.007772
# style_Light_On_White                    0.028497              0.002591
# style_Long_Exposure                     0.005181              0.020725
# style_Macro                             0.020725              0.018135
# style_Motion_Blur                       0.010363              0.015544
# style_Negative_Image                    0.795337              0.018135
# style_Rule_of_Thirds                    0.025907              0.572539
# style_Shallow_DOF                       0.023316              0.023316
# style_Silhouettes                       0.007772              0.010363
# style_Soft_Focus                        0.015544              0.002591
# style_Vanishing_Point                   0.007772              0.002591
#
#                             style_Shallow_DOF  style_Silhouettes  \
# style_Complementary_Colors           0.041451           0.010363
# style_Duotones                       0.015544           0.015544
# style_HDR                            0.007772           0.005181
# style_Image_Grain                    0.002591           0.005181
# style_Light_On_White                 0.010363           0.005181
# style_Long_Exposure                  0.015544           0.007772
# style_Macro                          0.064767           0.000000
# style_Motion_Blur                    0.018135           0.002591
# style_Negative_Image                 0.015544           0.005181
# style_Rule_of_Thirds                 0.051813           0.018135
# style_Shallow_DOF                    0.699482           0.012953
# style_Silhouettes                    0.002591           0.862694
# style_Soft_Focus                     0.046632           0.005181
# style_Vanishing_Point                0.002591           0.005181
#
#                             style_Soft_Focus  style_Vanishing_Point
# style_Complementary_Colors          0.005181               0.085492
# style_Duotones                      0.010363               0.155440
# style_HDR                           0.002591               0.098446
# style_Image_Grain                   0.002591               0.046632
# style_Light_On_White                0.002591               0.012953
# style_Long_Exposure                 0.010363               0.113990
# style_Macro                         0.018135               0.028497
# style_Motion_Blur                   0.018135               0.044041
# style_Negative_Image                0.007772               0.051813
# style_Rule_of_Thirds                0.010363               0.158031
# style_Shallow_DOF                   0.023316               0.038860
# style_Silhouettes                   0.002591               0.049223
# style_Soft_Focus                    0.740933               0.031088
# style_Vanishing_Point               0.000000               0.945596

# %%
import networkx as nx
g = nx.DiGraph()
for row_ix, row in conf_df_n.iterrows():
    g.add_weighted_edges_from([(row_ix, col_ix, vals) for col_ix, vals in row.iteritems()])

# %%
nx.draw_spring(g)
