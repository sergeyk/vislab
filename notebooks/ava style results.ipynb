# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import pandas as pd

import vislab
import vislab.datasets
import vislab.results
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'ava_style_oct17', '/Users/sergeyk/work/aphrodite/data/results2', force=True)
preds_panel
# Out:
# Results in collection ava_style_oct17: 42
# <class 'pandas.core.panel.Panel'>
# Dimensions: 14 (items) x 14079 (major_axis) x 5 (minor_axis)
# Items axis: clf ava_style_style_Complementary_Colors to clf ava_style_style_Vanishing_Point
# Major_axis axis: 1187 to 97009
# Minor_axis axis: decaf_fc6  vw to split

# %%
label_df = vislab.datasets.ava.get_style_df()

# %%
pred_prefix = 'clf ava_style'

# %%
preds_panel.minor_xs('decaf_fc6  vw')[pred_prefix + '_style_Light_On_White'].iloc[:5]
# Out:
# 1187   -0.9758257
# 1270   -0.9691783
# 1279   -0.8467782
# 1282   -0.9864113
# 1295   -0.5456507
# Name: clf ava_style_style_Light_On_White, dtype: object

# %%
preds_panel.minor_xs('lab_hist  vw')[pred_prefix + '_style_Light_On_White'].iloc[:5]
# Out:
# 1187   -0.9294088
# 1270   -0.7604233
# 1279   -0.9428681
# 1282   -0.9705217
# 1295   -0.8051479
# Name: clf ava_style_style_Light_On_White, dtype: object

# %% [markdown]
# ### Decaf FC6 results

# %%
mc_pred_df = preds_panel.minor_xs('decaf_fc6  vw').join(label_df)
mc_metrics = vislab.results.multiclass_metrics(
    mc_pred_df, pred_prefix, balanced=False,
    with_plot=True, with_print=True)
# Out:
# ------------------------------------------------------------
# Classification metrics on the full dataset
# top_k_accuracies: [0.469, 0.629, 0.728, 0.802, 0.864, 0.912, 0.946, 0.967, 0.98, 0.988, 0.993, 0.997, 0.999, 1.0]
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.584677  0.436309  0.499713      997
# style_Duotones               0.620491  0.263804  0.370211     1630
# style_HDR                    0.521921  0.644330  0.576701      388
# style_Image_Grain            0.465804  0.671105  0.549918      751
# style_Light_On_White         0.767110  0.740367  0.753501     1090
# style_Long_Exposure          0.390244  0.635514  0.483556      856
# style_Macro                  0.441245  0.554259  0.491337     1714
# style_Motion_Blur            0.222450  0.757417  0.343899      573
# style_Negative_Image         0.467963  0.722222  0.567934      900
# style_Rule_of_Thirds         0.071429  0.000743  0.001471     1346
# style_Shallow_DOF            0.534177  0.149752  0.233925     1409
# style_Silhouettes            0.687887  0.800412  0.739895      972
# style_Soft_Focus             0.000000  0.000000  0.000000      627
# style_Vanishing_Point        0.359410  0.825424  0.500771      590
# accuracy: 0.468178862963

# %%
mc_metrics['binary_metrics_df']
# Out:
#                              accuracy          ap        auc         mcc  \
# style_Complementary_Colors  0.7775771   0.2263676  0.7681698   0.3948673
# style_Duotones              0.8074839   0.3638252  0.8203882   0.4963489
# style_HDR                   0.7909413   0.5805779  0.9297186   0.2899358
# style_Image_Grain           0.7531604   0.3003146  0.8666004   0.3447971
# style_Light_On_White        0.9287727   0.3186406  0.8698107    0.678232
# style_Long_Exposure         0.6320884    0.247232  0.8061642   0.2604329
# style_Macro                 0.5398396   0.2494721    0.61371    0.291592
# style_Motion_Blur           0.5886007   0.1315363  0.7175012    0.218653
# style_Negative_Image         0.677671   0.1976946  0.7718732   0.3173009
# style_Rule_of_Thirds         0.685545   0.1217657  0.3666323 -0.04050756
# style_Shallow_DOF           0.8600737   0.3299075  0.8127878   0.5032289
# style_Silhouettes           0.8808784   0.2429445  0.8016368   0.5634552
# style_Soft_Focus            0.4545258  0.07409475  0.4473458  -0.1541497
# style_Vanishing_Point       0.7218089   0.1264487  0.6690734   0.2992125
# _mean                       0.7213548    0.250773   0.732958   0.3188142
#
#                            pr_fig           results_df roc_fig
# style_Complementary_Colors   None  [precision, recall]    None
# style_Duotones               None  [precision, recall]    None
# style_HDR                    None  [precision, recall]    None
# style_Image_Grain            None  [precision, recall]    None
# style_Light_On_White         None  [precision, recall]    None
# style_Long_Exposure          None  [precision, recall]    None
# style_Macro                  None  [precision, recall]    None
# style_Motion_Blur            None  [precision, recall]    None
# style_Negative_Image         None  [precision, recall]    None
# style_Rule_of_Thirds         None  [precision, recall]    None
# style_Shallow_DOF            None  [precision, recall]    None
# style_Silhouettes            None  [precision, recall]    None
# style_Soft_Focus             None  [precision, recall]    None
# style_Vanishing_Point        None  [precision, recall]    None
# _mean                         NaN                  NaN     NaN

# %% [markdown]
# ### Lab hist results

# %%
mc_pred_df = preds_panel.minor_xs('lab_hist  vw').join(label_df)
mc_metrics = vislab.results.multiclass_metrics(
    mc_pred_df, pred_prefix, balanced=False,
    with_plot=True, with_print=True)
# Out:
# ------------------------------------------------------------
# Classification metrics on the full dataset
# top_k_accuracies: [0.128, 0.271, 0.408, 0.529, 0.636, 0.707, 0.77, 0.812, 0.843, 0.87, 0.887, 0.907, 0.938, 1.0]
#                             precision    recall  f1-score  support
# style_Complementary_Colors   0.230548  0.080241  0.119048      997
# style_Duotones               0.485294  0.020245  0.038869     1630
# style_HDR                    0.097561  0.020619  0.034043      388
# style_Image_Grain            0.000000  0.000000  0.000000      751
# style_Light_On_White         0.735294  0.045872  0.086356     1090
# style_Long_Exposure          0.354331  0.052570  0.091556      856
# style_Macro                  0.103764  0.595099  0.176715     1714
# style_Motion_Blur            0.189135  0.164049  0.175701      573
# style_Negative_Image         0.255556  0.025556  0.046465      900
# style_Rule_of_Thirds         0.164939  0.130015  0.145409     1346
# style_Shallow_DOF            0.047205  0.026969  0.034327     1409
# style_Silhouettes            0.291829  0.077160  0.122050      972
# style_Soft_Focus             0.074919  0.036683  0.049251      627
# style_Vanishing_Point        0.510204  0.254237  0.339367      590
# accuracy: 0.13104095933
# /Users/sergeyk/work/vislab/vislab/results.py:187: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3].
#   results = sklearn.metrics.precision_recall_fscore_support(y_true, y_pred)

# %%
mc_metrics['binary_metrics_df']
# Out:
#                              accuracy          ap        auc         mcc  \
# style_Complementary_Colors  0.7886296   0.1292206  0.6993435     0.28691
# style_Duotones              0.7012931   0.1930035  0.6055941   0.3420536
# style_HDR                   0.7327169  0.05993801  0.6890925    0.157602
# style_Image_Grain           0.6993426   0.1193129  0.6822738   0.2129527
# style_Light_On_White        0.9195261   0.1681384  0.6313978   0.6282659
# style_Long_Exposure         0.7648631  0.09266578  0.5812646   0.2337176
# style_Macro                 0.3061475   0.2639489  0.5415462 -0.04131128
# style_Motion_Blur           0.5792819   0.1605489  0.6478032  0.08915889
# style_Negative_Image        0.6363505   0.0981902  0.5738102   0.2148169
# style_Rule_of_Thirds        0.4061258   0.1853273  0.5708334  0.04929951
# style_Shallow_DOF           0.3118544   0.1563306  0.5103499 -0.00014544
# style_Silhouettes           0.6303547   0.1457985  0.6915323   0.2483403
# style_Soft_Focus             0.476992   0.1278723  0.6753661  0.04411982
# style_Vanishing_Point       0.4399335   0.3900555  0.7949978   0.1163874
# _mean                       0.5995294   0.1635965  0.6353718   0.1844406
#
#                            pr_fig           results_df roc_fig
# style_Complementary_Colors   None  [precision, recall]    None
# style_Duotones               None  [precision, recall]    None
# style_HDR                    None  [precision, recall]    None
# style_Image_Grain            None  [precision, recall]    None
# style_Light_On_White         None  [precision, recall]    None
# style_Long_Exposure          None  [precision, recall]    None
# style_Macro                  None  [precision, recall]    None
# style_Motion_Blur            None  [precision, recall]    None
# style_Negative_Image         None  [precision, recall]    None
# style_Rule_of_Thirds         None  [precision, recall]    None
# style_Shallow_DOF            None  [precision, recall]    None
# style_Silhouettes            None  [precision, recall]    None
# style_Soft_Focus             None  [precision, recall]    None
# style_Vanishing_Point        None  [precision, recall]    None
# _mean                         NaN                  NaN     NaN
