# %%
import pandas as pd

# %%
df = pd.read_hdf('../data/unshared/pins_df_mar21.h5', 'df')

# %%
plot(df['repins'].value_counts().iloc[:20])

# %%
df['repins'].value_counts().iloc[5:].sum()
# Out:
# 594295

# %%
print df.shape
print df[df['query_pastel']].shape
# Out:
# (3172020, 53)
# (66566, 53)

# %%
df[df['query_minimal']]['img'].value_counts()
# Out:
# http://media-cache-ec0.pinimg.com/736x/ed/f8/33/edf83362e63d568f8aea540a14d78955.jpg    26
# http://media-cache-ak0.pinimg.com/736x/88/df/1c/88df1c72f7874dc6db7339b0d67f0564.jpg    23
# http://media-cache-ec0.pinimg.com/736x/93/d2/b5/93d2b560e7cdedf435f1cd4c3cbdc65e.jpg    19
# http://media-cache-ak0.pinimg.com/736x/84/44/84/844484f7f3fbf7acf1b9a2b9f95e39ba.jpg    14
# http://media-cache-ak0.pinimg.com/736x/2d/e5/8c/2de58c1193688ec1ae55e432df6fd88b.jpg    13
# http://media-cache-ec0.pinimg.com/736x/eb/33/7c/eb337c2b7edb493463574c8eb98e4beb.jpg    13
# http://media-cache-ak0.pinimg.com/736x/59/5b/a5/595ba5ea17bbe54c2d615ff75589cf4f.jpg    13
# http://media-cache-ec0.pinimg.com/736x/5b/2c/6c/5b2c6c1c2da862471b7da3255c4f1e52.jpg    13
# http://media-cache-ak0.pinimg.com/736x/d1/4a/ec/d14aec5211eaa01a75745d33dec53b4e.jpg    12
# http://media-cache-ak0.pinimg.com/736x/f9/ea/95/f9ea95357f8bf3dfb21be9f8e409e49a.jpg    12
# ...

# %%
df[df['img'] == 'http://media-cache-ak0.pinimg.com/736x/96/dc/d5/96dcd54a68bcf6997e52b95f390d39b4.jpg']
# Out:
#                                                            board_name  \
# image_id
# 215117319671371590  mother-serene-spectacular-audacious-and-tempes...
# 220746819206010491                                      serene-spaces
# 366058275932551721                                             pastel
# 366058275932591127                                             pastel
# 377176537513157400                                             pastel
# 405605510159727927                                               soft
# 492018328010639772                                               soft
# 6544361928254148                                     melancholy-light
# 76631631130984426                                              pastel
# 84512930477494908                                hazy-shade-of-winter
# 85779567874911933                                       pastel-colour
# 86272149081380965                                     serene-pictures
# ...
