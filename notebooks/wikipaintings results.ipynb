# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import sklearn.metrics
import pandas as pd

import vislab
import vislab.results
import vislab.datasets
# Out:
# /Users/sergeyk/anaconda/python.app/Contents/lib/python2.7/site-packages/configobj.py:145: DeprecationWarning: The compiler package is deprecated and removed in Python 3.x.
#   import compiler

# %%
label_df = vislab.datasets.wikipaintings.get_style_df()

# %%
c = vislab.util.get_mongodb_client()['predict']['wikipaintings_oct25']
if c.find({'features': 'noise'}).count() > 0:
    c.remove({'features': 'noise'})
pd.DataFrame([x for x in c.find()])
# Out:
#                         _id                     data  \
# 0  526b20719622958641aab77a  wikipaintings_style_ALL
# 1  526bafe39622958641aab77b  wikipaintings_style_ALL
# 2  5271c7d59622958641af6843  wikipaintings_style_ALL
# 3  5272512f9622958641af684e  wikipaintings_style_ALL
# 4  5272d9b49622958641b0db67  wikipaintings_style_ALL
# 5  5272eb469622958641b1a34a  wikipaintings_style_ALL
# 6  527322fb9622958641b1a34d  wikipaintings_style_ALL
# 7  527345049622958641b1a350  wikipaintings_style_ALL
#
#                                             features  num_test  num_train  \
# 0                                        [decaf_fc6]     16492      49475
# 1                                           [mc_bit]     16492      49475
# 2                                  [decaf_tuned_fc6]     16492      49475
# 3                       [fusion_wikipaintings_oct25]     16492      49475
# 4                          [decaf_tuned_fc6_flatten]     16492      49475
# 5               [decaf_fc6, pascal_mc_for_decaf_fc6]     16492      49475
# 6  [fusion_wikipaintings_oct25, pascal_mc_for_fus...     16492      49475
# 7                               [decaf_tuned_fc6_ud]     16492      49475
#
#    num_val quadratic                                       results_name  \
# 0    16492     False  data_wikipaintings_style_ALL_features_['decaf_...
# 1    16492     False  data_wikipaintings_style_ALL_features_['mc_bit...
# 2    16492     False  data_wikipaintings_style_ALL_features_['decaf_...
# 3    16492      None  data_wikipaintings_style_ALL_features_['fusion...
# 4    16492     False  data_wikipaintings_style_ALL_features_['decaf_...
# 5    16492        pd  data_wikipaintings_style_ALL_features_['decaf_...
# 6    16492        fp  data_wikipaintings_style_ALL_features_['fusion...
# 7    16492      None  data_wikipaintings_style_ALL_features_['decaf_...
#
#    score_test  score_val task
# 0    0.383014   0.595281  clf
# 1    0.453180   0.728084  clf
# 2    0.387178   0.600663  clf
# 3    0.466557   0.757390  clf
# 4    0.318274   0.715596  clf
# 5    0.396138   0.619133  clf
# 6    0.463024   0.817788  clf
# 7    0.330074   0.505001  clf

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'wikipaintings_oct25', '/Users/sergeyk/work/aphrodite/data/results2/',
    multiclass=True, force=True)
pred_prefix = 'pred'
print preds_panel.minor_axis
# Out:
# Results in collection wikipaintings_oct25: 8
# Index([u'decaf_fc6 False vw', u'decaf_fc6,pascal_mc_for_decaf_fc6 pd vw', u'decaf_tuned_fc6 False vw', u'decaf_tuned_fc6_flatten False vw', u'decaf_tuned_fc6_ud None vw', u'fusion_wikipaintings_oct25 None vw', u'fusion_wikipaintings_oct25,pascal_mc_for_fusion_wikipaintings_oct25 fp vw', u'mc_bit False vw'], dtype='object')

# %%
feat_to_evaluate = [
    u'decaf_fc6 False vw',
    #u'decaf_fc6,pascal_mc_for_decaf_fc6 pd vw',
    u'decaf_tuned_fc6 False vw',
    #u'decaf_tuned_fc6_flatten False vw',
    #u'decaf_tuned_fc6_ud None vw',
    #u'fusion_wikipaintings_oct25 None vw',
    u'fusion_wikipaintings_oct25,pascal_mc_for_fusion_wikipaintings_oct25 fp vw',
    u'mc_bit False vw'
]
preds_panel = preds_panel.select(lambda x: x in feat_to_evaluate, 'minor')

# %%
nice_feat_names = {
    'decaf_fc6 False vw': 'DeCAF_6',
    'decaf_fc6_flatten False vw': 'DeCAF_5',
    'decaf_tuned_fc6 False vw': 'Fine-tuned DeCAF_6',
    'fusion_wikipaintings_oct25,pascal_mc_for_fusion_wikipaintings_oct25 fp vw': 'Late-fusion x Content',
    'mc_bit False vw': 'MC-bit'
}

mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=preds_panel.minor_axis.tolist() + ['random'],
    balanced=True, with_plot=False, with_print=True, nice_feat_names=nice_feat_names)
# Out:
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_fc6 False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                                     precision    recall  f1-score  support
# style_Abstract_Art                   0.328125  0.264984  0.293194      317
# style_Abstract_Expressionism         0.290323  0.312303  0.300912      317
# style_Art_Informel                   0.257143  0.255521  0.256329      317
# style_Art_Nouveau_(Modern)           0.275986  0.242902  0.258389      317
# style_Baroque                        0.340659  0.391167  0.364170      317
# style_Color_Field_Painting           0.515588  0.678233  0.585831      317
# style_Cubism                         0.352273  0.488959  0.409511      317
# style_Early_Renaissance              0.438871  0.441640  0.440252      317
# style_Expressionism                  0.291480  0.205047  0.240741      317
# style_High_Renaissance               0.359621  0.360759  0.360190      316
# style_Impressionism                  0.422343  0.488959  0.453216      317
# style_Magic_Realism                  0.364865  0.425868  0.393013      317
# style_Mannerism_(Late_Renaissance)   0.360947  0.384858  0.372519      317
# style_Minimalism                     0.473810  0.627760  0.540027      317
# style_Nave_Art_(Primitivism)         0.293478  0.255521  0.273187      317
# style_Neoclassicism                  0.493976  0.388013  0.434629      317
# style_Northern_Renaissance           0.485549  0.529968  0.506787      317
# style_Pop_Art                        0.371747  0.315457  0.341297      317
# style_Post-Impressionism             0.355649  0.268139  0.305755      317
# style_Realism                        0.356589  0.290221  0.320000      317
# style_Rococo                         0.477745  0.507886  0.492355      317
# style_Romanticism                    0.406844  0.337539  0.368966      317
# style_Surrealism                     0.224719  0.189274  0.205479      317
# style_Symbolism                      0.345865  0.290221  0.315609      317
# style_Ukiyo-e                        0.649485  0.794953  0.714894      317
# accuracy: 0.389449772842
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_tuned_fc6 False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                                     precision    recall  f1-score  support
# style_Abstract_Art                   0.320285  0.283912  0.301003      317
# style_Abstract_Expressionism         0.277070  0.274448  0.275753      317
# style_Art_Informel                   0.198502  0.167192  0.181507      317
# style_Art_Nouveau_(Modern)           0.282686  0.252366  0.266667      317
# style_Baroque                        0.335878  0.416404  0.371831      317
# style_Color_Field_Painting           0.560647  0.656151  0.604651      317
# style_Cubism                         0.375622  0.476341  0.420028      317
# style_Early_Renaissance              0.453453  0.476341  0.464615      317
# style_Expressionism                  0.295359  0.220820  0.252708      317
# style_High_Renaissance               0.358730  0.357595  0.358162      316
# style_Impressionism                  0.428571  0.482650  0.454006      317
# style_Magic_Realism                  0.390110  0.447950  0.417034      317
# style_Mannerism_(Late_Renaissance)   0.370262  0.400631  0.384848      317
# style_Minimalism                     0.471739  0.684543  0.558559      317
# style_Nave_Art_(Primitivism)         0.259386  0.239748  0.249180      317
# style_Neoclassicism                  0.518828  0.391167  0.446043      317
# style_Northern_Renaissance           0.420561  0.425868  0.423197      317
# style_Pop_Art                        0.380000  0.359621  0.369530      317
# style_Post-Impressionism             0.369478  0.290221  0.325088      317
# style_Realism                        0.342756  0.305994  0.323333      317
# style_Rococo                         0.472393  0.485804  0.479005      317
# style_Romanticism                    0.391667  0.296530  0.337522      317
# style_Surrealism                     0.269231  0.220820  0.242634      317
# style_Symbolism                      0.330189  0.331230  0.330709      317
# style_Ukiyo-e                        0.650667  0.769716  0.705202      317
# accuracy: 0.388566380616
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************fusion_wikipaintings_oct25,pascal_mc_for_fusion_wikipaintings_oct25 fp vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                                     precision    recall  f1-score  support
# style_Abstract_Art                   0.569536  0.271293  0.367521      317
# style_Abstract_Expressionism         0.364829  0.438486  0.398281      317
# style_Art_Informel                   0.348993  0.164038  0.223176      317
# style_Art_Nouveau_(Modern)           0.422969  0.476341  0.448071      317
# style_Baroque                        0.436261  0.485804  0.459701      317
# style_Color_Field_Painting           0.692308  0.652997  0.672078      317
# style_Cubism                         0.527157  0.520505  0.523810      317
# style_Early_Renaissance              0.653543  0.523659  0.581436      317
# style_Expressionism                  0.298667  0.353312  0.323699      317
# style_High_Renaissance               0.533981  0.348101  0.421456      316
# style_Impressionism                  0.534161  0.542587  0.538341      317
# style_Magic_Realism                  0.666667  0.391167  0.493042      317
# style_Mannerism_(Late_Renaissance)   0.559671  0.429022  0.485714      317
# style_Minimalism                     0.603077  0.618297  0.610592      317
# style_Nave_Art_(Primitivism)         0.513043  0.372240  0.431444      317
# style_Neoclassicism                  0.661290  0.517350  0.580531      317
# style_Northern_Renaissance           0.568966  0.520505  0.543657      317
# style_Pop_Art                        0.563380  0.378549  0.452830      317
# style_Post-Impressionism             0.334066  0.479495  0.393782      317
# style_Realism                        0.285171  0.473186  0.355872      317
# style_Rococo                         0.634752  0.564669  0.597663      317
# style_Romanticism                    0.408360  0.400631  0.404459      317
# style_Surrealism                     0.216825  0.577287  0.315245      317
# style_Symbolism                      0.365269  0.384858  0.374808      317
# style_Ukiyo-e                        0.924188  0.807571  0.861953      317
# accuracy: 0.467693084301
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************mc_bit False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                                     precision    recall  f1-score  support
# style_Abstract_Art                   0.399194  0.312303  0.350442      317
# style_Abstract_Expressionism         0.338710  0.397476  0.365747      317
# style_Art_Informel                   0.328638  0.220820  0.264151      317
# style_Art_Nouveau_(Modern)           0.412791  0.447950  0.429652      317
# style_Baroque                        0.393491  0.419558  0.406107      317
# style_Color_Field_Painting           0.598901  0.687697  0.640235      317
# style_Cubism                         0.417910  0.529968  0.467316      317
# style_Early_Renaissance              0.497238  0.567823  0.530191      317
# style_Expressionism                  0.294737  0.353312  0.321377      317
# style_High_Renaissance               0.376238  0.360759  0.368336      316
# style_Impressionism                  0.392638  0.605678  0.476427      317
# style_Magic_Realism                  0.591928  0.416404  0.488889      317
# style_Mannerism_(Late_Renaissance)   0.448171  0.463722  0.455814      317
# style_Minimalism                     0.531977  0.577287  0.553707      317
# style_Nave_Art_(Primitivism)         0.423488  0.375394  0.397993      317
# style_Neoclassicism                  0.682464  0.454259  0.545455      317
# style_Northern_Renaissance           0.469388  0.507886  0.487879      317
# style_Pop_Art                        0.518367  0.400631  0.451957      317
# style_Post-Impressionism             0.419753  0.321767  0.364286      317
# style_Realism                        0.353312  0.353312  0.353312      317
# style_Rococo                         0.508065  0.596215  0.548621      317
# style_Romanticism                    0.425373  0.359621  0.389744      317
# style_Surrealism                     0.339695  0.280757  0.307427      317
# style_Symbolism                      0.385057  0.422713  0.403008      317
# style_Ukiyo-e                        0.824074  0.842271  0.833073      317
# accuracy: 0.451034830893
#
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************random********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                                     precision    recall  f1-score  support
# style_Abstract_Art                   0.025070  0.028391  0.026627      317
# style_Abstract_Expressionism         0.044218  0.041009  0.042553      317
# style_Art_Informel                   0.042169  0.044164  0.043143      317
# style_Art_Nouveau_(Modern)           0.036011  0.041009  0.038348      317
# style_Baroque                        0.044728  0.044164  0.044444      317
# style_Color_Field_Painting           0.023649  0.022082  0.022838      317
# style_Cubism                         0.061594  0.053628  0.057336      317
# style_Early_Renaissance              0.024390  0.022082  0.023179      317
# style_Expressionism                  0.034014  0.031546  0.032733      317
# style_High_Renaissance               0.062500  0.066456  0.064417      316
# style_Impressionism                  0.021472  0.022082  0.021773      317
# style_Magic_Realism                  0.028846  0.028391  0.028617      317
# style_Mannerism_(Late_Renaissance)   0.040134  0.037855  0.038961      317
# style_Minimalism                     0.027190  0.028391  0.027778      317
# style_Nave_Art_(Primitivism)         0.037249  0.041009  0.039039      317
# style_Neoclassicism                  0.036697  0.037855  0.037267      317
# style_Northern_Renaissance           0.039474  0.037855  0.038647      317
# style_Pop_Art                        0.034985  0.037855  0.036364      317
# style_Post-Impressionism             0.027972  0.025237  0.026534      317
# style_Realism                        0.054878  0.056782  0.055814      317
# style_Rococo                         0.046875  0.047319  0.047096      317
# style_Romanticism                    0.022654  0.022082  0.022364      317
# style_Surrealism                     0.023026  0.022082  0.022544      317
# style_Symbolism                      0.056426  0.056782  0.056604      317
# style_Ukiyo-e                        0.037618  0.037855  0.037736      317
# accuracy: 0.0373548712771
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])

# %%
conf_df = mc_metrics['feat_metrics']['fusion_wikipaintings_oct25,pascal_mc_for_fusion_wikipaintings_oct25 fp vw']['conf_df'].astype(float)
conf_df.index = [x.replace('style_', '') for x in conf_df.index]
conf_df.columns = [x.replace('style_', '') for x in conf_df.columns]
fig = vislab.dataset_viz.plot_conditional_occurrence(conf_df, sort_by_prior=False, font_size=16)
fig.savefig('/Users/sergeyk/work/aphrodite-writeup/figures/evaluation/wikipaintings_conf.pdf', bbox_inches='tight')

# %%
leg = fig.get_axes()[0].get_legend()
leg.get_
# Out:
# <a list of 0 Patch objects>

# %%
acc_df = mc_metrics['acc_df']
fig = vislab.results_viz.plot_top_k_accuracies(acc_df, font_size=16)
fig.savefig('/Users/sergeyk/work/aphrodite-writeup/figures/evaluation/wikipaintings_top_k.pdf', bbox_inches='tight')

# %%
ap_df = mc_metrics['ap_df']
column_order = ap_df.columns[(-ap_df.ix['_mean']).argsort().values]
ap_df.index = [x.replace('style_', '') for x in ap_df.index]
ap_df = ap_df.reindex_axis(column_order, axis=1)
ap_df.to_csv('/Users/sergeyk/work/aphrodite-writeup/results/wikipaintings_ap_df.csv')
fig = vislab.results_viz.plot_df_bar(ap_df, fontsize=14)
fig.savefig('/Users/sergeyk/work/aphrodite-writeup/figures/wikipaintings_ap_barplot.pdf', bbox_inches='tight')

# %%
ap_df
# Out:
#                              Late-fusion x Content     MC-bit    DeCAF_6  \
# Abstract_Art                             0.3563449  0.3211417  0.2581126
# Abstract_Expressionism                   0.3661094  0.3391885  0.2427984
# Art_Informel                             0.2117311  0.2336025  0.1873358
# Art_Nouveau_(Modern)                      0.445623  0.4039234  0.1966565
# Baroque                                  0.4267142  0.3755243   0.313266
# Color_Field_Painting                     0.7662422  0.7459669  0.6889791
# Cubism                                   0.5258076  0.4913361  0.3998066
# Early_Renaissance                        0.5860306  0.5508155  0.4531317
# Expressionism                             0.283536  0.2378924  0.1862808
# High_Renaissance                          0.403771  0.3352285  0.2878271
# Impressionism                            0.5404505  0.5248633  0.4112192
# Magic_Realism                            0.5135299   0.471549   0.427639
# Mannerism_(Late_Renaissance)              0.512122  0.4425603  0.3562755
# Minimalism                               0.6591307  0.6191386  0.6035631
# Nave_Art_(Primitivism)                   0.3936707  0.3721455  0.2249727
# Neoclassicism                            0.5986298  0.5661973  0.3986599
# Northern_Renaissance                     0.5312522   0.478448  0.4329004
# Pop_Art                                   0.432155  0.3801613  0.2807598
# Post-Impressionism                        0.402949   0.381129  0.2921657
# Realism                                  0.3729811  0.3490049   0.265889
# Rococo                                   0.5925264  0.5731982  0.4674117
# Romanticism                              0.3911398  0.3755905  0.3433306
# Surrealism                               0.2968617  0.2478703  0.1338807
# Symbolism                                 0.392941  0.3640179  0.2596021
# Ukiyo-e                                  0.9002495  0.8885023  0.7879372
# _mean                                       0.4761  0.4427598  0.3560161
#
#                              Fine-tuned DeCAF_6      random
# Abstract_Art                          0.2331097  0.04275982
# Abstract_Expressionism                0.2158403  0.04427343
# Art_Informel                          0.1547321  0.04124597
# Art_Nouveau_(Modern)                  0.1964268  0.04227236
# Baroque                               0.3195557  0.04384674
# Color_Field_Painting                  0.7012525  0.04127457
# Cubism                                0.4300739  0.04534463
# Early_Renaissance                     0.4398357  0.04298916
# Expressionism                         0.1750504  0.04444291
# High_Renaissance                      0.2803096  0.04830206
# Impressionism                         0.4607092  0.04363579
# Magic_Realism                         0.4340241  0.04219277
# Mannerism_(Late_Renaissance)          0.3541729  0.04357005
# Minimalism                            0.6290553  0.04161259
# Nave_Art_(Primitivism)                0.1949905  0.04192393
# Neoclassicism                         0.4466457  0.04398899
# Northern_Renaissance                  0.3500666  0.04487364
# Pop_Art                               0.3136232  0.04261911
# Post-Impressionism                    0.3049723   0.0425742
# Realism                               0.2674738    0.046111
# Rococo                                0.4956692  0.04732547
# Romanticism                           0.2996733  0.04151203
# Surrealism                             0.161018  0.04310067
# Symbolism                             0.2798516  0.04414564
# Ukiyo-e                               0.7591923  0.04578235
# _mean                                  0.355893   0.0436688
