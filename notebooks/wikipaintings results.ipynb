# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import sklearn.metrics
import pandas as pd

import vislab
import vislab.datasets.wikipaintings as wikipaintings

# %%
df = wikipaintings.get_detailed_dataset()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103693 entries, paul-reed_12-1964 to xu-hongming_-1996-2
# Data columns (total 11 columns):
# image_id        103693  non-null values
# artist_slug     103693  non-null values
# artwork_slug    103693  non-null values
# date            78174  non-null values
# genre           101965  non-null values
# style           102382  non-null values
# technique       41107  non-null values
# keywords        59819  non-null values
# name            103693  non-null values
# page_url        103693  non-null values
# image_url       103693  non-null values
# dtypes: object(11)

# %%
label_df = wikipaintings.get_style_dataset()

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'wikipaintings_sep26', '/Users/sergeyk/work/aphrodite-dev/data/results/', force=False)
preds_panel
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 22 (items) x 70344 (major_axis) x 4 (minor_axis)
# Items axis: clf wikipaintings_style_style_Abstract_Art to clf wikipaintings_style_style_Ukiyo-e
# Major_axis axis: a-y-jackson_algoma-in-november-1935 to zinaida-serebriakova_young-moroccan-1932
# Minor_axis axis: decaf_fc6  vw to split

# %%
preds_panel.major_xs('a-y-jackson_algoma-in-november-1935')['clf wikipaintings_style_style_Abstract_Art']
# Out:
# decaf_fc6  vw   -0.6192468
# label                   -1
# noise  vw              NaN
# split                train
# Name: clf wikipaintings_style_style_Abstract_Art, dtype: object

# %% [markdown]
# ## Binary metrics

# %%
selected_score = 'decaf_fc6  vw'
pred_prefix = 'clf wikipaintings_style'
label = 'style_Abstract_Art'

pred_df = preds_panel['{}_{}'.format(pred_prefix, label)]
pred_df['pred'] = pred_df[selected_score]
pred_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70344 entries, a-y-jackson_algoma-in-november-1935 to zinaida-serebriakova_young-moroccan-1932
# Data columns (total 5 columns):
# decaf_fc6  vw    70292  non-null values
# label            70292  non-null values
# noise  vw        0  non-null values
# split            70292  non-null values
# pred             70292  non-null values
# dtypes: object(5)

# %%
balanced_binary_metrics = vislab.results.binary_metrics(pred_df, 'style_Abstract_Art balanced', True)
# Out:
# ------------------------------------------------------------
# Classification metrics on the {} balanced balanced
#        precision    recall  f1-score  support
# False   0.934509  0.838418  0.883859      885
# True    0.853484  0.941243  0.895218      885
# Accuracy: 0.889830508475
# Matthews' Correlation Coefficient: 0.783815650273

# %%
full_binary_metrics = vislab.results.binary_metrics(pred_df, 'style_Abstract_Art full', False)
# Out:
# ------------------------------------------------------------
# Classification metrics on the {} full full
#        precision    recall  f1-score  support
# False   0.999094  0.826530  0.904657    69407
# True    0.064709  0.941243  0.121093      885
# Accuracy: 0.827974733967
# Matthews' Correlation Coefficient: 0.221329161326

# %% [markdown]
# ## Multiclass metrics

# %%
mc_pred_df = preds_panel.minor_xs('decaf_fc6  vw').join(label_df)

# %%
balanced_mc_metrics = vislab.results.multiclass_metrics(mc_pred_df, 'clf wikipaintings_style', balanced=True)
# Out:
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
#                               precision    recall  f1-score  support
# style_Abstract_Art             0.344428  0.279015  0.308290      853
# style_Abstract_Expressionism   0.256459  0.314185  0.282403      853
# style_Art_Informel             0.334471  0.344666  0.339492      853
# style_Baroque                  0.402637  0.465416  0.431756      853
# style_Color_Field_Painting     0.479147  0.606096  0.535197      853
# style_Cubism                   0.278063  0.444314  0.342058      853
# style_Early_Renaissance        0.412281  0.550996  0.471651      853
# style_Expressionism            0.288401  0.215709  0.246814      853
# style_High_Renaissance         0.395808  0.376319  0.385817      853
# style_Impressionism            0.494289  0.558030  0.524229      853
# style_Magic_Realism            0.550296  0.436108  0.486593      853
# style_Minimalism               0.510907  0.521688  0.516241      853
# style_Neoclassicism            0.564626  0.389215  0.460791      853
# style_Northern_Renaissance     0.420738  0.494725  0.454741      853
# style_Pop_Art                  0.482240  0.413834  0.445426      853
# style_Post-Impressionism       0.391221  0.240328  0.297749      853
# style_Realism                  0.370817  0.324736  0.346250      853
# style_Rococo                   0.496902  0.470106  0.483133      853
# style_Romanticism              0.368272  0.304807  0.333547      853
# style_Surrealism               0.281553  0.237984  0.257942      853
# style_Symbolism                0.313406  0.202814  0.246263      853
# style_Ukiyo-e                  0.513666  0.749121  0.609442      853
# Accuracy: 0.406373228179

# %%
full_mc_metrics = vislab.results.multiclass_metrics(mc_pred_df, 'clf wikipaintings_style', balanced=False)
# Out:
# ------------------------------------------------------------
# Classification metrics on the full dataset
#                               precision    recall  f1-score  support
# style_Abstract_Art             0.189522  0.277339  0.225172      887
# style_Abstract_Expressionism   0.240659  0.332658  0.279277     1975
# style_Art_Informel             0.166585  0.345566  0.224801      981
# style_Baroque                  0.435479  0.474291  0.454057     3209
# style_Color_Field_Painting     0.444183  0.612146  0.514811     1235
# style_Cubism                   0.174374  0.425914  0.247443     1505
# style_Early_Renaissance        0.210058  0.547237  0.303585     1122
# style_Expressionism            0.401263  0.215524  0.280427     5308
# style_High_Renaissance         0.171324  0.371400  0.234483     1007
# style_Impressionism            0.674125  0.558219  0.610721    11388
# style_Magic_Realism            0.258940  0.441640  0.326467      951
# style_Minimalism               0.318000  0.519608  0.394541      918
# style_Neoclassicism            0.337150  0.387427  0.360544     1368
# style_Northern_Renaissance     0.326612  0.501523  0.395596     1970
# style_Pop_Art                  0.262454  0.413834  0.321201      853
# style_Post-Impressionism       0.392057  0.236790  0.295255     5545
# style_Realism                  0.533109  0.321235  0.400900     8872
# style_Rococo                   0.282571  0.479853  0.355688     1365
# style_Romanticism              0.453537  0.311310  0.369200     5252
# style_Surrealism               0.413317  0.242554  0.305706     4197
# style_Symbolism                0.295106  0.222160  0.253489     3556
# style_Ukiyo-e                  0.203890  0.747986  0.320434      869
# Accuracy: 0.378172943901
