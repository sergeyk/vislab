# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import sklearn.metrics
import pandas as pd

import vislab
import vislab.results
import vislab.datasets.wikipaintings as wikipaintings

# %%
label_df = wikipaintings.get_style_df()

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'wikipaintings_sep26', '/Users/sergeyk/work/aphrodite/data/results/', force=False)
pred_prefix = 'clf wikipaintings_style'
print preds_panel.minor_axis
# Out:
# Loaded from cache: 23 records
# Index([u'decaf_fc6  vw', u'label', u'noise  vw', u'split'], dtype='object')

# %%
preds_panel.major_xs('a-y-jackson_algoma-in-november-1935')['clf wikipaintings_style_style_Abstract_Art']
# Out:
# decaf_fc6  vw   -0.6192468
# label                   -1
# noise  vw              NaN
# split                train
# Name: clf wikipaintings_style_style_Abstract_Art, dtype: object

# %% [markdown]
# ## Multiclass metrics

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=['decaf_fc6  vw', '_random'],
    balanced=True, with_plot=True, with_print=True)
# Out:
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.412
# 2     0.619
# 3     0.745
# 4     0.822
# 5     0.875
# 6     0.909
# 7     0.934
# 8     0.949
# 9     0.960
# 10    0.969
# 11    0.977
# 12    0.983
# 13    0.987
# 14    0.990
# 15    0.993
# 16    0.995
# 17    0.996
# 18    0.997
# 19    0.998
# 20    0.999
# 21    1.000
# 22    1.000
# dtype: float64
#                               precision    recall  f1-score  support
# style_Abstract_Art             0.348703  0.283705  0.312864      853
# style_Abstract_Expressionism   0.282353  0.337632  0.307528      853
# style_Art_Informel             0.341743  0.349355  0.345507      853
# style_Baroque                  0.409137  0.472450  0.438520      853
# style_Color_Field_Painting     0.504210  0.631887  0.560874      853
# style_Cubism                   0.282949  0.445487  0.346084      853
# style_Early_Renaissance        0.423043  0.563892  0.483417      853
# style_Expressionism            0.270701  0.199297  0.229575      853
# style_High_Renaissance         0.384154  0.375147  0.379597      853
# style_Impressionism            0.504167  0.567409  0.533922      853
# style_Magic_Realism            0.557037  0.440797  0.492147      853
# style_Minimalism               0.498331  0.525205  0.511416      853
# style_Neoclassicism            0.555366  0.382181  0.452778      853
# style_Northern_Renaissance     0.420488  0.505275  0.458999      853
# style_Pop_Art                  0.480926  0.413834  0.444865      853
# style_Post-Impressionism       0.376648  0.234467  0.289017      853
# style_Realism                  0.377537  0.327081  0.350503      853
# style_Rococo                   0.522876  0.468933  0.494438      853
# style_Romanticism              0.387574  0.307151  0.342708      853
# style_Surrealism               0.283310  0.236811  0.257982      853
# style_Symbolism                0.332784  0.236811  0.276712      853
# style_Ukiyo-e                  0.501570  0.749121  0.600846      853
# accuracy: 0.411542150698
#
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: 1     0.045
# 2     0.091
# 3     0.138
# 4     0.183
# 5     0.227
# 6     0.271
# 7     0.317
# 8     0.364
# 9     0.413
# 10    0.458
# 11    0.503
# 12    0.549
# 13    0.591
# 14    0.634
# 15    0.680
# 16    0.726
# 17    0.771
# 18    0.816
# 19    0.862
# 20    0.906
# 21    0.955
# 22    1.000
# dtype: float64
#                               precision    recall  f1-score  support
# style_Abstract_Art             0.058894  0.057444  0.058160      853
# style_Abstract_Expressionism   0.049757  0.048066  0.048897      853
# style_Art_Informel             0.049312  0.050410  0.049855      853
# style_Baroque                  0.037215  0.036342  0.036773      853
# style_Color_Field_Painting     0.047450  0.046893  0.047170      853
# style_Cubism                   0.042269  0.044549  0.043379      853
# style_Early_Renaissance        0.035842  0.035170  0.035503      853
# style_Expressionism            0.041081  0.044549  0.042745      853
# style_High_Renaissance         0.046512  0.046893  0.046702      853
# style_Impressionism            0.031566  0.029308  0.030395      853
# style_Magic_Realism            0.048110  0.049238  0.048667      853
# style_Minimalism               0.039648  0.042204  0.040886      853
# style_Neoclassicism            0.049587  0.049238  0.049412      853
# style_Northern_Renaissance     0.054245  0.053927  0.054086      853
# style_Pop_Art                  0.047558  0.043376  0.045371      853
# style_Post-Impressionism       0.040745  0.041032  0.040888      853
# style_Realism                  0.049412  0.049238  0.049325      853
# style_Rococo                   0.045564  0.044549  0.045050      853
# style_Romanticism              0.045045  0.046893  0.045951      853
# style_Surrealism               0.045508  0.045721  0.045614      853
# style_Symbolism                0.044289  0.044549  0.044418      853
# style_Ukiyo-e                  0.042403  0.042204  0.042303      853
# accuracy: 0.0450815304274

# %%
balanced_mc_metrics = vislab.results.multiclass_metrics(
    mc_pred_df, pred_prefix, balanced=True,
    with_plot=True, with_print=True)
# Out:
# ------------------------------------------------------------
# Classification metrics on the balanced dataset
# top_k_accuracies: [0.408, 0.619, 0.739, 0.82, 0.875, 0.91, 0.935, 0.95, 0.961, 0.97, 0.978, 0.984, 0.988, 0.991, 0.993, 0.995, 0.996, 0.997, 0.999, 0.999, 1.0, 1.0]
#                               precision    recall  f1-score  support
# style_Abstract_Art             0.346821  0.281360  0.310680      853
# style_Abstract_Expressionism   0.267051  0.325909  0.293559      853
# style_Art_Informel             0.328211  0.350528  0.339002      853
# style_Baroque                  0.399797  0.460727  0.428105      853
# style_Color_Field_Painting     0.490619  0.613130  0.545076      853
# style_Cubism                   0.280560  0.446659  0.344640      853
# style_Early_Renaissance        0.406393  0.521688  0.456879      853
# style_Expressionism            0.308050  0.233294  0.265510      853
# style_High_Renaissance         0.398726  0.366940  0.382173      853
# style_Impressionism            0.481328  0.543962  0.510732      853
# style_Magic_Realism            0.566517  0.444314  0.498029      853
# style_Minimalism               0.517634  0.533411  0.525404      853
# style_Neoclassicism            0.544688  0.378664  0.446750      853
# style_Northern_Renaissance     0.402498  0.491208  0.442450      853
# style_Pop_Art                  0.480272  0.413834  0.444584      853
# style_Post-Impressionism       0.372007  0.236811  0.289398      853
# style_Realism                  0.385827  0.344666  0.364087      853
# style_Rococo                   0.534483  0.472450  0.501556      853
# style_Romanticism              0.393020  0.303634  0.342593      853
# style_Surrealism               0.274725  0.234467  0.253004      853
# style_Symbolism                0.317195  0.222743  0.261708      853
# style_Ukiyo-e                  0.505146  0.747948  0.603025      853
# accuracy: 0.407652136843

# %% [markdown]
# ### Unbalanced dataset: classes have uneven representation.

# %%
full_mc_metrics = vislab.results.multiclass_metrics(
    mc_pred_df, 'clf wikipaintings_style', balanced=False,
    with_plot=True, with_print=True)
# Out:
# ------------------------------------------------------------
# Classification metrics on the full dataset
# top_k_accuracies: [0.378, 0.579, 0.703, 0.787, 0.846, 0.887, 0.917, 0.937, 0.953, 0.965, 0.975, 0.982, 0.987, 0.99, 0.993, 0.995, 0.997, 0.998, 0.999, 0.999, 1.0, 1.0]
#                               precision    recall  f1-score  support
# style_Abstract_Art             0.187833  0.278467  0.224342      887
# style_Abstract_Expressionism   0.240659  0.332658  0.279277     1975
# style_Art_Informel             0.166585  0.345566  0.224801      981
# style_Baroque                  0.435479  0.474291  0.454057     3209
# style_Color_Field_Painting     0.444183  0.612146  0.514811     1235
# style_Cubism                   0.174374  0.425914  0.247443     1505
# style_Early_Renaissance        0.210058  0.547237  0.303585     1122
# style_Expressionism            0.401263  0.215524  0.280427     5308
# style_High_Renaissance         0.170854  0.371400  0.234043     1007
# style_Impressionism            0.674125  0.558219  0.610721    11388
# style_Magic_Realism            0.258621  0.441640  0.326214      951
# style_Minimalism               0.318000  0.519608  0.394541      918
# style_Neoclassicism            0.337150  0.387427  0.360544     1368
# style_Northern_Renaissance     0.326612  0.501523  0.395596     1970
# style_Pop_Art                  0.262454  0.413834  0.321201      853
# style_Post-Impressionism       0.392057  0.236790  0.295255     5545
# style_Realism                  0.533109  0.321235  0.400900     8872
# style_Rococo                   0.282571  0.479853  0.355688     1365
# style_Romanticism              0.457247  0.310548  0.369883     5252
# style_Surrealism               0.415171  0.242554  0.306211     4197
# style_Symbolism                0.295106  0.222160  0.253489     3556
# style_Ukiyo-e                  0.202366  0.747986  0.318549      869
# accuracy: 0.378126311535
