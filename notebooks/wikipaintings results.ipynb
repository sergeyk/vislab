# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import sklearn.metrics
import pandas as pd

import vislab
import vislab.results
import vislab.datasets.wikipaintings as wikipaintings
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
label_df = wikipaintings.get_style_df()

# %%
c = vislab.util.get_mongodb_client()['predict']['wikipaintings_oct25']
if c.find({'features': 'noise'}).count() > 0:
    c.remove({'features': 'noise'})
pd.DataFrame([x for x in c.find()])
# Out:
#                         _id                     data     features  num_test  \
# 0  526b20719622958641aab77a  wikipaintings_style_ALL  [decaf_fc6]     16492
# 1  526bafe39622958641aab77b  wikipaintings_style_ALL     [mc_bit]     16492
#
#    num_train  num_val quadratic  \
# 0      49475    16492     False
# 1      49475    16492     False
#
#                                         results_name  score_test  score_val  \
# 0  data_wikipaintings_style_ALL_features_['decaf_...    0.383014   0.595281
# 1  data_wikipaintings_style_ALL_features_['mc_bit...    0.453180   0.728084
#
#   task
# 0  clf
# 1  clf

# %%
results_df, preds_panel = aphrodite.results.load_pred_results(
    'wikipaintings_oct25', '/Users/sergeyk/work/aphrodite/data/results2/', multiclass=True, force=True)
pred_prefix = 'pred'
print preds_panel.minor_axis
# Out:
# Results in collection wikipaintings_oct25: 2
# Index([u'decaf_fc6 False vw', u'mc_bit False vw'], dtype='object')

# %%
# OLD!
results_df, preds_panel = aphrodite.results.load_pred_results(
    'wikipaintings_sep26', '/Users/sergeyk/work/aphrodite/data/results/', force=False)
pred_prefix = 'clf wikipaintings_style'
print preds_panel.minor_axis
# Out:
# Loaded from cache: 23 records
# Index([u'decaf_fc6  vw', u'label', u'noise  vw', u'split'], dtype='object')

# %% [markdown]
# ## Multiclass metrics

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=preds_panel.minor_axis.tolist() + ['random'],
    balanced=True, with_plot=True, with_print=True)
# Out:
# Looks like the preds frame already has gt info.
# ********************decaf_fc6 False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                                     precision    recall  f1-score  support
# style_Abstract_Art                   0.491566  0.412121  0.448352      990
# style_Abstract_Expressionism         0.396190  0.419778  0.407643      991
# style_Art_Informel                   0.410891  0.418769  0.414793      991
# style_Art_Nouveau_(Modern)           0.360768  0.265388  0.305814      991
# style_Baroque                        0.412861  0.447023  0.429264      991
# style_Color_Field_Painting           0.573608  0.758829  0.653345      991
# style_Cubism                         0.444444  0.613522  0.515473      991
# style_Early_Renaissance              0.525145  0.547931  0.536296      991
# style_Expressionism                  0.338789  0.208880  0.258427      991
# style_High_Renaissance               0.454545  0.474268  0.464198      991
# style_Impressionism                  0.484574  0.538850  0.510272      991
# style_Magic_Realism                  0.444992  0.547475  0.490942      990
# style_Mannerism_(Late_Renaissance)   0.487850  0.526741  0.506550      991
# style_Minimalism                     0.538462  0.685166  0.603020      991
# style_Nave_Art_(Primitivism)         0.398664  0.361251  0.379037      991
# style_Impressionism                  0.042424  0.042381  0.042403      991
# style_Magic_Realism                  0.047523  0.047475  0.047499      990
# style_Mannerism_(Late_Renaissance)   0.050050  0.050454  0.050251      991
# style_Minimalism                     0.044643  0.045409  0.045023      991
# style_Nave_Art_(Primitivism)         0.043393  0.044400  0.043890      991
# style_Neoclassicism                  0.040837  0.041372  0.041103      991
# style_Northern_Renaissance           0.039354  0.039354  0.039354      991
# style_Pop_Art                        0.047109  0.044400  0.045714      991
# style_Post-Impressionism             0.044489  0.044400  0.044444      991
# style_Realism                        0.037328  0.038345  0.037830      991
# style_Rococo                         0.035749  0.037336  0.036525      991
# style_Romanticism                    0.034304  0.033300  0.033794      991
# style_Surrealism                     0.028311  0.028254  0.028283      991
# style_Symbolism                      0.030422  0.031282  0.030846      991
# style_Ukiyo-e                        0.037717  0.037336  0.037525      991
# accuracy: 0.0403261615468
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])

# %% [markdown]
# ### Unbalanced dataset: classes have uneven representation.

# %%
full_mc_metrics = vislab.results.multiclass_metrics(
    mc_pred_df, 'clf wikipaintings_style', balanced=False,
    with_plot=True, with_print=True)
# Out:
# ------------------------------------------------------------
# Classification metrics on the full dataset
# top_k_accuracies: [0.378, 0.579, 0.703, 0.787, 0.846, 0.887, 0.917, 0.937, 0.953, 0.965, 0.975, 0.982, 0.987, 0.99, 0.993, 0.995, 0.997, 0.998, 0.999, 0.999, 1.0, 1.0]
#                               precision    recall  f1-score  support
# style_Abstract_Art             0.187833  0.278467  0.224342      887
# style_Abstract_Expressionism   0.240659  0.332658  0.279277     1975
# style_Art_Informel             0.166585  0.345566  0.224801      981
# style_Baroque                  0.435479  0.474291  0.454057     3209
# style_Color_Field_Painting     0.444183  0.612146  0.514811     1235
# style_Cubism                   0.174374  0.425914  0.247443     1505
# style_Early_Renaissance        0.210058  0.547237  0.303585     1122
# style_Expressionism            0.401263  0.215524  0.280427     5308
# style_High_Renaissance         0.170854  0.371400  0.234043     1007
# style_Impressionism            0.674125  0.558219  0.610721    11388
# style_Magic_Realism            0.258621  0.441640  0.326214      951
# style_Minimalism               0.318000  0.519608  0.394541      918
# style_Neoclassicism            0.337150  0.387427  0.360544     1368
# style_Northern_Renaissance     0.326612  0.501523  0.395596     1970
# style_Pop_Art                  0.262454  0.413834  0.321201      853
# style_Post-Impressionism       0.392057  0.236790  0.295255     5545
# style_Realism                  0.533109  0.321235  0.400900     8872
# style_Rococo                   0.282571  0.479853  0.355688     1365
# style_Romanticism              0.457247  0.310548  0.369883     5252
# style_Surrealism               0.415171  0.242554  0.306211     4197
# style_Symbolism                0.295106  0.222160  0.253489     3556
# style_Ukiyo-e                  0.202366  0.747986  0.318549      869
# accuracy: 0.378126311535
