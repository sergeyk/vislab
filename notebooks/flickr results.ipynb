# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import sklearn.metrics
import pandas as pd
import vislab.datasets
import vislab.results

# %%
label_df = vislab.datasets.flickr.load_flickr_df()

# %%
c = vislab.util.get_mongodb_client()['predict']['flickr_oct26']
if c.find({'features': 'noise'}).count() > 0:
    c.remove({'features': 'noise'})
pd.DataFrame([x for x in c.find()])
# Out:
#                         _id              data             features  num_test  \
# 0  526ce38a9622958641aaee52  flickr_style_ALL          [decaf_fc6]     10525
# 1  526cf7179622958641aaee53  flickr_style_ALL             [mc_bit]     10525
# 2  526da6289622958641aaee54  flickr_style_ALL  [decaf_fc6_flatten]     10525
#
#    num_train  num_val quadratic  \
# 0      29633    10040     False
# 1      29633    10040     False
# 2      29633    10040     False
#
#                                         results_name  score_test  score_val  \
# 0  data_flickr_style_ALL_features_['decaf_fc6']_n...    0.420880   0.495051
# 1  data_flickr_style_ALL_features_['mc_bit']_num_...    0.279248   0.399438
# 2  data_flickr_style_ALL_features_['decaf_fc6_fla...    0.366759   0.540157
#
#   task
# 0  clf
# 1  clf
# 2  clf

# %%
df, preds_panel = aphrodite.results.load_pred_results(
    'flickr_oct26', '/Users/sergeyk/work/aphrodite/data/results2', multiclass=True, force=True)
pred_prefix = 'pred'
print preds_panel.minor_axis
# Out:
# Results in collection flickr_oct26: 3
# Index([u'decaf_fc6 False vw', u'decaf_fc6_flatten False vw', u'mc_bit False vw'], dtype='object')

# %%
# OLD!
df, preds_panel = aphrodite.results.load_pred_results(
    'aug29', '/Users/sergeyk/work/ aphrodite/data/results', force=False)
pred_prefix = 'clf flickr_style'
print preds_panel.minor_axis
# Out:
# Loaded from cache: 136 records

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=preds_panel.minor_axis.tolist() + ['_random'],
    balanced=True, with_plot=True, with_print=True)
# Out:
# Looks like the preds frame already has gt info.
# ********************decaf_fc6 False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                              precision    recall  f1-score  support
# style_Bright,_Energetic       0.463785  0.408893  0.434613     2991
# style_Depth_of_Field          0.372788  0.321683  0.345355     2947
# style_Ethereal                0.462131  0.461358  0.461745     2989
# style_Geometric_Composition   0.463288  0.480944  0.471951     2965
# style_HDR                     0.502076  0.568693  0.533312     2977
# style_Hazy                    0.490353  0.598788  0.539173     2971
# style_Horror                  0.508499  0.480107  0.493895     2991
# style_Long_Exposure           0.478289  0.505133  0.491345     2922
# style_Macro                   0.621003  0.761663  0.684179     2958
# style_Melancholy              0.343410  0.195390  0.249068     2907
# style_Minimal                 0.452143  0.575300  0.506341     2915
# style_Noir                    0.490308  0.634448  0.553142     2990
# style_Romantic                0.329724  0.205882  0.253486     2958
# style_Serene                  0.367631  0.234932  0.286669     2920
# style_Soft,_Pastel            0.371074  0.329904  0.349280     2722
# style_Sunny                   0.527103  0.633311  0.575347     2948
# style_Vintage                 0.455542  0.514047  0.483030     2990
# accuracy: 0.466470905495
#
# Looks like the preds frame already has gt info.
# ********************decaf_fc6_flatten False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                              precision    recall  f1-score  support
# style_Bright,_Energetic       0.763903  0.243316  0.369075     2992
# style_Depth_of_Field          0.696095  0.139125  0.231900     2947
# style_Ethereal                0.785489  0.249916  0.379188     2989
# style_Geometric_Composition   0.766551  0.296796  0.427912     2965
# style_HDR                     0.434962  0.672825  0.528357     2977
# style_Hazy                    0.508685  0.621003  0.559260     2971
# style_Horror                  0.582486  0.498161  0.537034     2991
# style_Long_Exposure           0.519636  0.548100  0.533489     2921
# style_Macro                   0.486951  0.832657  0.614521     2958
# style_Melancholy              0.474407  0.261438  0.337104     2907
# style_Minimal                 0.412048  0.645948  0.503143     2912
# style_Noir                    0.434873  0.771572  0.556239     2990
# style_Romantic                0.400819  0.364097  0.381577     2958
# style_Serene                  0.421509  0.283219  0.338796     2920
# style_Soft,_Pastel            0.376147  0.421904  0.397713     2721
# style_Sunny                   0.481855  0.680122  0.564074     2948
# style_Vintage                 0.464002  0.644482  0.539549     2990
# accuracy: 0.481431168468
#
# Looks like the preds frame already has gt info.
# ********************mc_bit False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                              precision    recall  f1-score  support
# style_Bright,_Energetic       0.495452  0.309699  0.381148     2990
# style_Depth_of_Field          0.432642  0.340238  0.380916     2945
# style_Ethereal                0.659574  0.238621  0.350455     2988
# style_Geometric_Composition   0.590966  0.476882  0.527830     2963
# style_HDR                     0.434954  0.742857  0.548659     2975
# style_Hazy                    0.813152  0.262378  0.396741     2969
# style_Horror                  0.755435  0.046504  0.087614     2989
# style_Long_Exposure           0.203966  0.916381  0.333666     2918
# style_Macro                   0.370878  0.943505  0.532455     2956
# style_Melancholy              0.242748  0.515840  0.330138     2904
# style_Minimal                 0.663622  0.424253  0.517603     2911
# style_Noir                    0.933054  0.074632  0.138209     2988
# style_Romantic                0.603113  0.052418  0.096453     2957
# style_Serene                  0.724382  0.070254  0.128085     2918
# style_Soft,_Pastel            0.301486  0.537528  0.386304     2718
# style_Sunny                   0.689655  0.407056  0.511945     2948
# style_Vintage                 0.873950  0.034794  0.066924     2989
# accuracy: 0.374325350818
#
# Looks like the preds frame already has gt info.
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [ True]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:275: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [ 0  1  2  3  6  7  8  9 10 11 12 13 14 16]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ 0  1  2  3  6  7  8  9 10 11 12 13 14 16].
#   y_true, y_pred)
# ********************noise False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                              precision    recall  f1-score  support
# style_Bright,_Energetic       0.000000  0.000000  0.000000     2992
# style_Depth_of_Field          0.000000  0.000000  0.000000     2949
# style_Ethereal                0.000000  0.000000  0.000000     2989
# style_Geometric_Composition   0.000000  0.000000  0.000000     2967
# style_HDR                     0.063028  0.092680  0.075031     2978
# style_Hazy                    0.059925  0.721979  0.110664     2971
# style_Horror                  0.000000  0.000000  0.000000     2991
# style_Long_Exposure           0.000000  0.000000  0.000000     2921
# style_Macro                   0.000000  0.000000  0.000000     2958
# style_Melancholy              0.000000  0.000000  0.000000     2906
# style_Minimal                 0.000000  0.000000  0.000000     2914
# style_Noir                    0.000000  0.000000  0.000000     2990
# style_Romantic                0.000000  0.000000  0.000000     2958
# style_Serene                  0.000000  0.000000  0.000000     2920
# style_Soft,_Pastel            0.000000  0.000000  0.000000     2721
# style_Sunny                   0.062089  0.208277  0.095661     2948
# style_Vintage                 0.000000  0.000000  0.000000     2990
# accuracy: 0.060623614246
#
# Looks like the preds frame already has gt info.
# ********************_random********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                              precision    recall  f1-score  support
# style_Bright,_Energetic       0.060657  0.060454  0.060555     2994
# style_Depth_of_Field          0.056466  0.054971  0.055708     2947
# style_Ethereal                0.061273  0.060535  0.060902     2990
# style_Geometric_Composition   0.064107  0.064734  0.064419     2966
# style_HDR                     0.065821  0.064473  0.065140     2978
# style_Hazy                    0.056237  0.055518  0.055875     2972
# style_Horror                  0.059044  0.057840  0.058436     2991
# style_Long_Exposure           0.052525  0.053370  0.052944     2923
# style_Macro                   0.055806  0.054429  0.055109     2958
# style_Melancholy              0.056124  0.058500  0.057287     2906
# style_Minimal                 0.056629  0.058379  0.057491     2912
# style_Noir                    0.063690  0.061538  0.062596     2990
# style_Romantic                0.057571  0.058485  0.058024     2958
# style_Serene                  0.054100  0.054452  0.054275     2920
# style_Soft,_Pastel            0.050693  0.055147  0.052826     2720
# style_Sunny                   0.053559  0.052578  0.053064     2948
# style_Vintage                 0.063274  0.061538  0.062394     2990
# accuracy: 0.0580868106186
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])
