# %%
# %load_ext autoreload
# %autoreload 2
import os
import aphrodite.results
import sklearn.metrics
import pandas as pd
import vislab.datasets
import vislab.results
# Out:
# /Users/sergeyk/anaconda/python.app/Contents/lib/python2.7/site-packages/configobj.py:145: DeprecationWarning: The compiler package is deprecated and removed in Python 3.x.
#   import compiler

# %%
label_df = vislab.datasets.flickr.load_flickr_df()

# %%
c = vislab.util.get_mongodb_client()['predict']['flickr_oct26']
if c.find({'features': 'noise'}).count() > 0:
    c.remove({'features': 'noise'})
pd.DataFrame([x for x in c.find()])
# Out:
#                         _id              data  \
# 0  526ce38a9622958641aaee52  flickr_style_ALL
# 1  526cf7179622958641aaee53  flickr_style_ALL
# 2  526da6289622958641aaee54  flickr_style_ALL
# 3  5271ce419622958641af6844  flickr_style_ALL
# 4  527250979622958641af684c  flickr_style_ALL
# 5  52729fb89622958641af6850  flickr_style_ALL
# 6  5272b5ed9622958641af6851  flickr_style_ALL
# 7  52731b769622958641b1a34c  flickr_style_ALL
# 8  527333e39622958641b1a34f  flickr_style_ALL
#
#                                             features  num_test  num_train  \
# 0                                        [decaf_fc6]     10525      29633
# 1                                           [mc_bit]     10525      29633
# 2                                [decaf_fc6_flatten]     10525      29633
# 3                                  [decaf_tuned_fc6]     10525      29633
# 4                              [fusion_flickr_oct26]     10525      29633
# 5                          [decaf_tuned_fc6_flatten]     10525      29633
# 6   [decaf_tuned_fc6, pascal_mc_for_decaf_tuned_fc6]     10525      29633
# 7  [fusion_flickr_oct26, pascal_mc_for_fusion_fli...     10525      29633
# 8                               [decaf_tuned_fc6_ud]     10525      29633
#
#    num_val quadratic                                       results_name  \
# 0    10040     False  data_flickr_style_ALL_features_['decaf_fc6']_n...
# 1    10040     False  data_flickr_style_ALL_features_['mc_bit']_num_...
# 2    10040     False  data_flickr_style_ALL_features_['decaf_fc6_fla...
# 3    10040     False  data_flickr_style_ALL_features_['decaf_tuned_f...
# 4    10040      None  data_flickr_style_ALL_features_['fusion_flickr...
# 5    10040     False  data_flickr_style_ALL_features_['decaf_tuned_f...
# 6    10040        pd  data_flickr_style_ALL_features_['decaf_tuned_f...
# 7    10040        fp  data_flickr_style_ALL_features_['fusion_flickr...
# 8    10040      None  data_flickr_style_ALL_features_['decaf_tuned_f...
#
#    score_test  score_val task
# 0    0.420880   0.495051  clf
# 1    0.279248   0.399438  clf
# 2    0.366759   0.540157  clf
# 3    0.413716   0.503487  clf
# 4    0.418018   0.634308  clf
# 5    0.350339   0.690889  clf
# 6    0.415589   0.512261  clf
# 7    0.418336   0.624072  clf
# 8    0.360898   0.473341  clf

# %%
df, preds_panel = aphrodite.results.load_pred_results(
    'flickr_oct26', os.path.expanduser('~/work/aphrodite/data/results2'),
    multiclass=True, force=True)
pred_prefix = 'pred'
print preds_panel.minor_axis
# Out:
# Results in collection flickr_oct26: 9
# Index([u'decaf_fc6 False vw', u'decaf_fc6_flatten False vw', u'decaf_tuned_fc6 False vw', u'decaf_tuned_fc6,pascal_mc_for_decaf_tuned_fc6 pd vw', u'decaf_tuned_fc6_flatten False vw', u'decaf_tuned_fc6_ud None vw', u'fusion_flickr_oct26 None vw', u'fusion_flickr_oct26,pascal_mc_for_fusion_flickr_oct26 fp vw', u'mc_bit False vw'], dtype='object')

# %%
# Select features to include.

feat_to_evaluate = [
    u'decaf_fc6 False vw',
    u'decaf_fc6_flatten False vw',
    u'decaf_tuned_fc6 False vw',
    #u'decaf_tuned_fc6,pascal_mc_for_decaf_tuned_fc6 pd vw',
    #u'decaf_tuned_fc6_flatten False vw',
    #u'decaf_tuned_fc6_ud None vw',
    #u'fusion_flickr_oct26 None vw',
    u'fusion_flickr_oct26,pascal_mc_for_fusion_flickr_oct26 fp vw',
    u'mc_bit False vw'
]
preds_panel = preds_panel.select(lambda x: x in feat_to_evaluate, 'minor')
print preds_panel.minor_axis
# Out:
# Index([u'decaf_fc6 False vw', u'decaf_fc6_flatten False vw', u'decaf_tuned_fc6 False vw', u'fusion_flickr_oct26,pascal_mc_for_fusion_flickr_oct26 fp vw', u'mc_bit False vw'], dtype='object')

# %%
nice_feat_names = {
    'decaf_fc6 False vw': 'DeCAF_6',
    'decaf_fc6_flatten False vw': 'DeCAF_5',
    'decaf_tuned_fc6 False vw': 'Fine-tuned DeCAF_6',
    'decaf_tuned_fc6,pascal_mc_for_decaf_tuned_fc6 pd vw': 'DeCAF_6 x Content',
    'decaf_tuned_fc6_flatten False vw': 'Fine-tuned DeCAF_5',
    'fusion_flickr_oct26 None vw': 'Late fusion',
    'fusion_flickr_oct26,pascal_mc_for_fusion_flickr_oct26 fp vw': 'Late-fusion x Content',
    'mc_bit False vw': 'MC-bit'
}

mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=preds_panel.minor_axis.tolist() + ['random'],
    balanced=True, with_plot=False, with_print=False, nice_feat_names=nice_feat_names)
# Out:
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_fc6 False vw********************
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_fc6_flatten False vw********************
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************decaf_tuned_fc6 False vw********************
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************fusion_flickr_oct26,pascal_mc_for_fusion_flickr_oct26 fp vw********************
# Looks like the preds frame already has gt info.
# Only taking 'test' split predictions.
# ********************mc_bit False vw********************
# Looks like the preds frame already has gt info.
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ True].
#   pred_df['label'], pred_df['pred_bin'])
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])
# Only taking 'test' split predictions.
# ********************random********************

# %%
ap_df = mc_metrics['ap_df'].copy()
ap_df
# Out:
#                                DeCAF_6     DeCAF_5 Fine-tuned DeCAF_6  \
# style_Bright,_Energetic      0.3351026   0.3269672           0.363762
# style_Depth_of_Field         0.2482035    0.217462          0.2573376
# style_Ethereal               0.3616337    0.355642          0.3728667
# style_Geometric_Composition  0.4152786   0.3648662          0.3931962
# style_HDR                    0.4665558    0.335402          0.4737614
# style_Hazy                     0.50429   0.3894099          0.4994355
# style_Horror                 0.4620782   0.3422808          0.4793058
# style_Long_Exposure          0.3832794   0.3081033          0.4204988
# style_Macro                  0.6766343    0.590946          0.6758878
# style_Melancholy             0.1590168  0.09782438          0.1722044
# style_Minimal                0.4703267   0.3287882          0.4661944
# style_Noir                   0.5177567   0.3799497          0.5220968
# style_Romantic               0.1891556   0.1455972          0.1995547
# style_Serene                 0.1996429   0.1425574          0.2023682
# style_Soft,_Pastel           0.3109956   0.2533801          0.3121457
# style_Sunny                    0.54074   0.4775125          0.5414972
# style_Vintage                 0.387972   0.3143064          0.3824078
# _mean                        0.3899213   0.3159409          0.3961483
#
#                             Late-fusion x Content     MC-bit      random
# style_Bright,_Energetic                 0.3488747  0.2486568  0.06836109
# style_Depth_of_Field                    0.2661056  0.2244359  0.06538524
# style_Ethereal                          0.4049492  0.3336516  0.06720231
# style_Geometric_Composition             0.4435846  0.4191548   0.0637535
# style_HDR                               0.5454542  0.5250402  0.06634187
# style_Hazy                              0.5670732  0.4785087  0.06787122
# style_Horror                            0.4769048  0.3002289  0.06246153
# style_Long_Exposure                     0.4655707  0.4073589  0.06651126
# style_Macro                             0.6916438   0.623753  0.07417948
# style_Melancholy                        0.1824684  0.1689813   0.0718906
# style_Minimal                           0.4917808  0.4536837  0.06563325
# style_Noir                               0.537022  0.4071778  0.06445551
# style_Romantic                          0.1921534   0.168565  0.06692545
# style_Serene                            0.2051429  0.2096363  0.06758394
# style_Soft,_Pastel                      0.3144385  0.2705613  0.07070091
# style_Sunny                              0.559768  0.5199951  0.06502221
# style_Vintage                           0.4095119  0.3436293  0.06448709
# _mean                                    0.417791  0.3590011  0.06698626

# %%
ap_df.ix['_mean']
# Out:
# DeCAF_6                   0.3899213
# DeCAF_5                   0.3159409
# Fine-tuned DeCAF_6        0.3961483
# Late-fusion x Content      0.417791
# MC-bit                    0.3590011
# random                   0.06698626
# Name: _mean, dtype: object

# %%
conf_df = mc_metrics['feat_metrics']['fusion_flickr_oct26,pascal_mc_for_fusion_flickr_oct26 fp vw']['conf_df'].astype(float)
conf_df.index = [x.replace('style_', '') for x in conf_df.index]
conf_df.columns = [x.replace('style_', '') for x in conf_df.columns]
fig = vislab.dataset_viz.plot_conditional_occurrence(conf_df, sort_by_prior=False, font_size=14)
fig.savefig('/Users/sergeyk/work/aphrodite-writeup/figures/evaluation/flickr_conf.pdf', bbox_inches='tight')

# %%
acc_df = mc_metrics['acc_df']
acc_df = acc_df[['Late-fusion x Content', 'Fine-tuned DeCAF_6', 'DeCAF_6', 'DeCAF_5', 'MC-bit', 'random']]
fig = vislab.results_viz.plot_top_k_accuracies(acc_df, font_size=16)
fig.savefig('/Users/sergeyk/work/aphrodite-writeup/figures/evaluation/flickr_top_k.pdf', bbox_inches='tight')

# %%
ap_df = mc_metrics['ap_df']
column_order = ap_df.columns[(-ap_df.ix['_mean']).argsort().values]
ap_df.index = [x.replace('style_', '') for x in ap_df.index]
ap_df = ap_df.reindex_axis(column_order, axis=1)
ap_df.to_csv('/Users/sergeyk/work/aphrodite-writeup/results/flickr_ap_df.csv')

fig = vislab.results_viz.plot_df_bar(ap_df, fontsize=14)
fig.savefig('/Users/sergeyk/work/aphrodite-writeup/figures/flickr_ap_barplot.pdf', bbox_inches='tight')
