# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import sklearn.metrics
import pandas as pd
import vislab.datasets
import vislab.results

# %%
label_df = vislab.datasets.flickr.load_flickr_df()

# %%
c = vislab.util.get_mongodb_client()['predict']['flickr_oct26']
if c.find({'features': 'noise'}).count() > 0:
    c.remove({'features': 'noise'})
pd.DataFrame([x for x in c.find()])
# Out:
#                         _id              data             features  num_test  \
# 0  526ce38a9622958641aaee52  flickr_style_ALL          [decaf_fc6]     10525
# 1  526cf7179622958641aaee53  flickr_style_ALL             [mc_bit]     10525
# 2  526da6289622958641aaee54  flickr_style_ALL  [decaf_fc6_flatten]     10525
#
#    num_train  num_val quadratic  \
# 0      29633    10040     False
# 1      29633    10040     False
# 2      29633    10040     False
#
#                                         results_name  score_test  score_val  \
# 0  data_flickr_style_ALL_features_['decaf_fc6']_n...    0.420880   0.495051
# 1  data_flickr_style_ALL_features_['mc_bit']_num_...    0.279248   0.399438
# 2  data_flickr_style_ALL_features_['decaf_fc6_fla...    0.366759   0.540157
#
#   task
# 0  clf
# 1  clf
# 2  clf

# %%
df, preds_panel = aphrodite.results.load_pred_results(
    'flickr_oct26', '/Users/sergeyk/work/aphrodite/data/results2', multiclass=True, force=True)
pred_prefix = 'pred'
print preds_panel.minor_axis
# Out:
# Results in collection flickr_oct26: 3
# Index([u'decaf_fc6 False vw', u'decaf_fc6_flatten False vw', u'mc_bit False vw'], dtype='object')

# %%
# OLD!
df, preds_panel = aphrodite.results.load_pred_results(
    'aug29', '/Users/sergeyk/work/ aphrodite/data/results', force=False)
pred_prefix = 'clf flickr_style'
print preds_panel.minor_axis
# Out:
# Loaded from cache: 136 records

# %%
mc_metrics = vislab.results.multiclass_metrics_feat_comparison(
    preds_panel, label_df, pred_prefix, features=preds_panel.minor_axis.tolist() + ['random'],
    balanced=True, with_plot=True, with_print=True)
# Out:
# Looks like the preds frame already has gt info.
# ********************decaf_fc6 False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                              precision    recall  f1-score  support
# style_Bright,_Energetic       0.463636  0.409091  0.434659     2992
# style_Depth_of_Field          0.372148  0.320896  0.344627     2948
# style_Ethereal                0.462441  0.461358  0.461899     2989
# style_Geometric_Composition   0.462963  0.480607  0.471620     2965
# style_HDR                     0.501632  0.568021  0.532766     2977
# style_Hazy                    0.490358  0.599125  0.539312     2971
# style_Horror                  0.508679  0.480107  0.493980     2991
# style_Long_Exposure           0.477641  0.504622  0.490761     2921
# style_Macro                   0.620728  0.761325  0.683875     2958
# style_Melancholy              0.342598  0.195114  0.248630     2906
# style_Minimal                 0.451509  0.575549  0.506039     2912
# style_Noir                    0.490693  0.634783  0.553514     2990
# style_Romantic                0.330081  0.205882  0.253592     2958
# style_Serene                  0.368252  0.235959  0.287623     2920
# style_Soft,_Pastel            0.371440  0.330639  0.349854     2722
# style_Sunny                   0.527715  0.632757  0.575482     2949
# style_Vintage                 0.456218  0.514047  0.483409     2990
# accuracy: 0.466429613057
#
# Looks like the preds frame already has gt info.
# ********************decaf_fc6_flatten False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                              precision    recall  f1-score  support
# style_Bright,_Energetic       0.762800  0.243984  0.369714     2992
# style_Depth_of_Field          0.697793  0.139464  0.232466     2947
# style_Ethereal                0.784437  0.249498  0.378584     2990
# style_Geometric_Composition   0.766347  0.296459  0.427529     2965
# style_HDR                     0.435217  0.672489  0.528441     2977
# style_Hazy                    0.508545  0.621003  0.559176     2971
# style_Horror                  0.582422  0.498495  0.537201     2991
# style_Long_Exposure           0.519935  0.549127  0.534133     2921
# style_Macro                   0.486668  0.832995  0.614387     2958
# style_Melancholy              0.474672  0.261004  0.336809     2908
# style_Minimal                 0.412643  0.645604  0.503482     2912
# style_Noir                    0.435061  0.771906  0.556480     2990
# style_Romantic                0.400668  0.364650  0.381812     2959
# style_Serene                  0.422880  0.283562  0.339483     2920
# style_Soft,_Pastel            0.376598  0.422271  0.398129     2721
# style_Sunny                   0.481526  0.680801  0.564081     2948
# style_Vintage                 0.464337  0.644482  0.539776     2990
# accuracy: 0.481602077507
#
# Looks like the preds frame already has gt info.
# ********************mc_bit False vw********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                              precision    recall  f1-score  support
# style_Bright,_Energetic       0.495983  0.309699  0.381305     2990
# style_Depth_of_Field          0.432269  0.340238  0.380771     2945
# style_Ethereal                0.658333  0.238031  0.349643     2987
# style_Geometric_Composition   0.590397  0.477058  0.527710     2964
# style_HDR                     0.434612  0.742608  0.548319     2976
# style_Hazy                    0.812500  0.262715  0.397048     2969
# style_Horror                  0.759563  0.046504  0.087642     2989
# style_Long_Exposure           0.203998  0.916381  0.333708     2918
# style_Macro                   0.370991  0.943166  0.532518     2956
# style_Melancholy              0.243112  0.516529  0.330615     2904
# style_Minimal                 0.663798  0.423909  0.517400     2911
# style_Noir                    0.932773  0.074297  0.137632     2988
# style_Romantic                0.603113  0.052436  0.096483     2956
# style_Serene                  0.727915  0.070596  0.128710     2918
# style_Soft,_Pastel            0.302043  0.538631  0.387046     2718
# style_Sunny                   0.689080  0.406993  0.511737     2946
# style_Vintage                 0.873950  0.034794  0.066924     2989
# accuracy: 0.374380297457
#
# Looks like the preds frame already has gt info.
# ********************random********************
# ------------------------------------------------------------
# Classification metrics on {} balanced
#                              precision    recall  f1-score  support
# style_Bright,_Energetic       0.050964  0.049482  0.050212     2991
# style_Depth_of_Field          0.059247  0.058684  0.058964     2948
# style_Ethereal                0.063815  0.062876  0.063342     2990
# style_Geometric_Composition   0.059028  0.057316  0.058159     2966
# style_HDR                     0.059959  0.058448  0.059194     2977
# style_Hazy                    0.060831  0.060586  0.060708     2971
# style_Horror                  0.060737  0.061184  0.060959     2991
# style_Long_Exposure           0.055349  0.056145  0.055744     2921
# style_Macro                   0.057172  0.057809  0.057489     2958
# style_Melancholy              0.057192  0.056779  0.056985     2906
# style_Minimal                 0.060076  0.060096  0.060086     2912
# style_Noir                    0.060006  0.061873  0.060925     2990
# style_Romantic                0.061870  0.062183  0.062026     2959
# style_Serene                  0.068301  0.066781  0.067532     2920
# style_Soft,_Pastel            0.051759  0.056209  0.053892     2722
# style_Sunny                   0.054558  0.054613  0.054586     2948
# style_Vintage                 0.059696  0.059197  0.059446     2990
# accuracy: 0.0588493807431
# /Users/sergeyk/work/vislab/vislab/results.py:72: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [False]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [False].
#   pred_df['label'], pred_df['pred_bin'])
