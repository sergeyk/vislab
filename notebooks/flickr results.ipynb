# %%
# %load_ext autoreload
# %autoreload 2
import re
import aphrodite.results
import sklearn.metrics
import pandas as pd
import vislab
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
label_df = vislab.datasets.flickr.load_flickr_df()

# %%
df, preds_panel = aphrodite.results.load_pred_results('aug29', '/Users/sergeyk/work/aphrodite-dev/data/results', force=False)

# %%
mc_pred_df = preds_panel.minor_xs('decaf_fc6  vw').join(label_df)
mc_pred_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50198 entries, f_1094854525 to f_99137295
# Data columns (total 36 columns):
# clf flickr_style_Bright,_Energetic        50198  non-null values
# clf flickr_style_Depth_of_Field           50198  non-null values
# clf flickr_style_Ethereal                 50198  non-null values
# clf flickr_style_Geometric_Composition    50198  non-null values
# clf flickr_style_HDR                      50198  non-null values
# clf flickr_style_Hazy                     50198  non-null values
# clf flickr_style_Horror                   50198  non-null values
# clf flickr_style_Long_Exposure            50198  non-null values
# clf flickr_style_Macro                    50198  non-null values
# clf flickr_style_Melancholy               50198  non-null values
# clf flickr_style_Minimal                  50198  non-null values
# clf flickr_style_Noir                     50198  non-null values
# clf flickr_style_Romantic                 50198  non-null values
# ...

# %%
full_mc_metrics = vislab.results.multiclass_metrics(mc_pred_df, 'clf flickr_style', balanced=False)
# Out:
# ------------------------------------------------------------
# Classification metrics on the full dataset
#                        precision    recall  f1-score  support
# Bright,_Energetic       0.543867  0.446333  0.490297     3000
# Depth_of_Field          0.386169  0.336265  0.359494     2956
# Ethereal                0.453739  0.477652  0.465388     2998
# Geometric_Composition   0.499781  0.384331  0.434518     2974
# HDR                     0.521117  0.487609  0.503806     2986
# Hazy                    0.494199  0.600336  0.542121     2980
# Horror                  0.471853  0.556000  0.510482     3000
# Long_Exposure           0.494597  0.406143  0.446027     2930
# Macro                   0.670562  0.715538  0.692320     2967
# Melancholy              0.227656  0.092624  0.131675     2915
# Minimal                 0.444473  0.582335  0.504149     2921
# Noir                    0.450305  0.714572  0.552462     2999
# ...

# %%
all_binary_metrics_df = vislab.results.all_binary_metrics_df(
    preds_panel, label_df, 'decaf_fc6  vw', 'clf flickr_style', balanced=False)

# %%
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(111)
ax = all_binary_metrics_df[['ap', 'accuracy', 'mcc']].plot(ax=ax, kind='bar')
fig.autofmt_xdate()
